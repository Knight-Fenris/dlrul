# %%
import gc
gc.collect()
import numpy as np
import pandas as pd
import os
import h5py
import time
import matplotlib.pyplot as plt
from pprint import pprint
# %matplotlib inline

# TPU initialization moved to top for better efficiency
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.metrics import R2Score as RSquare
from sklearn.preprocessing import StandardScaler

# Fixed TPU strategy setup for Kaggle TPUv5
# try:
#     tpu = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='local')
#     tf.config.experimental_connect_to_cluster(tpu)
#     tf.tpu.experimental.initialize_tpu_system(tpu)
#     tpu_strategy = tf.distribute.TPUStrategy(tpu)
#     print(f"Running on TPU with {tpu_strategy.num_replicas_in_sync} cores")
# except (ValueError, RuntimeError):
tpu_strategy = tf.distribute.get_strategy()
print("Running on CPU/GPU")

all_files=[]
for dirname, _, filenames in os.walk('./data_set'):
    for filename in filenames:
        all_files.append(os.path.join(dirname, filename))
all_files.sort()
pprint(all_files)
# Out:
# Running on CPU/GPU
# ['./data_set/N-CMAPSS_DS01-005.h5',
#  './data_set/N-CMAPSS_DS02-006.h5',
#  './data_set/N-CMAPSS_DS03-012.h5',
#  './data_set/N-CMAPSS_DS04.h5',
#  './data_set/N-CMAPSS_DS05.h5',
#  './data_set/N-CMAPSS_DS06.h5',
#  './data_set/N-CMAPSS_DS07.h5',
#  './data_set/N-CMAPSS_DS08a-009.h5',
#  './data_set/N-CMAPSS_DS08c-008.h5',
#  './data_set/N-CMAPSS_DS08d-010.h5',
#  './data_set/N-CMAPSS_Example_data_loading_and_exploration.ipynb',
#  './data_set/Run_to_Failure_Simulation_Under_Real_Flight_Conditions_Dataset.pdf',
#  './data_set/data-06-00005-v2.pdf',
#  './data_set/flight_profile_DS02.png',
#  './data_set/kde_DS02.png']

# %%
def read_hdf(filename):
    t = time.process_time()  
    with h5py.File(filename, 'r') as hdf:
        # Development set
        W_dev = np.array(hdf.get('W_dev'), dtype=np.float32)
        X_s_dev = np.array(hdf.get('X_s_dev'), dtype=np.float32)
        X_v_dev = np.array(hdf.get('X_v_dev'), dtype=np.float32)
        T_dev = np.array(hdf.get('T_dev'), dtype=np.float32)
        Y_dev = np.array(hdf.get('Y_dev'), dtype=np.float32)
        A_dev = np.array(hdf.get('A_dev'), dtype=np.float32)

        # Test set
        W_test = np.array(hdf.get('W_test'), dtype=np.float32)
        X_s_test = np.array(hdf.get('X_s_test'), dtype=np.float32)
        X_v_test = np.array(hdf.get('X_v_test'), dtype=np.float32)
        T_test = np.array(hdf.get('T_test'), dtype=np.float32)
        Y_test = np.array(hdf.get('Y_test'), dtype=np.float32)
        A_test = np.array(hdf.get('A_test'), dtype=np.float32)
        
        # Varnams
        W_var = np.array(hdf.get('W_var'))
        X_s_var = np.array(hdf.get('X_s_var'))  
        X_v_var = np.array(hdf.get('X_v_var')) 
        T_var = np.array(hdf.get('T_var'))
        A_var = np.array(hdf.get('A_var'))
        
        # from np.array to list dtype U4/U5
        W_var = list(np.array(W_var, dtype='U20'))
        X_s_var = list(np.array(X_s_var, dtype='U20'))  
        X_v_var = list(np.array(X_v_var, dtype='U20')) 
        T_var = list(np.array(T_var, dtype='U20'))
        A_var = list(np.array(A_var, dtype='U20'))
                        
    ## Train data
    df_a_dev=pd.DataFrame(A_dev,columns=A_var)
    df_t_dev=pd.DataFrame(T_dev,columns=T_var)
    df_w_dev=pd.DataFrame(W_dev,columns=W_var)
    df_xs_dev=pd.DataFrame(X_s_dev,columns=X_s_var)
    df_xv_dev=pd.DataFrame(X_v_dev,columns=X_v_var)
    df_y_dev=pd.DataFrame(Y_dev,columns=['RUL'])

    #get rul
    trainy=df_y_dev[['RUL']]

    #get x from sensors values
    trainx=pd.concat([df_xs_dev,df_w_dev],axis=1)

    print(type(trainy),trainy.shape, type(trainx), trainx.shape)

    ## Test data
    df_a_test=pd.DataFrame(A_test,columns=A_var)
    df_t_test=pd.DataFrame(T_test,columns=T_var)
    df_w_test=pd.DataFrame(W_test,columns=W_var)
    df_xs_test=pd.DataFrame(X_s_test,columns=X_s_var)
    df_xv_test=pd.DataFrame(X_v_test,columns=X_v_var)
    df_y_test=pd.DataFrame(Y_test,columns=['RUL'])

    #get health state from aux
    testy=df_y_test[['RUL']]

    #get x from sensors values
    testx=pd.concat([df_xs_test,df_w_test],axis=1)

    print(type(testy),testy.shape, type(testx), testx.shape)

    print('')
    print("Operation time (min): " , (time.process_time()-t)/60)
    print('')

    return (trainx,trainy,df_a_dev,testx,testy,df_a_test)

# %%
curr_file=all_files[2]
print(curr_file)
# Out:
# ./data_set/N-CMAPSS_DS03-012.h5

# %%
trainx,trainy,adev,testx,testy,atest = read_hdf(filename=curr_file)
# Out:
# <class 'pandas.core.frame.DataFrame'> (5571277, 1) <class 'pandas.core.frame.DataFrame'> (5571277, 18)
# <class 'pandas.core.frame.DataFrame'> (4251560, 1) <class 'pandas.core.frame.DataFrame'> (4251560, 18)
#
# Operation time (min):  0.03280156666666656
#
# <class 'pandas.core.frame.DataFrame'> (4251560, 1) <class 'pandas.core.frame.DataFrame'> (4251560, 18)
#
# Operation time (min):  0.03280156666666656

# %%
trainx.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5571277 entries, 0 to 5571276
# Data columns (total 18 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   T24     5571277 non-null  float32
#  1   T30     5571277 non-null  float32
#  2   T48     5571277 non-null  float32
#  3   T50     5571277 non-null  float32
#  4   P15     5571277 non-null  float32
#  5   P2      5571277 non-null  float32
#  6   P21     5571277 non-null  float32
#  7   P24     5571277 non-null  float32
#  8   Ps30    5571277 non-null  float32
#  9   P40     5571277 non-null  float32
#  10  P50     5571277 non-null  float32
#  11  Nf      5571277 non-null  float32
#  12  Nc      5571277 non-null  float32
#  13  Wf      5571277 non-null  float32
#  14  alt     5571277 non-null  float32
#  15  Mach    5571277 non-null  float32
#  16  TRA     5571277 non-null  float32
#  17  T2      5571277 non-null  float32
# dtypes: float32(18)
# memory usage: 382.5 MB

# %%
# Standard scale with memory optimization
sc=StandardScaler()
sc.fit(trainx.values)
trainx_l_sc=sc.transform(trainx.values).astype(np.float32)
testx_l_sc=sc.transform(testx.values).astype(np.float32)

print(trainx_l_sc.shape, testx_l_sc.shape, trainy.shape, testy.shape)

trainx_l_sc=pd.DataFrame(trainx_l_sc,columns=trainx.columns)
testx_l_sc=pd.DataFrame(testx_l_sc,columns=trainx.columns)

print(trainx_l_sc.shape, testx_l_sc.shape, trainy.shape, testy.shape)
# Out:
# (5571277, 18) (4251560, 18) (5571277, 1) (4251560, 1)
# (5571277, 18) (4251560, 18) (5571277, 1) (4251560, 1)

# %%
def time_window_slicing_sample(input_array, window_length, unit, sequence_cols, stride=1):
    window_lst = []
    input_temp = input_array[input_array['unit'] == unit][sequence_cols].values.astype(np.float32)
    print ("Unit%s input array shape: " %unit, input_temp.shape)
    num_samples = int((input_temp.shape[0] - window_length)/stride) + 1

    for i in range(num_samples):
        window = input_temp[i*stride:i*stride + window_length,:]
        window_lst.append(window)

    sample_array = np.dstack(window_lst).astype(np.float32)
    print ("sample_array.shape", sample_array.shape)
    return sample_array

def time_window_slicing_label(input_array, window_length, unit, sequence_cols = 'RUL', stride=1):
    window_lst = []
    input_temp = input_array[input_array['unit'] == unit][sequence_cols].values.astype(np.float32)
    num_samples = int((input_temp.shape[0] - window_length)/stride) + 1
    for i in range(num_samples):
        window = input_temp[i*stride:i*stride + window_length]
        window_lst.append(window)

    label_array = np.asarray(window_lst).astype(np.float32)
    return label_array[:,-1]

# %%
trainy = trainy[trainy!=0].dropna()
trainx_l_sc = trainx_l_sc.loc[trainy.index]
testy = testy[testy!=0].dropna()
testx_l_sc = testx_l_sc.loc[testy.index]

print(trainx_l_sc.shape, trainy.shape, testy.shape, testx_l_sc.shape)
# Out:
# (5486397, 18) (5486397, 1) (4189932, 1) (4189932, 18)

# %%
df=trainx_l_sc.copy()
df['unit']=adev['unit']
df['RUL']=trainy['RUL']

# %%
# Optimized windowing with reduced window size for memory efficiency
WINDOW_SIZE = 30  # Reduced from 50
STRIDE = 15      # Reduced from 25

all_units_data=[]
for un in adev.unit.unique():
    all_units_data.append(time_window_slicing_sample(df, WINDOW_SIZE, un, df.columns.difference(['unit','RUL']), STRIDE))

all_units_data=np.dstack(all_units_data)
all_units_data=all_units_data.transpose(2,0,1)
print(all_units_data.shape)
# Out:
# Unit1.0 input array shape:  (303829, 18)
# sample_array.shape (30, 18, 20254)
# Unit2.0 input array shape:  (637806, 18)
# sample_array.shape (30, 18, 42519)
# Unit3.0 input array shape:  (582325, 18)
# Unit2.0 input array shape:  (637806, 18)
# sample_array.shape (30, 18, 42519)
# Unit3.0 input array shape:  (582325, 18)
# sample_array.shape (30, 18, 38820)
# Unit4.0 input array shape:  (530938, 18)
# sample_array.shape (30, 18, 38820)
# Unit4.0 input array shape:  (530938, 18)
# sample_array.shape (30, 18, 35394)
# Unit5.0 input array shape:  (396645, 18)
# sample_array.shape (30, 18, 26442)
# sample_array.shape (30, 18, 35394)
# Unit5.0 input array shape:  (396645, 18)
# sample_array.shape (30, 18, 26442)
# Unit6.0 input array shape:  (926215, 18)
# Unit6.0 input array shape:  (926215, 18)
# sample_array.shape (30, 18, 61746)
# Unit7.0 input array shape:  (690621, 18)
# sample_array.shape (30, 18, 61746)
# Unit7.0 input array shape:  (690621, 18)
# sample_array.shape (30, 18, 46040)
# Unit8.0 input array shape:  (1059191, 18)
# sample_array.shape (30, 18, 46040)
# Unit8.0 input array shape:  (1059191, 18)
# sample_array.shape (30, 18, 70611)
# sample_array.shape (30, 18, 70611)
# Unit9.0 input array shape:  (358827, 18)
# sample_array.shape (30, 18, 23920)
# Unit9.0 input array shape:  (358827, 18)
# sample_array.shape (30, 18, 23920)
# (365746, 30, 18)
# (365746, 30, 18)

# %%
all_labels=[]
for un in adev.unit.unique():
    all_labels=all_labels+time_window_slicing_label(df, WINDOW_SIZE, un, stride=STRIDE).tolist()

print(len(all_labels))
all_labels=np.array(all_labels, dtype=np.float32)
# Out:
# 365746

# %%
#test data
df=testx_l_sc.copy()
df['unit']=atest['unit']
df['RUL']=testy['RUL']

test_units_data=[]
for un in atest.unit.unique():
    test_units_data.append(time_window_slicing_sample(df, WINDOW_SIZE, un, df.columns.difference(['unit','RUL']), STRIDE))

test_units_data=np.dstack(test_units_data)
test_units_data=test_units_data.transpose(2,0,1)
print(test_units_data.shape)

test_labels=[]
for un in atest.unit.unique():
    test_labels=test_labels+time_window_slicing_label(df, WINDOW_SIZE, un, stride=STRIDE).tolist()

print(len(test_labels))
test_labels=np.array(test_labels, dtype=np.float32)
# Out:
# Unit10.0 input array shape:  (938592, 18)
# sample_array.shape (30, 18, 62571)
# Unit11.0 input array shape:  (814152, 18)
# sample_array.shape (30, 18, 62571)
# Unit11.0 input array shape:  (814152, 18)
# sample_array.shape (30, 18, 54275)
# Unit12.0 input array shape:  (399732, 18)
# sample_array.shape (30, 18, 26647)
# sample_array.shape (30, 18, 54275)
# Unit12.0 input array shape:  (399732, 18)
# sample_array.shape (30, 18, 26647)
# Unit13.0 input array shape:  (1089493, 18)
# Unit13.0 input array shape:  (1089493, 18)
# sample_array.shape (30, 18, 72631)
# Unit14.0 input array shape:  (340824, 18)
# sample_array.shape (30, 18, 22720)
# Unit15.0 input array shape:  (607139, 18)
# sample_array.shape (30, 18, 72631)
# Unit14.0 input array shape:  (340824, 18)
# sample_array.shape (30, 18, 22720)
# Unit15.0 input array shape:  (607139, 18)
# sample_array.shape (30, 18, 40474)
# sample_array.shape (30, 18, 40474)
# (279318, 30, 18)
# (279318, 30, 18)
# 279318
# 279318

# %%
from sklearn.model_selection import train_test_split
xtrain,xval,ytrain,yval=train_test_split(all_units_data,all_labels,test_size=0.2, random_state=42)

ytrain = ytrain.reshape([-1, 1])
yval = yval.reshape([-1, 1])
test_labels = test_labels.reshape([-1, 1])

print(f"Final shapes - Train: {xtrain.shape}, Val: {xval.shape}, Test: {test_units_data.shape}")

# Clean up memory
del all_units_data, all_labels, adev, trainx, trainy, trainx_l_sc
gc.collect()
# Out:
# Final shapes - Train: (292596, 30, 18), Val: (73150, 30, 18), Test: (279318, 30, 18)
# 4

# %%
# Optimized batch size for TPUv5 and memory constraints
# Use smaller batch size to avoid memory issues

# BATCH_SIZE = 32
BATCH_SIZE = 2048

BUFFER_SIZE = 5000  # Further reduced buffer size

# Ensure data types
xtrain = xtrain.astype(np.float32)
ytrain = ytrain.astype(np.float32)
xval = xval.astype(np.float32)
yval = yval.astype(np.float32)
test_units_data = test_units_data.astype(np.float32)
test_labels = test_labels.astype(np.float32)

# Optimized tf.data pipeline
train_ds = tf.data.Dataset.from_tensor_slices((xtrain, ytrain))
val_ds = tf.data.Dataset.from_tensor_slices((xval, yval))
test_ds = tf.data.Dataset.from_tensor_slices((test_units_data, test_labels))

AUTOTUNE = tf.data.AUTOTUNE

# More efficient data pipeline with explicit options
train_gen = (
    train_ds
    .shuffle(buffer_size=BUFFER_SIZE, seed=42, reshuffle_each_iteration=False)
    .batch(BATCH_SIZE, drop_remainder=True)
    .cache()
    .prefetch(2)  # Fixed prefetch value instead of AUTOTUNE
)

val_gen = (
    val_ds
    .batch(BATCH_SIZE)
    .cache()
    .prefetch(2)  # Fixed prefetch value
)

test_gen = (
    test_ds
    .batch(BATCH_SIZE)
    .prefetch(2)  # Fixed prefetch value
)

print("✅ Optimized tf.data pipelines created successfully.")
# Out:
# ✅ Optimized tf.data pipelines created successfully.

# %%
# Enhanced transformer encoder for sequential data
class Shape(tf.keras.layers.Layer):
    def call(self,x):
        return tf.shape(x)

def transformer_encoder_v4(inputs, head_size, num_heads, ff_dim, dropout, use_causal_mask=False):
    """Sequential-data optimized transformer block with causal attention option."""
    
    # Pre-LayerNorm for better gradient flow
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs)
    
    # Multi-head attention with causal masking for sequential data
    attention_layer = tf.keras.layers.MultiHeadAttention(
        key_dim=head_size, 
        num_heads=num_heads, 
        dropout=dropout,
        use_bias=False
    )
    
    attention_output = attention_layer(x, x, use_causal_mask=use_causal_mask)    
    attention_output = tf.keras.layers.Dropout(dropout)(attention_output)
    res1 = attention_output + inputs

    # Enhanced feed-forward with residual connections
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(res1)
    
    # Two-layer feed-forward with residual connection
    x_ff = tf.keras.layers.Dense(ff_dim, activation="gelu", use_bias=False)(x)
    x_ff = tf.keras.layers.Dropout(dropout)(x_ff)
    x_ff = tf.keras.layers.Dense(inputs.shape[-1], use_bias=False)(x_ff)
    
    return x_ff + res1

# Positional encoding for sequential data
def positional_encoding_layer(sequence_length, d_model, max_wavelength=10000):
    """Sinusoidal positional encoding for sequential data."""
    position = tf.cast(tf.range(sequence_length)[:, tf.newaxis], dtype=tf.float32)
    div_term = tf.exp(tf.cast(tf.range(0, d_model, 2), dtype=tf.float32) * 
                      -(tf.math.log(float(max_wavelength)) / d_model))
    
    pos_encoding = tf.zeros((sequence_length, d_model))
    pos_encoding = tf.concat([
        tf.sin(position * div_term),
        tf.cos(position * div_term)
    ], axis=-1)
    
    if d_model % 2 == 1:
        pos_encoding = pos_encoding[:, :-1]
    
    return pos_encoding

class PositionalEncoding(tf.keras.layers.Layer):
    """Learnable positional encoding layer for sequential data."""
    def __init__(self, sequence_length, d_model, **kwargs):
        super(PositionalEncoding, self).__init__(**kwargs)
        self.sequence_length = sequence_length
        self.d_model = d_model
        
    def build(self, input_shape):
        self.pos_encoding = self.add_weight(
            name='pos_encoding',
            shape=(self.sequence_length, self.d_model),
            initializer='uniform',
            trainable=True
        )
        super(PositionalEncoding, self).build(input_shape)
    
    def call(self, inputs):
        return inputs + self.pos_encoding

# Temporal convolutional layer for local sequential patterns
def temporal_conv_block(inputs, filters, kernel_size, dropout):
    """1D convolutional block to capture local temporal patterns."""
    x = tf.keras.layers.Conv1D(
        filters=filters, 
        kernel_size=kernel_size, 
        padding='same', 
        activation='gelu',
        use_bias=False
    )(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    
    # Residual connection if dimensions match
    if inputs.shape[-1] == filters:
        x = x + inputs
    
    return x

# %%
import keras_tuner
import keras_nlp
class ReduceSumLayer(tf.keras.layers.Layer):
    def call(self,x):
        return tf.reduce_sum(x,axis=1)
def build_sequential_transformer(hp):
    """Enhanced transformer model specifically designed for sequential RUL prediction."""
    # Reduced input shape due to smaller window
    input_shape = (WINDOW_SIZE, 18)
    
    # Hyperparameters optimized for sequential data
    head_size = hp.Choice("head_size", [8, 16, 32])
    num_heads = hp.Choice("num_heads", [2, 4, 6])  # Even numbers work better
    ff_dim = hp.Choice("ff_dim", [64, 128, 256])
    num_transformer_blocks = hp.Int("num_blocks", min_value=2, max_value=6, step=1)
    mlp_units = hp.Int("mlp_units", min_value=1, max_value=3, step=1)
    learning_rate = hp.Choice("learning_rate", [1e-3, 5e-4, 1e-4, 5e-5])
    
    # Sequential data specific parameters
    # use_causal_mask = True  # For degradation prediction
    use_causal_mask = hp.Boolean("use_causal_mask")  # For degradation prediction
    use_temp_conv = hp.Boolean("use_temp_conv")      # Local temporal patterns
    pos_encoding_type = hp.Choice("pos_encoding", ["learnable", "sinusoidal", "none"])
    
    with tpu_strategy.scope():
        inputs = tf.keras.Input(shape=input_shape)
        x = inputs
        
        # Temporal convolutional preprocessing for local patterns
        if use_temp_conv:
            temp_filters = hp.Choice("temp_filters", [16, 32])
            temp_kernel = hp.Choice("temp_kernel", [3, 5])
            temp_dropout = hp.Float('temp_dropout', min_value=0.1, max_value=0.3, step=0.1)
            x = temporal_conv_block(x, temp_filters, temp_kernel, temp_dropout)
            x = temporal_conv_block(x, input_shape[-1], 1, temp_dropout)  # Project back
        
        # Positional encoding for sequential awareness
        if pos_encoding_type == "learnable":
            x = PositionalEncoding(input_shape[0], input_shape[1])(x)
        elif pos_encoding_type == "sinusoidal":
            pos_enc = positional_encoding_layer(input_shape[0], input_shape[1])
            x = x + pos_enc
        
        # Transformer blocks for long-range dependencies
        for i in range(num_transformer_blocks):
            dropout_rate = hp.Float(f'dropout_{i}', min_value=0.1, max_value=0.4, step=0.1)
            x = transformer_encoder_v4(x, head_size, num_heads, ff_dim, dropout_rate, use_causal_mask)
        
        # Sequence aggregation strategies
        aggregation = hp.Choice("aggregation", ["attention","last", "mean", "max"])
        
        if aggregation == "last":
            # Last timestep - most relevant for RUL
            x = x[:, -1, :]
        elif aggregation == "mean":
            x = tf.keras.layers.GlobalAveragePooling1D()(x)
        elif aggregation == "max":
            x = tf.keras.layers.GlobalMaxPooling1D()(x)
        elif aggregation == "attention":
            # Learnable attention weighting
            attention_weights = tf.keras.layers.Dense(1, activation='softmax')(x)
            # x = tf.reduce_sum(x * attention_weights, axis=1)
            x = ReduceSumLayer()(x*attention_weights)
        
        # Enhanced MLP head with skip connections
        original_dim = x.shape[-1]
        for i in range(mlp_units):
            dim = hp.Choice(f'dim_{i}', [32, 64, 128, 256])
            mlp_dropout = hp.Float(f'mlp_dropout_{i}', min_value=0.1, max_value=0.5, step=0.1)
            mlp_activation = hp.Choice(f'mlp_activ_{i}', ['gelu', 'swish', 'relu'])
            
            x_dense = tf.keras.layers.Dense(dim, activation=mlp_activation, use_bias=False)(x)
            x_dense = tf.keras.layers.BatchNormalization()(x_dense)
            x_dense = tf.keras.layers.Dropout(mlp_dropout)(x_dense)
            
            # Skip connection if dimensions allow
            if i == 0 and original_dim == dim:
                x = x_dense + x
            else:
                x = x_dense
        
        # Final regression layer with optional activation
        final_activation = hp.Choice("final_activation", ["linear", "relu"])
        outputs = tf.keras.layers.Dense(1, activation=final_activation)(x)
        
        model = tf.keras.Model(inputs, outputs)

        # Enhanced optimizer selection with schedule
        optimizer_type = hp.Choice('optimizer', ['adam', 'adamw', 'rmsprop'])
        # use_schedule = hp.Boolean('use_lr_schedule')

        
        if optimizer_type == 'adamw':
            optimizer = tf.keras.optimizers.AdamW(
                learning_rate=learning_rate, 
                weight_decay=1e-4,
                clipnorm=1.0
            )
        elif optimizer_type == 'rmsprop':
            optimizer = tf.keras.optimizers.RMSprop(
                learning_rate=learning_rate,
                clipnorm=1.0
            )
        else:
            optimizer = tf.keras.optimizers.Adam(
                learning_rate=learning_rate,
                clipnorm=1.0
            )
        
        # Enhanced loss function for RUL prediction
        loss_type = hp.Choice('loss', ['mse', 'mae', 'huber'])
        if loss_type == 'huber':
            loss = tf.keras.losses.Huber(delta=1.0)  # Robust to outliers
        elif loss_type == 'mae':
            loss = tf.keras.losses.MeanAbsoluteError()
        else:
            loss = tf.keras.losses.MeanSquaredError()
            
        model.compile(
            loss=loss,
            optimizer=optimizer, 
            metrics=["mean_absolute_error", "mean_squared_error"]
        )
    
    return model

# %%
# Test the sequential model creation
# with tpu_strategy.scope():
#     test_model = build_sequential_transformer(keras_tuner.HyperParameters())
#     test_model.summary()
#     print(f"Model has {test_model.count_params():,} parameters")

# %%
tuner = keras_tuner.BayesianOptimization(
    hypermodel=build_sequential_transformer,
    objective="val_mean_absolute_error",
    max_trials=100,  
    executions_per_trial=2,
    overwrite=False,#set True when training new
    directory="keras_tuner_sequential",
    project_name="sequential_transformer_rul",
    distribution_strategy=tpu_strategy,
    max_consecutive_failed_trials=5
)

# tuner.search_space_summary()
# Out:
# Reloading Tuner from keras_tuner_sequential/sequential_transformer_rul/tuner0.json

# %%
# Enhanced callbacks for sequential training
import os
os.makedirs('checkpoints', exist_ok=True)

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=12, 
        restore_best_weights=True, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.7, 
        patience=5, 
        min_lr=1e-8, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'checkpoints/best_sequential_model.weights.h5', 
        save_best_only=True, 
        save_weights_only=True, 
        monitor='val_loss'
    )
]
# callbacks.append(lr_sche)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Sequential model training with fallback
# try:
#     print("Starting sequential transformer hyperparameter search...")
#     history = tuner.search(
#         train_gen,
#         verbose=2,
#         epochs=100,
#         validation_data=val_gen, 
#         callbacks=callbacks[:2]  # Skip checkpoint for tuning
#     )
    
#     # Get best model
#     with tpu_strategy.scope():
#         best_hps = tuner.get_best_hyperparameters()[0]
#         print("Optimal hyperparameters for sequential model:")
#         for hp_name in best_hps.values.keys():
#             print(f"{hp_name}: {best_hps.get(hp_name)}")
        
#         model = build_sequential_transformer(best_hps)
    
# except Exception as e:
#     print(f"Sequential tuner failed with error: {e}")

# %%
best_hps = tuner.get_best_hyperparameters()[0]

# %%
print("The hyperparameter search is complete. Here are the optimal values:")
for hp_name in best_hps.values.keys():
    print(f"{hp_name}: {best_hps.get(hp_name)}")
# Out:
# The hyperparameter search is complete. Here are the optimal values:
# head_size: 32
# num_heads: 6
# ff_dim: 64
# num_blocks: 3
# mlp_units: 3
# learning_rate: 0.001
# use_causal_mask: False
# use_temp_conv: True
# pos_encoding: sinusoidal
# dropout_0: 0.4
# dropout_1: 0.2
# aggregation: mean
# dim_0: 128
# mlp_dropout_0: 0.1
# mlp_activ_0: swish
# final_activation: linear
# optimizer: rmsprop
# use_lr_schedule: False
# loss: mae
# temp_filters: 32
# temp_kernel: 3
# temp_dropout: 0.1
# dropout_2: 0.1
# dropout_3: 0.4
# dim_1: 64
# mlp_dropout_1: 0.2
# mlp_activ_1: gelu
# dropout_4: 0.30000000000000004
# dim_2: 128
# mlp_dropout_2: 0.2
# mlp_activ_2: swish
# dropout_5: 0.2

# %%
# print("The hyperparameter search is complete. Here are the optimal values:")
# for hp_name in best_hps.values.keys():
#     print(f"{hp_name}: {best_hps.get(hp_name)}")
"""
The hyperparameter search is complete. Here are the optimal values:
head_size: 32
num_heads: 6
ff_dim: 64
num_blocks: 3
mlp_units: 3
learning_rate: 0.001
use_causal_mask: False
use_temp_conv: True
pos_encoding: sinusoidal
dropout_0: 0.4
dropout_1: 0.2
aggregation: mean
dim_0: 128
mlp_dropout_0: 0.1
mlp_activ_0: swish
final_activation: linear
optimizer: rmsprop
use_lr_schedule: False
loss: mae
temp_filters: 32
temp_kernel: 3
temp_dropout: 0.1
dropout_2: 0.1
dropout_3: 0.4
dim_1: 64
mlp_dropout_1: 0.2
mlp_activ_1: gelu
dropout_4: 0.30000000000000004
dim_2: 128
mlp_dropout_2: 0.2
mlp_activ_2: swish
dropout_5: 0.2
"""
# Out:
# '\nThe hyperparameter search is complete. Here are the optimal values:\nhead_size: 32\nnum_heads: 6\nff_dim: 64\nnum_blocks: 3\nmlp_units: 3\nlearning_rate: 0.001\nuse_causal_mask: False\nuse_temp_conv: True\npos_encoding: sinusoidal\ndropout_0: 0.4\ndropout_1: 0.2\naggregation: mean\ndim_0: 128\nmlp_dropout_0: 0.1\nmlp_activ_0: swish\nfinal_activation: linear\noptimizer: rmsprop\nuse_lr_schedule: False\nloss: mae\ntemp_filters: 32\ntemp_kernel: 3\ntemp_dropout: 0.1\ndropout_2: 0.1\ndropout_3: 0.4\ndim_1: 64\nmlp_dropout_1: 0.2\nmlp_activ_1: gelu\ndropout_4: 0.30000000000000004\ndim_2: 128\nmlp_dropout_2: 0.2\nmlp_activ_2: swish\ndropout_5: 0.2\n'

# %%
# with tpu_strategy.scope():
#         best_hps = tuner.get_best_hyperparameters()[0]
#         print("Optimal hyperparameters for sequential model:")
#         for hp_name in best_hps.values.keys():
#             print(f"{hp_name}: {best_hps.get(hp_name)}")
        
#         # model2 = build_sequential_transformer(best_hps)

# %%
model2 = tuner.get_best_models(num_models=2)[1]

# %%
# Final training with best hyperparameters
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=25, 
        restore_best_weights=True, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.7, 
        patience=5, 
        min_lr=1e-8, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'checkpoints/best_sequential_model.weights.h5', 
        save_best_only=True, 
        save_weights_only=True, 
        monitor='val_loss'
    )
]

history = model2.fit(
    train_gen, 
    validation_data=val_gen, 
    epochs=200,
    verbose=1,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - loss: 6.7996 - mean_absolute_error: 6.7996 - mean_squared_error: 92.5118 - val_loss: 10.2887 - val_mean_absolute_error: 10.2887 - val_mean_squared_error: 215.1631 - learning_rate: 0.0010
# Epoch 2/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - loss: 6.7996 - mean_absolute_error: 6.7996 - mean_squared_error: 92.5118 - val_loss: 10.2887 - val_mean_absolute_error: 10.2887 - val_mean_squared_error: 215.1631 - learning_rate: 0.0010
# Epoch 2/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 6.3809 - mean_absolute_error: 6.3809 - mean_squared_error: 80.6364 - val_loss: 7.6620 - val_mean_absolute_error: 7.6620 - val_mean_squared_error: 110.2634 - learning_rate: 0.0010
# Epoch 3/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 6.3809 - mean_absolute_error: 6.3809 - mean_squared_error: 80.6364 - val_loss: 7.6620 - val_mean_absolute_error: 7.6620 - val_mean_squared_error: 110.2634 - learning_rate: 0.0010
# Epoch 3/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.3155 - mean_absolute_error: 6.3155 - mean_squared_error: 78.9438 - val_loss: 8.8186 - val_mean_absolute_error: 8.8186 - val_mean_squared_error: 153.8891 - learning_rate: 0.0010
# Epoch 4/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.3155 - mean_absolute_error: 6.3155 - mean_squared_error: 78.9438 - val_loss: 8.8186 - val_mean_absolute_error: 8.8186 - val_mean_squared_error: 153.8891 - learning_rate: 0.0010
# Epoch 4/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 6.2500 - mean_absolute_error: 6.2500 - mean_squared_error: 77.6113 - val_loss: 7.2412 - val_mean_absolute_error: 7.2412 - val_mean_squared_error: 101.4502 - learning_rate: 0.0010
# Epoch 5/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 6.2500 - mean_absolute_error: 6.2500 - mean_squared_error: 77.6113 - val_loss: 7.2412 - val_mean_absolute_error: 7.2412 - val_mean_squared_error: 101.4502 - learning_rate: 0.0010
# Epoch 5/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.2774 - mean_absolute_error: 6.2774 - mean_squared_error: 78.4158 - val_loss: 7.8706 - val_mean_absolute_error: 7.8706 - val_mean_squared_error: 134.8316 - learning_rate: 0.0010
# Epoch 6/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.2774 - mean_absolute_error: 6.2774 - mean_squared_error: 78.4158 - val_loss: 7.8706 - val_mean_absolute_error: 7.8706 - val_mean_squared_error: 134.8316 - learning_rate: 0.0010
# Epoch 6/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.2358 - mean_absolute_error: 6.2358 - mean_squared_error: 77.4232 - val_loss: 9.2493 - val_mean_absolute_error: 9.2493 - val_mean_squared_error: 163.7596 - learning_rate: 0.0010
# Epoch 7/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.2358 - mean_absolute_error: 6.2358 - mean_squared_error: 77.4232 - val_loss: 9.2493 - val_mean_absolute_error: 9.2493 - val_mean_squared_error: 163.7596 - learning_rate: 0.0010
# Epoch 7/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 6.2314 - mean_absolute_error: 6.2314 - mean_squared_error: 77.2922 - val_loss: 7.1610 - val_mean_absolute_error: 7.1610 - val_mean_squared_error: 104.6602 - learning_rate: 0.0010
# Epoch 8/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 6.2314 - mean_absolute_error: 6.2314 - mean_squared_error: 77.2922 - val_loss: 7.1610 - val_mean_absolute_error: 7.1610 - val_mean_squared_error: 104.6602 - learning_rate: 0.0010
# Epoch 8/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.2366 - mean_absolute_error: 6.2366 - mean_squared_error: 77.4901 - val_loss: 8.7779 - val_mean_absolute_error: 8.7779 - val_mean_squared_error: 156.3656 - learning_rate: 0.0010
# Epoch 9/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.2366 - mean_absolute_error: 6.2366 - mean_squared_error: 77.4901 - val_loss: 8.7779 - val_mean_absolute_error: 8.7779 - val_mean_squared_error: 156.3656 - learning_rate: 0.0010
# Epoch 9/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 6.1886 - mean_absolute_error: 6.1886 - mean_squared_error: 76.4992 - val_loss: 7.3886 - val_mean_absolute_error: 7.3886 - val_mean_squared_error: 117.6400 - learning_rate: 0.0010
# Epoch 10/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 6.1886 - mean_absolute_error: 6.1886 - mean_squared_error: 76.4992 - val_loss: 7.3886 - val_mean_absolute_error: 7.3886 - val_mean_squared_error: 117.6400 - learning_rate: 0.0010
# Epoch 10/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 6.1961 - mean_absolute_error: 6.1961 - mean_squared_error: 76.8468 - val_loss: 8.5835 - val_mean_absolute_error: 8.5835 - val_mean_squared_error: 158.1838 - learning_rate: 0.0010
# Epoch 11/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 6.1961 - mean_absolute_error: 6.1961 - mean_squared_error: 76.8468 - val_loss: 8.5835 - val_mean_absolute_error: 8.5835 - val_mean_squared_error: 158.1838 - learning_rate: 0.0010
# Epoch 11/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.1709 - mean_absolute_error: 6.1709 - mean_squared_error: 75.9848 - val_loss: 10.1076 - val_mean_absolute_error: 10.1076 - val_mean_squared_error: 205.5527 - learning_rate: 0.0010
# Epoch 12/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 6.1709 - mean_absolute_error: 6.1709 - mean_squared_error: 75.9848 - val_loss: 10.1076 - val_mean_absolute_error: 10.1076 - val_mean_squared_error: 205.5527 - learning_rate: 0.0010
# Epoch 12/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 6.1671 - mean_absolute_error: 6.1671 - mean_squared_error: 75.9211 - val_loss: 9.2193 - val_mean_absolute_error: 9.2193 - val_mean_squared_error: 170.3775 - learning_rate: 0.0010
# Epoch 13/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 6.1671 - mean_absolute_error: 6.1671 - mean_squared_error: 75.9211 - val_loss: 9.2193 - val_mean_absolute_error: 9.2193 - val_mean_squared_error: 170.3775 - learning_rate: 0.0010
# Epoch 13/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.9971 - mean_absolute_error: 5.9971 - mean_squared_error: 72.4881 - val_loss: 7.1998 - val_mean_absolute_error: 7.1998 - val_mean_squared_error: 98.2371 - learning_rate: 7.0000e-04
# Epoch 14/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.9971 - mean_absolute_error: 5.9971 - mean_squared_error: 72.4881 - val_loss: 7.1998 - val_mean_absolute_error: 7.1998 - val_mean_squared_error: 98.2371 - learning_rate: 7.0000e-04
# Epoch 14/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.9709 - mean_absolute_error: 5.9709 - mean_squared_error: 71.8105 - val_loss: 7.2663 - val_mean_absolute_error: 7.2663 - val_mean_squared_error: 111.7425 - learning_rate: 7.0000e-04
# Epoch 15/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.9709 - mean_absolute_error: 5.9709 - mean_squared_error: 71.8105 - val_loss: 7.2663 - val_mean_absolute_error: 7.2663 - val_mean_squared_error: 111.7425 - learning_rate: 7.0000e-04
# Epoch 15/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.9730 - mean_absolute_error: 5.9730 - mean_squared_error: 72.0249 - val_loss: 6.5662 - val_mean_absolute_error: 6.5662 - val_mean_squared_error: 93.2339 - learning_rate: 7.0000e-04
# Epoch 16/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.9730 - mean_absolute_error: 5.9730 - mean_squared_error: 72.0249 - val_loss: 6.5662 - val_mean_absolute_error: 6.5662 - val_mean_squared_error: 93.2339 - learning_rate: 7.0000e-04
# Epoch 16/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 5.9625 - mean_absolute_error: 5.9625 - mean_squared_error: 71.8458 - val_loss: 6.4737 - val_mean_absolute_error: 6.4737 - val_mean_squared_error: 87.7007 - learning_rate: 7.0000e-04
# Epoch 17/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 5.9625 - mean_absolute_error: 5.9625 - mean_squared_error: 71.8458 - val_loss: 6.4737 - val_mean_absolute_error: 6.4737 - val_mean_squared_error: 87.7007 - learning_rate: 7.0000e-04
# Epoch 17/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.9502 - mean_absolute_error: 5.9502 - mean_squared_error: 71.6778 - val_loss: 6.0351 - val_mean_absolute_error: 6.0351 - val_mean_squared_error: 75.0885 - learning_rate: 7.0000e-04
# Epoch 18/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.9502 - mean_absolute_error: 5.9502 - mean_squared_error: 71.6778 - val_loss: 6.0351 - val_mean_absolute_error: 6.0351 - val_mean_squared_error: 75.0885 - learning_rate: 7.0000e-04
# Epoch 18/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.9445 - mean_absolute_error: 5.9445 - mean_squared_error: 71.5290 - val_loss: 7.1803 - val_mean_absolute_error: 7.1803 - val_mean_squared_error: 103.4734 - learning_rate: 7.0000e-04
# Epoch 19/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.9445 - mean_absolute_error: 5.9445 - mean_squared_error: 71.5290 - val_loss: 7.1803 - val_mean_absolute_error: 7.1803 - val_mean_squared_error: 103.4734 - learning_rate: 7.0000e-04
# Epoch 19/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.9479 - mean_absolute_error: 5.9479 - mean_squared_error: 71.6997 - val_loss: 6.9736 - val_mean_absolute_error: 6.9736 - val_mean_squared_error: 94.0589 - learning_rate: 7.0000e-04
# Epoch 20/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.9479 - mean_absolute_error: 5.9479 - mean_squared_error: 71.6997 - val_loss: 6.9736 - val_mean_absolute_error: 6.9736 - val_mean_squared_error: 94.0589 - learning_rate: 7.0000e-04
# Epoch 20/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.9274 - mean_absolute_error: 5.9274 - mean_squared_error: 71.2253 - val_loss: 6.6846 - val_mean_absolute_error: 6.6846 - val_mean_squared_error: 97.8520 - learning_rate: 7.0000e-04
# Epoch 21/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.9274 - mean_absolute_error: 5.9274 - mean_squared_error: 71.2253 - val_loss: 6.6846 - val_mean_absolute_error: 6.6846 - val_mean_squared_error: 97.8520 - learning_rate: 7.0000e-04
# Epoch 21/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.9173 - mean_absolute_error: 5.9173 - mean_squared_error: 70.9413 - val_loss: 7.1875 - val_mean_absolute_error: 7.1875 - val_mean_squared_error: 100.8005 - learning_rate: 7.0000e-04
# Epoch 22/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.9173 - mean_absolute_error: 5.9173 - mean_squared_error: 70.9413 - val_loss: 7.1875 - val_mean_absolute_error: 7.1875 - val_mean_squared_error: 100.8005 - learning_rate: 7.0000e-04
# Epoch 22/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.9297 - mean_absolute_error: 5.9297 - mean_squared_error: 71.3853 - val_loss: 6.7538 - val_mean_absolute_error: 6.7538 - val_mean_squared_error: 100.5496 - learning_rate: 7.0000e-04
# Epoch 23/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.9297 - mean_absolute_error: 5.9297 - mean_squared_error: 71.3853 - val_loss: 6.7538 - val_mean_absolute_error: 6.7538 - val_mean_squared_error: 100.5496 - learning_rate: 7.0000e-04
# Epoch 23/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.8266 - mean_absolute_error: 5.8266 - mean_squared_error: 69.2616 - val_loss: 6.2019 - val_mean_absolute_error: 6.2019 - val_mean_squared_error: 88.4200 - learning_rate: 4.9000e-04
# Epoch 24/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.8266 - mean_absolute_error: 5.8266 - mean_squared_error: 69.2616 - val_loss: 6.2019 - val_mean_absolute_error: 6.2019 - val_mean_squared_error: 88.4200 - learning_rate: 4.9000e-04
# Epoch 24/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.8038 - mean_absolute_error: 5.8038 - mean_squared_error: 68.9262 - val_loss: 7.0025 - val_mean_absolute_error: 7.0025 - val_mean_squared_error: 97.2374 - learning_rate: 4.9000e-04
# Epoch 25/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.8038 - mean_absolute_error: 5.8038 - mean_squared_error: 68.9262 - val_loss: 7.0025 - val_mean_absolute_error: 7.0025 - val_mean_squared_error: 97.2374 - learning_rate: 4.9000e-04
# Epoch 25/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.7966 - mean_absolute_error: 5.7966 - mean_squared_error: 68.7177 - val_loss: 6.8929 - val_mean_absolute_error: 6.8929 - val_mean_squared_error: 95.1660 - learning_rate: 4.9000e-04
# Epoch 26/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.7966 - mean_absolute_error: 5.7966 - mean_squared_error: 68.7177 - val_loss: 6.8929 - val_mean_absolute_error: 6.8929 - val_mean_squared_error: 95.1660 - learning_rate: 4.9000e-04
# Epoch 26/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.7821 - mean_absolute_error: 5.7821 - mean_squared_error: 68.6542 - val_loss: 6.6316 - val_mean_absolute_error: 6.6316 - val_mean_squared_error: 86.9728 - learning_rate: 4.9000e-04
# Epoch 27/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.7821 - mean_absolute_error: 5.7821 - mean_squared_error: 68.6542 - val_loss: 6.6316 - val_mean_absolute_error: 6.6316 - val_mean_squared_error: 86.9728 - learning_rate: 4.9000e-04
# Epoch 27/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.7819 - mean_absolute_error: 5.7819 - mean_squared_error: 68.5604 - val_loss: 6.6403 - val_mean_absolute_error: 6.6403 - val_mean_squared_error: 87.2227 - learning_rate: 4.9000e-04
# Epoch 28/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.7819 - mean_absolute_error: 5.7819 - mean_squared_error: 68.5604 - val_loss: 6.6403 - val_mean_absolute_error: 6.6403 - val_mean_squared_error: 87.2227 - learning_rate: 4.9000e-04
# Epoch 28/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.7112 - mean_absolute_error: 5.7112 - mean_squared_error: 67.4289 - val_loss: 5.7219 - val_mean_absolute_error: 5.7219 - val_mean_squared_error: 67.5822 - learning_rate: 3.4300e-04
# Epoch 29/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.7112 - mean_absolute_error: 5.7112 - mean_squared_error: 67.4289 - val_loss: 5.7219 - val_mean_absolute_error: 5.7219 - val_mean_squared_error: 67.5822 - learning_rate: 3.4300e-04
# Epoch 29/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.7105 - mean_absolute_error: 5.7105 - mean_squared_error: 67.4486 - val_loss: 5.6608 - val_mean_absolute_error: 5.6608 - val_mean_squared_error: 70.2648 - learning_rate: 3.4300e-04
# Epoch 30/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.7105 - mean_absolute_error: 5.7105 - mean_squared_error: 67.4486 - val_loss: 5.6608 - val_mean_absolute_error: 5.6608 - val_mean_squared_error: 70.2648 - learning_rate: 3.4300e-04
# Epoch 30/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.6989 - mean_absolute_error: 5.6989 - mean_squared_error: 67.1637 - val_loss: 5.8062 - val_mean_absolute_error: 5.8062 - val_mean_squared_error: 76.9827 - learning_rate: 3.4300e-04
# Epoch 31/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.6989 - mean_absolute_error: 5.6989 - mean_squared_error: 67.1637 - val_loss: 5.8062 - val_mean_absolute_error: 5.8062 - val_mean_squared_error: 76.9827 - learning_rate: 3.4300e-04
# Epoch 31/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.6758 - mean_absolute_error: 5.6758 - mean_squared_error: 66.7762 - val_loss: 5.6870 - val_mean_absolute_error: 5.6870 - val_mean_squared_error: 68.0960 - learning_rate: 3.4300e-04
# Epoch 32/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.6758 - mean_absolute_error: 5.6758 - mean_squared_error: 66.7762 - val_loss: 5.6870 - val_mean_absolute_error: 5.6870 - val_mean_squared_error: 68.0960 - learning_rate: 3.4300e-04
# Epoch 32/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.6811 - mean_absolute_error: 5.6811 - mean_squared_error: 66.9286 - val_loss: 6.2020 - val_mean_absolute_error: 6.2020 - val_mean_squared_error: 79.0889 - learning_rate: 3.4300e-04
# Epoch 33/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.6811 - mean_absolute_error: 5.6811 - mean_squared_error: 66.9286 - val_loss: 6.2020 - val_mean_absolute_error: 6.2020 - val_mean_squared_error: 79.0889 - learning_rate: 3.4300e-04
# Epoch 33/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.6641 - mean_absolute_error: 5.6641 - mean_squared_error: 66.6368 - val_loss: 5.9857 - val_mean_absolute_error: 5.9857 - val_mean_squared_error: 73.6187 - learning_rate: 3.4300e-04
# Epoch 34/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.6641 - mean_absolute_error: 5.6641 - mean_squared_error: 66.6368 - val_loss: 5.9857 - val_mean_absolute_error: 5.9857 - val_mean_squared_error: 73.6187 - learning_rate: 3.4300e-04
# Epoch 34/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.6583 - mean_absolute_error: 5.6583 - mean_squared_error: 66.5732 - val_loss: 5.6928 - val_mean_absolute_error: 5.6928 - val_mean_squared_error: 72.0619 - learning_rate: 3.4300e-04
# Epoch 35/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.6583 - mean_absolute_error: 5.6583 - mean_squared_error: 66.5732 - val_loss: 5.6928 - val_mean_absolute_error: 5.6928 - val_mean_squared_error: 72.0619 - learning_rate: 3.4300e-04
# Epoch 35/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5856 - mean_absolute_error: 5.5856 - mean_squared_error: 64.9729 - val_loss: 5.8131 - val_mean_absolute_error: 5.8131 - val_mean_squared_error: 72.2797 - learning_rate: 2.4010e-04
# Epoch 36/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5856 - mean_absolute_error: 5.5856 - mean_squared_error: 64.9729 - val_loss: 5.8131 - val_mean_absolute_error: 5.8131 - val_mean_squared_error: 72.2797 - learning_rate: 2.4010e-04
# Epoch 36/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.5969 - mean_absolute_error: 5.5969 - mean_squared_error: 65.4182 - val_loss: 5.6928 - val_mean_absolute_error: 5.6928 - val_mean_squared_error: 74.7595 - learning_rate: 2.4010e-04
# Epoch 37/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.5969 - mean_absolute_error: 5.5969 - mean_squared_error: 65.4182 - val_loss: 5.6928 - val_mean_absolute_error: 5.6928 - val_mean_squared_error: 74.7595 - learning_rate: 2.4010e-04
# Epoch 37/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5854 - mean_absolute_error: 5.5854 - mean_squared_error: 65.1430 - val_loss: 5.3386 - val_mean_absolute_error: 5.3386 - val_mean_squared_error: 64.5279 - learning_rate: 2.4010e-04
# Epoch 38/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5854 - mean_absolute_error: 5.5854 - mean_squared_error: 65.1430 - val_loss: 5.3386 - val_mean_absolute_error: 5.3386 - val_mean_squared_error: 64.5279 - learning_rate: 2.4010e-04
# Epoch 38/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.5738 - mean_absolute_error: 5.5738 - mean_squared_error: 65.0461 - val_loss: 5.3554 - val_mean_absolute_error: 5.3554 - val_mean_squared_error: 67.2103 - learning_rate: 2.4010e-04
# Epoch 39/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.5738 - mean_absolute_error: 5.5738 - mean_squared_error: 65.0461 - val_loss: 5.3554 - val_mean_absolute_error: 5.3554 - val_mean_squared_error: 67.2103 - learning_rate: 2.4010e-04
# Epoch 39/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.5809 - mean_absolute_error: 5.5809 - mean_squared_error: 65.1290 - val_loss: 5.3331 - val_mean_absolute_error: 5.3331 - val_mean_squared_error: 62.7610 - learning_rate: 2.4010e-04
# Epoch 40/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 5.5809 - mean_absolute_error: 5.5809 - mean_squared_error: 65.1290 - val_loss: 5.3331 - val_mean_absolute_error: 5.3331 - val_mean_squared_error: 62.7610 - learning_rate: 2.4010e-04
# Epoch 40/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 5.5619 - mean_absolute_error: 5.5619 - mean_squared_error: 64.8205 - val_loss: 5.3843 - val_mean_absolute_error: 5.3843 - val_mean_squared_error: 65.0892 - learning_rate: 2.4010e-04
# Epoch 41/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 5.5619 - mean_absolute_error: 5.5619 - mean_squared_error: 64.8205 - val_loss: 5.3843 - val_mean_absolute_error: 5.3843 - val_mean_squared_error: 65.0892 - learning_rate: 2.4010e-04
# Epoch 41/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.5523 - mean_absolute_error: 5.5523 - mean_squared_error: 64.6938 - val_loss: 5.2717 - val_mean_absolute_error: 5.2717 - val_mean_squared_error: 60.5648 - learning_rate: 2.4010e-04
# Epoch 42/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.5523 - mean_absolute_error: 5.5523 - mean_squared_error: 64.6938 - val_loss: 5.2717 - val_mean_absolute_error: 5.2717 - val_mean_squared_error: 60.5648 - learning_rate: 2.4010e-04
# Epoch 42/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5526 - mean_absolute_error: 5.5526 - mean_squared_error: 64.7297 - val_loss: 5.3838 - val_mean_absolute_error: 5.3838 - val_mean_squared_error: 63.1970 - learning_rate: 2.4010e-04
# Epoch 43/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5526 - mean_absolute_error: 5.5526 - mean_squared_error: 64.7297 - val_loss: 5.3838 - val_mean_absolute_error: 5.3838 - val_mean_squared_error: 63.1970 - learning_rate: 2.4010e-04
# Epoch 43/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5502 - mean_absolute_error: 5.5502 - mean_squared_error: 64.6439 - val_loss: 5.1174 - val_mean_absolute_error: 5.1174 - val_mean_squared_error: 61.6198 - learning_rate: 2.4010e-04
# Epoch 44/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5502 - mean_absolute_error: 5.5502 - mean_squared_error: 64.6439 - val_loss: 5.1174 - val_mean_absolute_error: 5.1174 - val_mean_squared_error: 61.6198 - learning_rate: 2.4010e-04
# Epoch 44/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.5427 - mean_absolute_error: 5.5427 - mean_squared_error: 64.6655 - val_loss: 5.4021 - val_mean_absolute_error: 5.4021 - val_mean_squared_error: 63.3349 - learning_rate: 2.4010e-04
# Epoch 45/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.5427 - mean_absolute_error: 5.5427 - mean_squared_error: 64.6655 - val_loss: 5.4021 - val_mean_absolute_error: 5.4021 - val_mean_squared_error: 63.3349 - learning_rate: 2.4010e-04
# Epoch 45/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5300 - mean_absolute_error: 5.5300 - mean_squared_error: 64.4883 - val_loss: 5.3353 - val_mean_absolute_error: 5.3353 - val_mean_squared_error: 63.2959 - learning_rate: 2.4010e-04
# Epoch 46/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5300 - mean_absolute_error: 5.5300 - mean_squared_error: 64.4883 - val_loss: 5.3353 - val_mean_absolute_error: 5.3353 - val_mean_squared_error: 63.2959 - learning_rate: 2.4010e-04
# Epoch 46/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5199 - mean_absolute_error: 5.5199 - mean_squared_error: 64.2571 - val_loss: 5.3157 - val_mean_absolute_error: 5.3157 - val_mean_squared_error: 64.1060 - learning_rate: 2.4010e-04
# Epoch 47/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5199 - mean_absolute_error: 5.5199 - mean_squared_error: 64.2571 - val_loss: 5.3157 - val_mean_absolute_error: 5.3157 - val_mean_squared_error: 64.1060 - learning_rate: 2.4010e-04
# Epoch 47/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5291 - mean_absolute_error: 5.5291 - mean_squared_error: 64.2613 - val_loss: 5.5151 - val_mean_absolute_error: 5.5151 - val_mean_squared_error: 65.7893 - learning_rate: 2.4010e-04
# Epoch 48/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5291 - mean_absolute_error: 5.5291 - mean_squared_error: 64.2613 - val_loss: 5.5151 - val_mean_absolute_error: 5.5151 - val_mean_squared_error: 65.7893 - learning_rate: 2.4010e-04
# Epoch 48/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5206 - mean_absolute_error: 5.5206 - mean_squared_error: 64.2390 - val_loss: 5.3050 - val_mean_absolute_error: 5.3050 - val_mean_squared_error: 64.0897 - learning_rate: 2.4010e-04
# Epoch 49/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.5206 - mean_absolute_error: 5.5206 - mean_squared_error: 64.2390 - val_loss: 5.3050 - val_mean_absolute_error: 5.3050 - val_mean_squared_error: 64.0897 - learning_rate: 2.4010e-04
# Epoch 49/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.4679 - mean_absolute_error: 5.4679 - mean_squared_error: 63.2123 - val_loss: 5.2184 - val_mean_absolute_error: 5.2184 - val_mean_squared_error: 61.8014 - learning_rate: 1.6807e-04
# Epoch 50/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.4679 - mean_absolute_error: 5.4679 - mean_squared_error: 63.2123 - val_loss: 5.2184 - val_mean_absolute_error: 5.2184 - val_mean_squared_error: 61.8014 - learning_rate: 1.6807e-04
# Epoch 50/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4668 - mean_absolute_error: 5.4668 - mean_squared_error: 63.3084 - val_loss: 5.6787 - val_mean_absolute_error: 5.6787 - val_mean_squared_error: 72.5542 - learning_rate: 1.6807e-04
# Epoch 51/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4668 - mean_absolute_error: 5.4668 - mean_squared_error: 63.3084 - val_loss: 5.6787 - val_mean_absolute_error: 5.6787 - val_mean_squared_error: 72.5542 - learning_rate: 1.6807e-04
# Epoch 51/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4516 - mean_absolute_error: 5.4516 - mean_squared_error: 63.1300 - val_loss: 5.1644 - val_mean_absolute_error: 5.1644 - val_mean_squared_error: 61.2386 - learning_rate: 1.6807e-04
# Epoch 52/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4516 - mean_absolute_error: 5.4516 - mean_squared_error: 63.1300 - val_loss: 5.1644 - val_mean_absolute_error: 5.1644 - val_mean_squared_error: 61.2386 - learning_rate: 1.6807e-04
# Epoch 52/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.4559 - mean_absolute_error: 5.4559 - mean_squared_error: 63.1731 - val_loss: 5.0306 - val_mean_absolute_error: 5.0306 - val_mean_squared_error: 58.0496 - learning_rate: 1.6807e-04
# Epoch 53/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.4559 - mean_absolute_error: 5.4559 - mean_squared_error: 63.1731 - val_loss: 5.0306 - val_mean_absolute_error: 5.0306 - val_mean_squared_error: 58.0496 - learning_rate: 1.6807e-04
# Epoch 53/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4408 - mean_absolute_error: 5.4408 - mean_squared_error: 62.8717 - val_loss: 5.1159 - val_mean_absolute_error: 5.1159 - val_mean_squared_error: 59.1811 - learning_rate: 1.6807e-04
# Epoch 54/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4408 - mean_absolute_error: 5.4408 - mean_squared_error: 62.8717 - val_loss: 5.1159 - val_mean_absolute_error: 5.1159 - val_mean_squared_error: 59.1811 - learning_rate: 1.6807e-04
# Epoch 54/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4442 - mean_absolute_error: 5.4442 - mean_squared_error: 62.8538 - val_loss: 5.2575 - val_mean_absolute_error: 5.2575 - val_mean_squared_error: 60.6692 - learning_rate: 1.6807e-04
# Epoch 55/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4442 - mean_absolute_error: 5.4442 - mean_squared_error: 62.8538 - val_loss: 5.2575 - val_mean_absolute_error: 5.2575 - val_mean_squared_error: 60.6692 - learning_rate: 1.6807e-04
# Epoch 55/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.4447 - mean_absolute_error: 5.4447 - mean_squared_error: 62.9729 - val_loss: 5.1138 - val_mean_absolute_error: 5.1138 - val_mean_squared_error: 60.0713 - learning_rate: 1.6807e-04
# Epoch 56/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.4447 - mean_absolute_error: 5.4447 - mean_squared_error: 62.9729 - val_loss: 5.1138 - val_mean_absolute_error: 5.1138 - val_mean_squared_error: 60.0713 - learning_rate: 1.6807e-04
# Epoch 56/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4345 - mean_absolute_error: 5.4345 - mean_squared_error: 62.7169 - val_loss: 5.6847 - val_mean_absolute_error: 5.6847 - val_mean_squared_error: 69.8487 - learning_rate: 1.6807e-04
# Epoch 57/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4345 - mean_absolute_error: 5.4345 - mean_squared_error: 62.7169 - val_loss: 5.6847 - val_mean_absolute_error: 5.6847 - val_mean_squared_error: 69.8487 - learning_rate: 1.6807e-04
# Epoch 57/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4206 - mean_absolute_error: 5.4206 - mean_squared_error: 62.5875 - val_loss: 5.0356 - val_mean_absolute_error: 5.0356 - val_mean_squared_error: 59.2553 - learning_rate: 1.6807e-04
# Epoch 58/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.4206 - mean_absolute_error: 5.4206 - mean_squared_error: 62.5875 - val_loss: 5.0356 - val_mean_absolute_error: 5.0356 - val_mean_squared_error: 59.2553 - learning_rate: 1.6807e-04
# Epoch 58/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3817 - mean_absolute_error: 5.3817 - mean_squared_error: 61.9253 - val_loss: 5.0692 - val_mean_absolute_error: 5.0692 - val_mean_squared_error: 58.8735 - learning_rate: 1.1765e-04
# Epoch 59/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3817 - mean_absolute_error: 5.3817 - mean_squared_error: 61.9253 - val_loss: 5.0692 - val_mean_absolute_error: 5.0692 - val_mean_squared_error: 58.8735 - learning_rate: 1.1765e-04
# Epoch 59/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3889 - mean_absolute_error: 5.3889 - mean_squared_error: 61.9054 - val_loss: 5.1830 - val_mean_absolute_error: 5.1830 - val_mean_squared_error: 61.0206 - learning_rate: 1.1765e-04
# Epoch 60/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3889 - mean_absolute_error: 5.3889 - mean_squared_error: 61.9054 - val_loss: 5.1830 - val_mean_absolute_error: 5.1830 - val_mean_squared_error: 61.0206 - learning_rate: 1.1765e-04
# Epoch 60/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3776 - mean_absolute_error: 5.3776 - mean_squared_error: 61.6988 - val_loss: 4.8958 - val_mean_absolute_error: 4.8958 - val_mean_squared_error: 55.7068 - learning_rate: 1.1765e-04
# Epoch 61/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3776 - mean_absolute_error: 5.3776 - mean_squared_error: 61.6988 - val_loss: 4.8958 - val_mean_absolute_error: 4.8958 - val_mean_squared_error: 55.7068 - learning_rate: 1.1765e-04
# Epoch 61/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.3663 - mean_absolute_error: 5.3663 - mean_squared_error: 61.5270 - val_loss: 5.0513 - val_mean_absolute_error: 5.0513 - val_mean_squared_error: 60.0802 - learning_rate: 1.1765e-04
# Epoch 62/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.3663 - mean_absolute_error: 5.3663 - mean_squared_error: 61.5270 - val_loss: 5.0513 - val_mean_absolute_error: 5.0513 - val_mean_squared_error: 60.0802 - learning_rate: 1.1765e-04
# Epoch 62/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3780 - mean_absolute_error: 5.3780 - mean_squared_error: 61.8090 - val_loss: 4.9495 - val_mean_absolute_error: 4.9495 - val_mean_squared_error: 57.9174 - learning_rate: 1.1765e-04
# Epoch 63/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3780 - mean_absolute_error: 5.3780 - mean_squared_error: 61.8090 - val_loss: 4.9495 - val_mean_absolute_error: 4.9495 - val_mean_squared_error: 57.9174 - learning_rate: 1.1765e-04
# Epoch 63/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3661 - mean_absolute_error: 5.3661 - mean_squared_error: 61.4988 - val_loss: 5.2063 - val_mean_absolute_error: 5.2063 - val_mean_squared_error: 60.8740 - learning_rate: 1.1765e-04
# Epoch 64/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3661 - mean_absolute_error: 5.3661 - mean_squared_error: 61.4988 - val_loss: 5.2063 - val_mean_absolute_error: 5.2063 - val_mean_squared_error: 60.8740 - learning_rate: 1.1765e-04
# Epoch 64/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3607 - mean_absolute_error: 5.3607 - mean_squared_error: 61.5453 - val_loss: 5.1714 - val_mean_absolute_error: 5.1714 - val_mean_squared_error: 60.1846 - learning_rate: 1.1765e-04
# Epoch 65/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3607 - mean_absolute_error: 5.3607 - mean_squared_error: 61.5453 - val_loss: 5.1714 - val_mean_absolute_error: 5.1714 - val_mean_squared_error: 60.1846 - learning_rate: 1.1765e-04
# Epoch 65/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3540 - mean_absolute_error: 5.3540 - mean_squared_error: 61.3307 - val_loss: 5.1078 - val_mean_absolute_error: 5.1078 - val_mean_squared_error: 59.2213 - learning_rate: 1.1765e-04
# Epoch 66/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3540 - mean_absolute_error: 5.3540 - mean_squared_error: 61.3307 - val_loss: 5.1078 - val_mean_absolute_error: 5.1078 - val_mean_squared_error: 59.2213 - learning_rate: 1.1765e-04
# Epoch 66/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.3405 - mean_absolute_error: 5.3405 - mean_squared_error: 61.1328 - val_loss: 5.0101 - val_mean_absolute_error: 5.0101 - val_mean_squared_error: 58.3063 - learning_rate: 8.2354e-05
# Epoch 67/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.3405 - mean_absolute_error: 5.3405 - mean_squared_error: 61.1328 - val_loss: 5.0101 - val_mean_absolute_error: 5.0101 - val_mean_squared_error: 58.3063 - learning_rate: 8.2354e-05
# Epoch 67/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3296 - mean_absolute_error: 5.3296 - mean_squared_error: 61.0077 - val_loss: 4.9240 - val_mean_absolute_error: 4.9240 - val_mean_squared_error: 57.4363 - learning_rate: 8.2354e-05
# Epoch 68/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3296 - mean_absolute_error: 5.3296 - mean_squared_error: 61.0077 - val_loss: 4.9240 - val_mean_absolute_error: 4.9240 - val_mean_squared_error: 57.4363 - learning_rate: 8.2354e-05
# Epoch 68/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3222 - mean_absolute_error: 5.3222 - mean_squared_error: 60.8786 - val_loss: 4.9654 - val_mean_absolute_error: 4.9654 - val_mean_squared_error: 56.9270 - learning_rate: 8.2354e-05
# Epoch 69/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3222 - mean_absolute_error: 5.3222 - mean_squared_error: 60.8786 - val_loss: 4.9654 - val_mean_absolute_error: 4.9654 - val_mean_squared_error: 56.9270 - learning_rate: 8.2354e-05
# Epoch 69/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.3240 - mean_absolute_error: 5.3240 - mean_squared_error: 60.7520 - val_loss: 4.8328 - val_mean_absolute_error: 4.8328 - val_mean_squared_error: 54.3424 - learning_rate: 8.2354e-05
# Epoch 70/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.3240 - mean_absolute_error: 5.3240 - mean_squared_error: 60.7520 - val_loss: 4.8328 - val_mean_absolute_error: 4.8328 - val_mean_squared_error: 54.3424 - learning_rate: 8.2354e-05
# Epoch 70/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3099 - mean_absolute_error: 5.3099 - mean_squared_error: 60.5840 - val_loss: 4.8893 - val_mean_absolute_error: 4.8893 - val_mean_squared_error: 57.1221 - learning_rate: 8.2354e-05
# Epoch 71/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3099 - mean_absolute_error: 5.3099 - mean_squared_error: 60.5840 - val_loss: 4.8893 - val_mean_absolute_error: 4.8893 - val_mean_squared_error: 57.1221 - learning_rate: 8.2354e-05
# Epoch 71/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3120 - mean_absolute_error: 5.3120 - mean_squared_error: 60.6481 - val_loss: 4.9257 - val_mean_absolute_error: 4.9257 - val_mean_squared_error: 58.2568 - learning_rate: 8.2354e-05
# Epoch 72/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3120 - mean_absolute_error: 5.3120 - mean_squared_error: 60.6481 - val_loss: 4.9257 - val_mean_absolute_error: 4.9257 - val_mean_squared_error: 58.2568 - learning_rate: 8.2354e-05
# Epoch 72/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.3111 - mean_absolute_error: 5.3111 - mean_squared_error: 60.7244 - val_loss: 4.8564 - val_mean_absolute_error: 4.8564 - val_mean_squared_error: 55.1199 - learning_rate: 8.2354e-05
# Epoch 73/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.3111 - mean_absolute_error: 5.3111 - mean_squared_error: 60.7244 - val_loss: 4.8564 - val_mean_absolute_error: 4.8564 - val_mean_squared_error: 55.1199 - learning_rate: 8.2354e-05
# Epoch 73/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3118 - mean_absolute_error: 5.3118 - mean_squared_error: 60.6305 - val_loss: 4.8375 - val_mean_absolute_error: 4.8375 - val_mean_squared_error: 55.2011 - learning_rate: 8.2354e-05
# Epoch 74/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.3118 - mean_absolute_error: 5.3118 - mean_squared_error: 60.6305 - val_loss: 4.8375 - val_mean_absolute_error: 4.8375 - val_mean_squared_error: 55.2011 - learning_rate: 8.2354e-05
# Epoch 74/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.3103 - mean_absolute_error: 5.3103 - mean_squared_error: 60.6316 - val_loss: 4.8322 - val_mean_absolute_error: 4.8322 - val_mean_squared_error: 54.1308 - learning_rate: 8.2354e-05
# Epoch 75/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.3103 - mean_absolute_error: 5.3103 - mean_squared_error: 60.6316 - val_loss: 4.8322 - val_mean_absolute_error: 4.8322 - val_mean_squared_error: 54.1308 - learning_rate: 8.2354e-05
# Epoch 75/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2989 - mean_absolute_error: 5.2989 - mean_squared_error: 60.5865 - val_loss: 4.8487 - val_mean_absolute_error: 4.8487 - val_mean_squared_error: 57.0110 - learning_rate: 8.2354e-05
# Epoch 76/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2989 - mean_absolute_error: 5.2989 - mean_squared_error: 60.5865 - val_loss: 4.8487 - val_mean_absolute_error: 4.8487 - val_mean_squared_error: 57.0110 - learning_rate: 8.2354e-05
# Epoch 76/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.3006 - mean_absolute_error: 5.3006 - mean_squared_error: 60.5720 - val_loss: 4.8261 - val_mean_absolute_error: 4.8261 - val_mean_squared_error: 56.3858 - learning_rate: 8.2354e-05
# Epoch 77/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.3006 - mean_absolute_error: 5.3006 - mean_squared_error: 60.5720 - val_loss: 4.8261 - val_mean_absolute_error: 4.8261 - val_mean_squared_error: 56.3858 - learning_rate: 8.2354e-05
# Epoch 77/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 5.3058 - mean_absolute_error: 5.3058 - mean_squared_error: 60.6006 - val_loss: 4.8193 - val_mean_absolute_error: 4.8193 - val_mean_squared_error: 55.4511 - learning_rate: 8.2354e-05
# Epoch 78/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 5.3058 - mean_absolute_error: 5.3058 - mean_squared_error: 60.6006 - val_loss: 4.8193 - val_mean_absolute_error: 4.8193 - val_mean_squared_error: 55.4511 - learning_rate: 8.2354e-05
# Epoch 78/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2896 - mean_absolute_error: 5.2896 - mean_squared_error: 60.2801 - val_loss: 4.8460 - val_mean_absolute_error: 4.8460 - val_mean_squared_error: 55.9811 - learning_rate: 8.2354e-05
# Epoch 79/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2896 - mean_absolute_error: 5.2896 - mean_squared_error: 60.2801 - val_loss: 4.8460 - val_mean_absolute_error: 4.8460 - val_mean_squared_error: 55.9811 - learning_rate: 8.2354e-05
# Epoch 79/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2989 - mean_absolute_error: 5.2989 - mean_squared_error: 60.4582 - val_loss: 4.8496 - val_mean_absolute_error: 4.8496 - val_mean_squared_error: 54.7639 - learning_rate: 8.2354e-05
# Epoch 80/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2989 - mean_absolute_error: 5.2989 - mean_squared_error: 60.4582 - val_loss: 4.8496 - val_mean_absolute_error: 4.8496 - val_mean_squared_error: 54.7639 - learning_rate: 8.2354e-05
# Epoch 80/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.2974 - mean_absolute_error: 5.2974 - mean_squared_error: 60.4672 - val_loss: 4.7603 - val_mean_absolute_error: 4.7603 - val_mean_squared_error: 54.3614 - learning_rate: 8.2354e-05
# Epoch 81/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.2974 - mean_absolute_error: 5.2974 - mean_squared_error: 60.4672 - val_loss: 4.7603 - val_mean_absolute_error: 4.7603 - val_mean_squared_error: 54.3614 - learning_rate: 8.2354e-05
# Epoch 81/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.2854 - mean_absolute_error: 5.2854 - mean_squared_error: 60.1955 - val_loss: 4.7019 - val_mean_absolute_error: 4.7019 - val_mean_squared_error: 52.9354 - learning_rate: 8.2354e-05
# Epoch 82/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.2854 - mean_absolute_error: 5.2854 - mean_squared_error: 60.1955 - val_loss: 4.7019 - val_mean_absolute_error: 4.7019 - val_mean_squared_error: 52.9354 - learning_rate: 8.2354e-05
# Epoch 82/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2779 - mean_absolute_error: 5.2779 - mean_squared_error: 60.0468 - val_loss: 4.8600 - val_mean_absolute_error: 4.8600 - val_mean_squared_error: 55.6775 - learning_rate: 8.2354e-05
# Epoch 83/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2779 - mean_absolute_error: 5.2779 - mean_squared_error: 60.0468 - val_loss: 4.8600 - val_mean_absolute_error: 4.8600 - val_mean_squared_error: 55.6775 - learning_rate: 8.2354e-05
# Epoch 83/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.2943 - mean_absolute_error: 5.2943 - mean_squared_error: 60.4232 - val_loss: 4.7295 - val_mean_absolute_error: 4.7295 - val_mean_squared_error: 53.1660 - learning_rate: 8.2354e-05
# Epoch 84/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.2943 - mean_absolute_error: 5.2943 - mean_squared_error: 60.4232 - val_loss: 4.7295 - val_mean_absolute_error: 4.7295 - val_mean_squared_error: 53.1660 - learning_rate: 8.2354e-05
# Epoch 84/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2863 - mean_absolute_error: 5.2863 - mean_squared_error: 60.2408 - val_loss: 4.7749 - val_mean_absolute_error: 4.7749 - val_mean_squared_error: 54.0734 - learning_rate: 8.2354e-05
# Epoch 85/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2863 - mean_absolute_error: 5.2863 - mean_squared_error: 60.2408 - val_loss: 4.7749 - val_mean_absolute_error: 4.7749 - val_mean_squared_error: 54.0734 - learning_rate: 8.2354e-05
# Epoch 85/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2764 - mean_absolute_error: 5.2764 - mean_squared_error: 60.1924 - val_loss: 4.8390 - val_mean_absolute_error: 4.8390 - val_mean_squared_error: 55.4150 - learning_rate: 8.2354e-05
# Epoch 86/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2764 - mean_absolute_error: 5.2764 - mean_squared_error: 60.1924 - val_loss: 4.8390 - val_mean_absolute_error: 4.8390 - val_mean_squared_error: 55.4150 - learning_rate: 8.2354e-05
# Epoch 86/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2798 - mean_absolute_error: 5.2798 - mean_squared_error: 60.2263 - val_loss: 4.8026 - val_mean_absolute_error: 4.8026 - val_mean_squared_error: 54.5090 - learning_rate: 8.2354e-05
# Epoch 87/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2798 - mean_absolute_error: 5.2798 - mean_squared_error: 60.2263 - val_loss: 4.8026 - val_mean_absolute_error: 4.8026 - val_mean_squared_error: 54.5090 - learning_rate: 8.2354e-05
# Epoch 87/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2557 - mean_absolute_error: 5.2557 - mean_squared_error: 59.6241 - val_loss: 4.7625 - val_mean_absolute_error: 4.7625 - val_mean_squared_error: 54.0211 - learning_rate: 5.7648e-05
# Epoch 88/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2557 - mean_absolute_error: 5.2557 - mean_squared_error: 59.6241 - val_loss: 4.7625 - val_mean_absolute_error: 4.7625 - val_mean_squared_error: 54.0211 - learning_rate: 5.7648e-05
# Epoch 88/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.2513 - mean_absolute_error: 5.2513 - mean_squared_error: 59.6748 - val_loss: 4.8371 - val_mean_absolute_error: 4.8371 - val_mean_squared_error: 56.0096 - learning_rate: 5.7648e-05
# Epoch 89/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.2513 - mean_absolute_error: 5.2513 - mean_squared_error: 59.6748 - val_loss: 4.8371 - val_mean_absolute_error: 4.8371 - val_mean_squared_error: 56.0096 - learning_rate: 5.7648e-05
# Epoch 89/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2493 - mean_absolute_error: 5.2493 - mean_squared_error: 59.7018 - val_loss: 4.8332 - val_mean_absolute_error: 4.8332 - val_mean_squared_error: 55.1854 - learning_rate: 5.7648e-05
# Epoch 90/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2493 - mean_absolute_error: 5.2493 - mean_squared_error: 59.7018 - val_loss: 4.8332 - val_mean_absolute_error: 4.8332 - val_mean_squared_error: 55.1854 - learning_rate: 5.7648e-05
# Epoch 90/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2551 - mean_absolute_error: 5.2551 - mean_squared_error: 59.7019 - val_loss: 4.7936 - val_mean_absolute_error: 4.7936 - val_mean_squared_error: 54.8723 - learning_rate: 5.7648e-05
# Epoch 91/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2551 - mean_absolute_error: 5.2551 - mean_squared_error: 59.7019 - val_loss: 4.7936 - val_mean_absolute_error: 4.7936 - val_mean_squared_error: 54.8723 - learning_rate: 5.7648e-05
# Epoch 91/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2382 - mean_absolute_error: 5.2382 - mean_squared_error: 59.4748 - val_loss: 4.8542 - val_mean_absolute_error: 4.8542 - val_mean_squared_error: 55.5787 - learning_rate: 5.7648e-05
# Epoch 92/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2382 - mean_absolute_error: 5.2382 - mean_squared_error: 59.4748 - val_loss: 4.8542 - val_mean_absolute_error: 4.8542 - val_mean_squared_error: 55.5787 - learning_rate: 5.7648e-05
# Epoch 92/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2274 - mean_absolute_error: 5.2274 - mean_squared_error: 59.2321 - val_loss: 4.7707 - val_mean_absolute_error: 4.7707 - val_mean_squared_error: 54.4002 - learning_rate: 4.0354e-05
# Epoch 93/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2274 - mean_absolute_error: 5.2274 - mean_squared_error: 59.2321 - val_loss: 4.7707 - val_mean_absolute_error: 4.7707 - val_mean_squared_error: 54.4002 - learning_rate: 4.0354e-05
# Epoch 93/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2234 - mean_absolute_error: 5.2234 - mean_squared_error: 59.2313 - val_loss: 4.8108 - val_mean_absolute_error: 4.8108 - val_mean_squared_error: 56.2408 - learning_rate: 4.0354e-05
# Epoch 94/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2234 - mean_absolute_error: 5.2234 - mean_squared_error: 59.2313 - val_loss: 4.8108 - val_mean_absolute_error: 4.8108 - val_mean_squared_error: 56.2408 - learning_rate: 4.0354e-05
# Epoch 94/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.2156 - mean_absolute_error: 5.2156 - mean_squared_error: 58.9560 - val_loss: 4.7960 - val_mean_absolute_error: 4.7960 - val_mean_squared_error: 56.0975 - learning_rate: 4.0354e-05
# Epoch 95/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.2156 - mean_absolute_error: 5.2156 - mean_squared_error: 58.9560 - val_loss: 4.7960 - val_mean_absolute_error: 4.7960 - val_mean_squared_error: 56.0975 - learning_rate: 4.0354e-05
# Epoch 95/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2251 - mean_absolute_error: 5.2251 - mean_squared_error: 59.2011 - val_loss: 4.7053 - val_mean_absolute_error: 4.7053 - val_mean_squared_error: 53.9116 - learning_rate: 4.0354e-05
# Epoch 96/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2251 - mean_absolute_error: 5.2251 - mean_squared_error: 59.2011 - val_loss: 4.7053 - val_mean_absolute_error: 4.7053 - val_mean_squared_error: 53.9116 - learning_rate: 4.0354e-05
# Epoch 96/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.2234 - mean_absolute_error: 5.2234 - mean_squared_error: 59.2078 - val_loss: 4.7231 - val_mean_absolute_error: 4.7231 - val_mean_squared_error: 53.6899 - learning_rate: 4.0354e-05
# Epoch 97/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.2234 - mean_absolute_error: 5.2234 - mean_squared_error: 59.2078 - val_loss: 4.7231 - val_mean_absolute_error: 4.7231 - val_mean_squared_error: 53.6899 - learning_rate: 4.0354e-05
# Epoch 97/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2183 - mean_absolute_error: 5.2183 - mean_squared_error: 59.1567 - val_loss: 4.7876 - val_mean_absolute_error: 4.7876 - val_mean_squared_error: 54.8995 - learning_rate: 2.8248e-05
# Epoch 98/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2183 - mean_absolute_error: 5.2183 - mean_squared_error: 59.1567 - val_loss: 4.7876 - val_mean_absolute_error: 4.7876 - val_mean_squared_error: 54.8995 - learning_rate: 2.8248e-05
# Epoch 98/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2073 - mean_absolute_error: 5.2073 - mean_squared_error: 59.0009 - val_loss: 4.7278 - val_mean_absolute_error: 4.7278 - val_mean_squared_error: 54.4447 - learning_rate: 2.8248e-05
# Epoch 99/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.2073 - mean_absolute_error: 5.2073 - mean_squared_error: 59.0009 - val_loss: 4.7278 - val_mean_absolute_error: 4.7278 - val_mean_squared_error: 54.4447 - learning_rate: 2.8248e-05
# Epoch 99/200
# ...
# Epoch 143/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1701 - mean_absolute_error: 5.1701 - mean_squared_error: 58.4491 - val_loss: 4.6591 - val_mean_absolute_error: 4.6591 - val_mean_squared_error: 53.3673 - learning_rate: 3.3233e-06
# Epoch 143/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1622 - mean_absolute_error: 5.1622 - mean_squared_error: 58.2183 - val_loss: 4.6403 - val_mean_absolute_error: 4.6403 - val_mean_squared_error: 53.1000 - learning_rate: 2.3263e-06
# Epoch 144/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1622 - mean_absolute_error: 5.1622 - mean_squared_error: 58.2183 - val_loss: 4.6403 - val_mean_absolute_error: 4.6403 - val_mean_squared_error: 53.1000 - learning_rate: 2.3263e-06
# Epoch 144/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.1600 - mean_absolute_error: 5.1600 - mean_squared_error: 58.1899 - val_loss: 4.6353 - val_mean_absolute_error: 4.6353 - val_mean_squared_error: 53.3191 - learning_rate: 2.3263e-06
# Epoch 145/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.1600 - mean_absolute_error: 5.1600 - mean_squared_error: 58.1899 - val_loss: 4.6353 - val_mean_absolute_error: 4.6353 - val_mean_squared_error: 53.3191 - learning_rate: 2.3263e-06
# Epoch 145/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.1760 - mean_absolute_error: 5.1760 - mean_squared_error: 58.4960 - val_loss: 4.6471 - val_mean_absolute_error: 4.6471 - val_mean_squared_error: 53.1200 - learning_rate: 2.3263e-06
# Epoch 146/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.1760 - mean_absolute_error: 5.1760 - mean_squared_error: 58.4960 - val_loss: 4.6471 - val_mean_absolute_error: 4.6471 - val_mean_squared_error: 53.1200 - learning_rate: 2.3263e-06
# Epoch 146/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1771 - mean_absolute_error: 5.1771 - mean_squared_error: 58.5467 - val_loss: 4.6438 - val_mean_absolute_error: 4.6438 - val_mean_squared_error: 53.0027 - learning_rate: 2.3263e-06
# Epoch 147/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1771 - mean_absolute_error: 5.1771 - mean_squared_error: 58.5467 - val_loss: 4.6438 - val_mean_absolute_error: 4.6438 - val_mean_squared_error: 53.0027 - learning_rate: 2.3263e-06
# Epoch 147/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1662 - mean_absolute_error: 5.1662 - mean_squared_error: 58.4413 - val_loss: 4.6456 - val_mean_absolute_error: 4.6456 - val_mean_squared_error: 53.2185 - learning_rate: 2.3263e-06
# Epoch 148/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1662 - mean_absolute_error: 5.1662 - mean_squared_error: 58.4413 - val_loss: 4.6456 - val_mean_absolute_error: 4.6456 - val_mean_squared_error: 53.2185 - learning_rate: 2.3263e-06
# Epoch 148/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1623 - mean_absolute_error: 5.1623 - mean_squared_error: 58.1712 - val_loss: 4.6411 - val_mean_absolute_error: 4.6411 - val_mean_squared_error: 52.9524 - learning_rate: 2.3263e-06
# Epoch 149/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1623 - mean_absolute_error: 5.1623 - mean_squared_error: 58.1712 - val_loss: 4.6411 - val_mean_absolute_error: 4.6411 - val_mean_squared_error: 52.9524 - learning_rate: 2.3263e-06
# Epoch 149/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.1608 - mean_absolute_error: 5.1608 - mean_squared_error: 58.2322 - val_loss: 4.6338 - val_mean_absolute_error: 4.6338 - val_mean_squared_error: 52.9827 - learning_rate: 2.3263e-06
# Epoch 150/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 5.1608 - mean_absolute_error: 5.1608 - mean_squared_error: 58.2322 - val_loss: 4.6338 - val_mean_absolute_error: 4.6338 - val_mean_squared_error: 52.9827 - learning_rate: 2.3263e-06
# Epoch 150/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.1712 - mean_absolute_error: 5.1712 - mean_squared_error: 58.5244 - val_loss: 4.6401 - val_mean_absolute_error: 4.6401 - val_mean_squared_error: 53.0674 - learning_rate: 2.3263e-06
# Epoch 151/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.1712 - mean_absolute_error: 5.1712 - mean_squared_error: 58.5244 - val_loss: 4.6401 - val_mean_absolute_error: 4.6401 - val_mean_squared_error: 53.0674 - learning_rate: 2.3263e-06
# Epoch 151/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1666 - mean_absolute_error: 5.1666 - mean_squared_error: 58.3068 - val_loss: 4.6408 - val_mean_absolute_error: 4.6408 - val_mean_squared_error: 53.1087 - learning_rate: 2.3263e-06
# Epoch 152/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1666 - mean_absolute_error: 5.1666 - mean_squared_error: 58.3068 - val_loss: 4.6408 - val_mean_absolute_error: 4.6408 - val_mean_squared_error: 53.1087 - learning_rate: 2.3263e-06
# Epoch 152/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1694 - mean_absolute_error: 5.1694 - mean_squared_error: 58.3410 - val_loss: 4.6397 - val_mean_absolute_error: 4.6397 - val_mean_squared_error: 53.1368 - learning_rate: 2.3263e-06
# Epoch 153/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1694 - mean_absolute_error: 5.1694 - mean_squared_error: 58.3410 - val_loss: 4.6397 - val_mean_absolute_error: 4.6397 - val_mean_squared_error: 53.1368 - learning_rate: 2.3263e-06
# Epoch 153/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1716 - mean_absolute_error: 5.1716 - mean_squared_error: 58.3041 - val_loss: 4.6476 - val_mean_absolute_error: 4.6476 - val_mean_squared_error: 53.0966 - learning_rate: 2.3263e-06
# Epoch 154/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1716 - mean_absolute_error: 5.1716 - mean_squared_error: 58.3041 - val_loss: 4.6476 - val_mean_absolute_error: 4.6476 - val_mean_squared_error: 53.0966 - learning_rate: 2.3263e-06
# Epoch 154/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1624 - mean_absolute_error: 5.1624 - mean_squared_error: 58.2842 - val_loss: 4.6490 - val_mean_absolute_error: 4.6490 - val_mean_squared_error: 53.1335 - learning_rate: 2.3263e-06
# Epoch 155/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1624 - mean_absolute_error: 5.1624 - mean_squared_error: 58.2842 - val_loss: 4.6490 - val_mean_absolute_error: 4.6490 - val_mean_squared_error: 53.1335 - learning_rate: 2.3263e-06
# Epoch 155/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1736 - mean_absolute_error: 5.1736 - mean_squared_error: 58.4125 - val_loss: 4.6399 - val_mean_absolute_error: 4.6399 - val_mean_squared_error: 53.0756 - learning_rate: 1.6284e-06
# Epoch 156/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1736 - mean_absolute_error: 5.1736 - mean_squared_error: 58.4125 - val_loss: 4.6399 - val_mean_absolute_error: 4.6399 - val_mean_squared_error: 53.0756 - learning_rate: 1.6284e-06
# Epoch 156/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.1727 - mean_absolute_error: 5.1727 - mean_squared_error: 58.3513 - val_loss: 4.6404 - val_mean_absolute_error: 4.6404 - val_mean_squared_error: 52.9886 - learning_rate: 1.6284e-06
# Epoch 157/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.1727 - mean_absolute_error: 5.1727 - mean_squared_error: 58.3513 - val_loss: 4.6404 - val_mean_absolute_error: 4.6404 - val_mean_squared_error: 52.9886 - learning_rate: 1.6284e-06
# Epoch 157/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1691 - mean_absolute_error: 5.1691 - mean_squared_error: 58.3393 - val_loss: 4.6426 - val_mean_absolute_error: 4.6426 - val_mean_squared_error: 53.0800 - learning_rate: 1.6284e-06
# Epoch 158/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1691 - mean_absolute_error: 5.1691 - mean_squared_error: 58.3393 - val_loss: 4.6426 - val_mean_absolute_error: 4.6426 - val_mean_squared_error: 53.0800 - learning_rate: 1.6284e-06
# Epoch 158/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1637 - mean_absolute_error: 5.1637 - mean_squared_error: 58.2949 - val_loss: 4.6486 - val_mean_absolute_error: 4.6486 - val_mean_squared_error: 53.1459 - learning_rate: 1.6284e-06
# Epoch 159/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1637 - mean_absolute_error: 5.1637 - mean_squared_error: 58.2949 - val_loss: 4.6486 - val_mean_absolute_error: 4.6486 - val_mean_squared_error: 53.1459 - learning_rate: 1.6284e-06
# Epoch 159/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1621 - mean_absolute_error: 5.1621 - mean_squared_error: 58.2058 - val_loss: 4.6393 - val_mean_absolute_error: 4.6393 - val_mean_squared_error: 53.0735 - learning_rate: 1.6284e-06
# Epoch 160/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1621 - mean_absolute_error: 5.1621 - mean_squared_error: 58.2058 - val_loss: 4.6393 - val_mean_absolute_error: 4.6393 - val_mean_squared_error: 53.0735 - learning_rate: 1.6284e-06
# Epoch 160/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1612 - mean_absolute_error: 5.1612 - mean_squared_error: 58.2425 - val_loss: 4.6424 - val_mean_absolute_error: 4.6424 - val_mean_squared_error: 53.1472 - learning_rate: 1.1399e-06
# Epoch 161/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1612 - mean_absolute_error: 5.1612 - mean_squared_error: 58.2425 - val_loss: 4.6424 - val_mean_absolute_error: 4.6424 - val_mean_squared_error: 53.1472 - learning_rate: 1.1399e-06
# Epoch 161/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.1623 - mean_absolute_error: 5.1623 - mean_squared_error: 58.1124 - val_loss: 4.6406 - val_mean_absolute_error: 4.6406 - val_mean_squared_error: 52.9945 - learning_rate: 1.1399e-06
# Epoch 162/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.1623 - mean_absolute_error: 5.1623 - mean_squared_error: 58.1124 - val_loss: 4.6406 - val_mean_absolute_error: 4.6406 - val_mean_squared_error: 52.9945 - learning_rate: 1.1399e-06
# Epoch 162/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1638 - mean_absolute_error: 5.1638 - mean_squared_error: 58.1643 - val_loss: 4.6415 - val_mean_absolute_error: 4.6415 - val_mean_squared_error: 52.9961 - learning_rate: 1.1399e-06
# Epoch 163/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1638 - mean_absolute_error: 5.1638 - mean_squared_error: 58.1643 - val_loss: 4.6415 - val_mean_absolute_error: 4.6415 - val_mean_squared_error: 52.9961 - learning_rate: 1.1399e-06
# Epoch 163/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1702 - mean_absolute_error: 5.1702 - mean_squared_error: 58.3818 - val_loss: 4.6399 - val_mean_absolute_error: 4.6399 - val_mean_squared_error: 53.0847 - learning_rate: 1.1399e-06
# Epoch 164/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1702 - mean_absolute_error: 5.1702 - mean_squared_error: 58.3818 - val_loss: 4.6399 - val_mean_absolute_error: 4.6399 - val_mean_squared_error: 53.0847 - learning_rate: 1.1399e-06
# Epoch 164/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1571 - mean_absolute_error: 5.1571 - mean_squared_error: 58.0835 - val_loss: 4.6399 - val_mean_absolute_error: 4.6399 - val_mean_squared_error: 53.0419 - learning_rate: 1.1399e-06
# Epoch 165/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1571 - mean_absolute_error: 5.1571 - mean_squared_error: 58.0835 - val_loss: 4.6399 - val_mean_absolute_error: 4.6399 - val_mean_squared_error: 53.0419 - learning_rate: 1.1399e-06
# Epoch 165/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1595 - mean_absolute_error: 5.1595 - mean_squared_error: 58.2795 - val_loss: 4.6407 - val_mean_absolute_error: 4.6407 - val_mean_squared_error: 53.0170 - learning_rate: 7.9792e-07
# Epoch 166/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1595 - mean_absolute_error: 5.1595 - mean_squared_error: 58.2795 - val_loss: 4.6407 - val_mean_absolute_error: 4.6407 - val_mean_squared_error: 53.0170 - learning_rate: 7.9792e-07
# Epoch 166/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1546 - mean_absolute_error: 5.1546 - mean_squared_error: 58.0037 - val_loss: 4.6427 - val_mean_absolute_error: 4.6427 - val_mean_squared_error: 53.0891 - learning_rate: 7.9792e-07
# Epoch 167/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1546 - mean_absolute_error: 5.1546 - mean_squared_error: 58.0037 - val_loss: 4.6427 - val_mean_absolute_error: 4.6427 - val_mean_squared_error: 53.0891 - learning_rate: 7.9792e-07
# Epoch 167/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.1626 - mean_absolute_error: 5.1626 - mean_squared_error: 58.2267 - val_loss: 4.6404 - val_mean_absolute_error: 4.6404 - val_mean_squared_error: 53.1174 - learning_rate: 7.9792e-07
# Epoch 168/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 5.1626 - mean_absolute_error: 5.1626 - mean_squared_error: 58.2267 - val_loss: 4.6404 - val_mean_absolute_error: 4.6404 - val_mean_squared_error: 53.1174 - learning_rate: 7.9792e-07
# Epoch 168/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1637 - mean_absolute_error: 5.1637 - mean_squared_error: 58.1725 - val_loss: 4.6430 - val_mean_absolute_error: 4.6430 - val_mean_squared_error: 53.1633 - learning_rate: 7.9792e-07
# Epoch 169/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1637 - mean_absolute_error: 5.1637 - mean_squared_error: 58.1725 - val_loss: 4.6430 - val_mean_absolute_error: 4.6430 - val_mean_squared_error: 53.1633 - learning_rate: 7.9792e-07
# Epoch 169/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1668 - mean_absolute_error: 5.1668 - mean_squared_error: 58.3325 - val_loss: 4.6378 - val_mean_absolute_error: 4.6378 - val_mean_squared_error: 52.9457 - learning_rate: 7.9792e-07
# Epoch 170/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1668 - mean_absolute_error: 5.1668 - mean_squared_error: 58.3325 - val_loss: 4.6378 - val_mean_absolute_error: 4.6378 - val_mean_squared_error: 52.9457 - learning_rate: 7.9792e-07
# Epoch 170/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1672 - mean_absolute_error: 5.1672 - mean_squared_error: 58.2828 - val_loss: 4.6374 - val_mean_absolute_error: 4.6374 - val_mean_squared_error: 52.9687 - learning_rate: 5.5855e-07
# Epoch 171/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1672 - mean_absolute_error: 5.1672 - mean_squared_error: 58.2828 - val_loss: 4.6374 - val_mean_absolute_error: 4.6374 - val_mean_squared_error: 52.9687 - learning_rate: 5.5855e-07
# Epoch 171/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1639 - mean_absolute_error: 5.1639 - mean_squared_error: 58.3466 - val_loss: 4.6373 - val_mean_absolute_error: 4.6373 - val_mean_squared_error: 52.9397 - learning_rate: 5.5855e-07
# Epoch 172/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1639 - mean_absolute_error: 5.1639 - mean_squared_error: 58.3466 - val_loss: 4.6373 - val_mean_absolute_error: 4.6373 - val_mean_squared_error: 52.9397 - learning_rate: 5.5855e-07
# Epoch 172/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1679 - mean_absolute_error: 5.1679 - mean_squared_error: 58.4161 - val_loss: 4.6371 - val_mean_absolute_error: 4.6371 - val_mean_squared_error: 52.9713 - learning_rate: 5.5855e-07
# Epoch 173/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1679 - mean_absolute_error: 5.1679 - mean_squared_error: 58.4161 - val_loss: 4.6371 - val_mean_absolute_error: 4.6371 - val_mean_squared_error: 52.9713 - learning_rate: 5.5855e-07
# Epoch 173/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.1580 - mean_absolute_error: 5.1580 - mean_squared_error: 58.3253 - val_loss: 4.6383 - val_mean_absolute_error: 4.6383 - val_mean_squared_error: 52.9336 - learning_rate: 5.5855e-07
# Epoch 174/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 5.1580 - mean_absolute_error: 5.1580 - mean_squared_error: 58.3253 - val_loss: 4.6383 - val_mean_absolute_error: 4.6383 - val_mean_squared_error: 52.9336 - learning_rate: 5.5855e-07
# Epoch 174/200
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1566 - mean_absolute_error: 5.1566 - mean_squared_error: 58.1407 - val_loss: 4.6409 - val_mean_absolute_error: 4.6409 - val_mean_squared_error: 52.9883 - learning_rate: 5.5855e-07
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 5.1566 - mean_absolute_error: 5.1566 - mean_squared_error: 58.1407 - val_loss: 4.6409 - val_mean_absolute_error: 4.6409 - val_mean_squared_error: 52.9883 - learning_rate: 5.5855e-07

# %%
# model.save('best_3.keras')
# from IPython.display import FileLink
# FileLink(r'best_3.keras')

# %%
model_path = "./models/best_DS03_copy.keras"
best_model = model2
best_model.save(model_path)

# %%
from tensorflow.keras.utils import plot_model
# Plot the model and save it as an image
# plot_model(best_model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

# %%
# %%
# Cell 28: Evaluation Metrics Functions
def score_metric_fn(y_true, y_pred):
    """
    NASA's scoring function for RUL prediction.
    Score = (1/t) * sum(exp(alpha * |Y_pred - Y_true|) - 1)
    where alpha = 1/13 for late predictions (underprediction) 
    and alpha = 1/10 for early predictions (overprediction)
    """
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    diff = y_pred - y_true
    alpha = np.where(diff < 0, 1/13, 1/10)  # 1/13 for late, 1/10 for early
    score = np.mean(np.exp(alpha * np.abs(diff)) - 1)
    return score
from sklearn.metrics import mean_squared_error, mean_absolute_error

def calculate_all_metrics(y_true, y_pred, model_name="Model"):
    """Calculate and display all evaluation metrics"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Standard metrics
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    # NASA scoring function
    score = score_metric_fn(y_true, y_pred)
    
    # Additional metrics
    mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100
    r2 = 1 - (np.sum((y_true - y_pred)**2) / np.sum((y_true - np.mean(y_true))**2))
    
    # Print results
    print(f"\n{'='*60}")
    print(f"{model_name} - Evaluation Metrics")
    print(f"{'='*60}")
    print(f"MAE (Mean Absolute Error):        {mae:.4f}")
    print(f"MSE (Mean Squared Error):         {mse:.4f}")
    print(f"RMSE (Root Mean Squared Error):   {rmse:.4f}")
    print(f"NASA Score:                       {score:.4f}")
    print(f"MAPE (Mean Absolute % Error):     {mape:.2f}%")
    print(f"R² Score:                         {r2:.4f}")
    print(f"{'='*60}\n")
    
    return {
        'mae': mae,
        'mse': mse,
        'rmse': rmse,
        'nasa_score': score,
        'mape': mape,
        'r2': r2
    }

def error_analysis(y_true, y_pred, model_name="Model"):
    """Analyze prediction errors in detail"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    
    print(f"\n{'='*60}")
    print(f"{model_name} - Error Analysis")
    print(f"{'='*60}")
    print(f"Mean Error (Bias):              {np.mean(errors):.4f}")
    print(f"Std Dev of Errors:              {np.std(errors):.4f}")
    print(f"Min Error:                      {np.min(errors):.4f}")
    print(f"Max Error:                      {np.max(errors):.4f}")
    print(f"25th Percentile Error:          {np.percentile(errors, 25):.4f}")
    print(f"Median Error:                   {np.median(errors):.4f}")
    print(f"75th Percentile Error:          {np.percentile(errors, 75):.4f}")
    
    # Count late vs early predictions
    late_predictions = np.sum(errors < 0)
    early_predictions = np.sum(errors > 0)
    print(f"\nLate Predictions (risky):       {late_predictions} ({late_predictions/len(errors)*100:.1f}%)")
    print(f"Early Predictions (safe):       {early_predictions} ({early_predictions/len(errors)*100:.1f}%)")
    print(f"{'='*60}\n")
    
    return errors

# %%
# %%
# Cell 29: Comprehensive Visualization Function
def plot_comprehensive_results(y_true, y_pred, errors, metrics, history=None):
    """Create comprehensive visualization of results"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Determine number of subplots
    n_plots = 8 if history is not None else 6
    fig = plt.figure(figsize=(20, 12 if history is not None else 10))
    
    # 1. Predictions vs Ground Truth
    ax1 = plt.subplot(3, 3, 1)
    plt.scatter(y_true, y_pred, alpha=0.5, s=20)
    plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', lw=2)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Predicted RUL', fontsize=12)
    plt.title(f'Predictions vs Ground Truth\nMAE: {metrics["mae"]:.2f}, RMSE: {metrics["rmse"]:.2f}', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    # 2. Error Distribution
    ax2 = plt.subplot(3, 3, 2)
    plt.hist(errors, bins=50, edgecolor='black', alpha=0.7)
    plt.axvline(x=0, color='r', linestyle='--', linewidth=2, label='Zero Error')
    plt.axvline(x=np.mean(errors), color='g', linestyle='--', linewidth=2, label=f'Mean: {np.mean(errors):.2f}')
    plt.xlabel('Prediction Error (Pred - True)', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.title('Error Distribution', fontsize=12)
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 3. Error vs True RUL
    ax3 = plt.subplot(3, 3, 3)
    plt.scatter(y_true, errors, alpha=0.5, s=20, c=errors, cmap='RdYlGn_r')
    plt.axhline(y=0, color='r', linestyle='--', linewidth=2)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Prediction Error', fontsize=12)
    plt.title('Error vs True RUL', fontsize=12)
    plt.colorbar(label='Error')
    plt.grid(True, alpha=0.3)
    
    # 4. Absolute Error vs True RUL
    ax4 = plt.subplot(3, 3, 4)
    abs_errors = np.abs(errors)
    plt.scatter(y_true, abs_errors, alpha=0.5, s=20)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Absolute Error', fontsize=12)
    plt.title('Absolute Error vs True RUL', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    # 5. Cumulative Error Distribution
    ax5 = plt.subplot(3, 3, 5)
    sorted_abs_errors = np.sort(np.abs(errors))
    cumulative = np.arange(1, len(sorted_abs_errors) + 1) / len(sorted_abs_errors) * 100
    plt.plot(sorted_abs_errors, cumulative, linewidth=2)
    plt.xlabel('Absolute Error', fontsize=12)
    plt.ylabel('Cumulative %', fontsize=12)
    plt.title('Cumulative Error Distribution', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    for percentile in [50, 75, 90, 95]:
        error_at_percentile = np.percentile(abs_errors, percentile)
        plt.axvline(x=error_at_percentile, linestyle='--', alpha=0.5, 
                   label=f'{percentile}th: {error_at_percentile:.2f}')
    plt.legend(fontsize=9)
    
    # 6. Metrics Summary Box
    ax6 = plt.subplot(3, 3, 6)
    ax6.axis('off')
    
    metrics_text = f"""
    EVALUATION METRICS
    {'='*35}
    
    MAE:           {metrics['mae']:.4f}
    MSE:           {metrics['mse']:.4f}
    RMSE:          {metrics['rmse']:.4f}
    NASA Score:    {metrics['nasa_score']:.4f}
    R² Score:      {metrics['r2']:.4f}
    MAPE:          {metrics['mape']:.2f}%
    
    {'='*35}
    
    Mean Error:    {np.mean(errors):.4f}
    Std Dev:       {np.std(errors):.4f}
    
    Late Pred:     {np.sum(errors < 0)} ({np.sum(errors < 0)/len(errors)*100:.1f}%)
    Early Pred:    {np.sum(errors > 0)} ({np.sum(errors > 0)/len(errors)*100:.1f}%)
    """
    
    ax6.text(0.1, 0.5, metrics_text, fontsize=11, family='monospace',
             verticalalignment='center', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.3))
    
    # 7 & 8. Training History (if provided)
    if history is not None:
        ax7 = plt.subplot(3, 3, 7)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epochs', fontsize=12)
        plt.ylabel('Loss', fontsize=12)
        plt.title('Loss vs Epochs', fontsize=12)
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        ax8 = plt.subplot(3, 3, 8)
        plt.plot(history.history['mean_absolute_error'], label='Training MAE')
        plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
        plt.xlabel('Epochs', fontsize=12)
        plt.ylabel('MAE', fontsize=12)
        plt.title('MAE vs Epochs', fontsize=12)
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # 9. Learning Rate (if available)
        ax9 = plt.subplot(3, 3, 9)
        if 'lr' in history.history:
            plt.plot(history.history['lr'])
            plt.xlabel('Epochs', fontsize=12)
            plt.ylabel('Learning Rate', fontsize=12)
            plt.title('Learning Rate Schedule', fontsize=12)
            plt.yscale('log')
            plt.grid(True, alpha=0.3)
        else:
            ax9.axis('off')
            ax9.text(0.5, 0.5, 'Learning Rate\nHistory Not Available', 
                    ha='center', va='center', fontsize=14)
    
    plt.tight_layout()
    plt.savefig('comprehensive_evaluation.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print("Comprehensive evaluation plot saved as 'comprehensive_evaluation.png'")

# %%

# %%
# Cell 30: Save Results Function
def save_results_to_file(results, filename='evaluation_results.txt'):
    """Save all metrics to a text file"""
    with open(filename, 'w') as f:
        f.write("="*60 + "\n")
        f.write("RUL PREDICTION - EVALUATION RESULTS\n")
        f.write("="*60 + "\n\n")
        
        for model_name, metrics in results.items():
            f.write(f"\n{model_name.upper()}\n")
            f.write("-"*40 + "\n")
            for metric_name, value in metrics.items():
                f.write(f"{metric_name.upper():20s}: {value:.4f}\n")
            f.write("\n")
    
    print(f" Results saved to '{filename}'")

# %%
# Cell 31: Evaluate on Test Set
print("\n" + "="*60)
print("FINAL MODEL EVALUATION ON TEST SET")
print("="*60)

# Make predictions
test_predictions = best_model.predict(test_gen, verbose=1)

# Calculate metrics
test_metrics = calculate_all_metrics(test_labels, test_predictions, "Best Model (Test Set)")

# Error analysis
test_errors = error_analysis(test_labels, test_predictions, "Best Model (Test Set)")
# Out:
# ============================================================
# FINAL MODEL EVALUATION ON TEST SET
# ============================================================
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2025-11-29 16:08:38.670304: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1198', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-11-29 16:08:38.701324: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1198', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-11-29 16:08:38.710614: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1198', 52 bytes spill stores, 52 bytes spill loads
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step
#
# ============================================================
# Best Model (Test Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        6.5678
# MSE (Mean Squared Error):         94.5460
# RMSE (Root Mean Squared Error):   9.7235
# NASA Score:                       1.2818
# MAPE (Mean Absolute % Error):     21.51%
# R² Score:                         0.7860
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              -1.4543
# Std Dev of Errors:              9.6141
# Min Error:                      -49.9497
# Max Error:                      37.5713
# 25th Percentile Error:          -5.4262
# Median Error:                   0.4849
# 75th Percentile Error:          3.1609
#
# Late Predictions (risky):       128139 (45.9%)
# Early Predictions (safe):       151179 (54.1%)
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        6.5678
# MSE (Mean Squared Error):         94.5460
# RMSE (Root Mean Squared Error):   9.7235
# NASA Score:                       1.2818
# MAPE (Mean Absolute % Error):     21.51%
# R² Score:                         0.7860
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              -1.4543
# Std Dev of Errors:              9.6141
# Min Error:                      -49.9497
# Max Error:                      37.5713
# 25th Percentile Error:          -5.4262
# Median Error:                   0.4849
# 75th Percentile Error:          3.1609
#
# Late Predictions (risky):       128139 (45.9%)
# Early Predictions (safe):       151179 (54.1%)
# ============================================================

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error
# Extract labels from tf.data.Dataset
def extract_labels(dataset):
    """Extracts all y_true and y_pred arrays from a tf.data.Dataset."""
    y_true_all = []
    for _, y in dataset:
        y_true_all.extend(y.numpy().flatten())
    return np.array(y_true_all)

# Extract true labels
val_labels = extract_labels(val_gen)
test_labels = extract_labels(test_gen)

# Ensure predictions are flattened
val_predictions = best_model.predict(val_gen, verbose=1).flatten()
test_predictions = best_model.predict(test_gen, verbose=1).flatten()

val_metrics = calculate_all_metrics(val_labels, val_predictions, "Best Model (Validation Set)")
val_errors = error_analysis(val_labels, val_predictions, "Best Model (Validation Set)")

test_metrics = calculate_all_metrics(test_labels, test_predictions, "Best Model (Test Set)")
test_errors = error_analysis(test_labels, test_predictions, "Best Model (Test Set)")

# ==========================================
# 🧩 Compare Validation vs Test Performance
# ==========================================
comparison_results = {
    "validation": val_metrics,
    "test": test_metrics
}
comparison_df = pd.DataFrame(comparison_results).T

print("VALIDATION VS TEST COMPARISON")
print(comparison_df.to_string())
print("\n")
# Out:
# 2025-11-29 16:08:39.480854: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 13/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2025-11-29 16:08:39.804246: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#
# ============================================================
# Best Model (Validation Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        4.6338
# MSE (Mean Squared Error):         52.9827
# RMSE (Root Mean Squared Error):   7.2789
# NASA Score:                       0.7378
# MAPE (Mean Absolute % Error):     14.79%
# R² Score:                         0.8822
# ============================================================
#
#
# ============================================================
# Best Model (Validation Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              -1.0157
# Std Dev of Errors:              7.2077
# Min Error:                      -41.2246
# Max Error:                      44.4962
# 25th Percentile Error:          -3.2107
#
# ============================================================
# Best Model (Validation Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        4.6338
# MSE (Mean Squared Error):         52.9827
# RMSE (Root Mean Squared Error):   7.2789
# NASA Score:                       0.7378
# MAPE (Mean Absolute % Error):     14.79%
# R² Score:                         0.8822
# ============================================================
#
#
# ============================================================
# Best Model (Validation Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              -1.0157
# Std Dev of Errors:              7.2077
# Min Error:                      -41.2246
# Max Error:                      44.4962
# 25th Percentile Error:          -3.2107
# Median Error:                   0.0868
# 75th Percentile Error:          1.9253
#
# Late Predictions (risky):       35712 (48.8%)
# Early Predictions (safe):       37438 (51.2%)
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        6.5678
# MSE (Mean Squared Error):         94.5460
# RMSE (Root Mean Squared Error):   9.7235
# NASA Score:                       1.2818
# MAPE (Mean Absolute % Error):     21.51%
# R² Score:                         0.7860
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              -1.4543
# Std Dev of Errors:              9.6141
# Min Error:                      -49.9497
# Max Error:                      37.5713
# 25th Percentile Error:          -5.4262
# Median Error:                   0.4849
# 75th Percentile Error:          3.1609
#
# Late Predictions (risky):       128139 (45.9%)
# Early Predictions (safe):       151179 (54.1%)
# ============================================================
#
# VALIDATION VS TEST COMPARISON
#                  mae        mse      rmse  nasa_score       mape        r2
# validation  4.633775  52.982685  7.278921    0.737806  14.791785  0.882203
# test        6.567765  94.546005  9.723477    1.281806  21.513700  0.786029
#
#
# Median Error:                   0.0868
# 75th Percentile Error:          1.9253
#
# Late Predictions (risky):       35712 (48.8%)
# Early Predictions (safe):       37438 (51.2%)
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        6.5678
# MSE (Mean Squared Error):         94.5460
# RMSE (Root Mean Squared Error):   9.7235
# NASA Score:                       1.2818
# MAPE (Mean Absolute % Error):     21.51%
# R² Score:                         0.7860
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              -1.4543
# Std Dev of Errors:              9.6141
# Min Error:                      -49.9497
# Max Error:                      37.5713
# 25th Percentile Error:          -5.4262
# Median Error:                   0.4849
# 75th Percentile Error:          3.1609
#
# Late Predictions (risky):       128139 (45.9%)
# Early Predictions (safe):       151179 (54.1%)
# ============================================================
#
# VALIDATION VS TEST COMPARISON
#                  mae        mse      rmse  nasa_score       mape        r2
# validation  4.633775  52.982685  7.278921    0.737806  14.791785  0.882203
# test        6.567765  94.546005  9.723477    1.281806  21.513700  0.786029

# %%
mae_diff = test_metrics["mae"] - val_metrics["mae"]
rmse_diff = test_metrics["rmse"] - val_metrics["rmse"]

print(f"MAE Difference (Test - Val): {mae_diff:+.4f}")
print(f"RMSE Difference (Test - Val): {rmse_diff:+.4f}")

if mae_diff > 1.0:
    print("⚠️ Warning: Significant performance drop on test set — possible overfitting")
elif mae_diff < -1.0:
    print("✅ Model generalizes better on test set")
else:
    print(" Model shows consistent performance across validation and test sets")
# Out:
# MAE Difference (Test - Val): +1.9340
# RMSE Difference (Test - Val): +2.4446
# ⚠️ Warning: Significant performance drop on test set — possible overfitting

# %%
def plot_comprehensive_results(y_true, y_pred, metrics, history=None, title="Comprehensive Evaluation"):
    """Comprehensive performance visualization."""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()

    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    # 1️⃣ True vs Predicted
    axs[0].plot(y_true, label="True RUL", alpha=0.7)
    axs[0].plot(y_pred, label="Predicted RUL", alpha=0.7)
    axs[0].set_title("Predicted vs True RUL")
    axs[0].set_xlabel("Sample Index")
    axs[0].set_ylabel("RUL")
    axs[0].legend()
    axs[0].grid(True)

    # 2️⃣ Scatter
    axs[1].scatter(y_true, y_pred, alpha=0.5)
    lims = [min(y_true.min(), y_pred.min()), max(y_true.max(), y_pred.max())]
    axs[1].plot(lims, lims, "r--", label="Ideal Fit")
    axs[1].set_xlim(lims)
    axs[1].set_ylim(lims)
    axs[1].set_title("True vs Predicted Scatter")
    axs[1].set_xlabel("True RUL")
    axs[1].set_ylabel("Predicted RUL")
    axs[1].legend()
    axs[1].grid(True)

    # 3️⃣ Training History (if available)
    if history is not None:
        axs[2].plot(history.history.get("mae", []), label="Train MAE")
        axs[2].plot(history.history.get("val_mae", []), label="Val MAE")
        axs[2].plot(history.history.get("loss", []), label="Train Loss")
        axs[2].plot(history.history.get("val_loss", []), label="Val Loss")
        axs[2].set_title("Training History")
        axs[2].set_xlabel("Epochs")
        axs[2].set_ylabel("Metric Value")
        axs[2].legend()
        axs[2].grid(True)
    else:
        axs[2].axis("off")
        axs[2].text(0.5, 0.5, "No training history provided", ha="center", va="center")

    plt.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()


# Run visualization
plot_comprehensive_results(test_labels, test_predictions, test_metrics)

# %%
def show_prediction_samples(y_true, y_pred, n_samples=20):
    """Show random sample predictions."""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    indices = np.random.choice(len(y_true), min(n_samples, len(y_true)), replace=False)
    print("\n" + "="*80)
    print("SAMPLE PREDICTIONS")
    print("="*80)
    print(f"{'Index':<8} {'True RUL':<12} {'Pred RUL':<12} {'Error':<12} {'Abs Error':<12} {'Type':<12}")
    print("-"*80)
    for idx in sorted(indices):
        error = y_pred[idx] - y_true[idx]
        pred_type = "Late (Risk)" if error < 0 else "Early (Safe)"
        print(f"{idx:<8} {y_true[idx]:<12.2f} {y_pred[idx]:<12.2f} {error:<+12.2f} {abs(error):<12.2f} {pred_type:<12}")
    print("="*80 + "\n")

show_prediction_samples(test_labels, test_predictions)
# Out:
# ================================================================================
# SAMPLE PREDICTIONS
# ================================================================================
# Index    True RUL     Pred RUL     Error        Abs Error    Type
# --------------------------------------------------------------------------------
# 6129     60.00        61.86        +1.86        1.86         Early (Safe)
# 63143    58.00        52.72        -5.28        5.28         Late (Risk)
# 73026    48.00        41.13        -6.87        6.87         Late (Risk)
# 85952    33.00        48.67        +15.67       15.67        Early (Safe)
# 98243    19.00        16.32        -2.68        2.68         Late (Risk)
# 99069    18.00        20.68        +2.68        2.68         Early (Safe)
# 99551    18.00        21.04        +3.04        3.04         Early (Safe)
# 133905   34.00        27.96        -6.04        6.04         Late (Risk)
# 144117   76.00        55.26        -20.74       20.74        Late (Risk)
# 145834   74.00        59.86        -14.14       14.14        Late (Risk)
# 182986   35.00        29.40        -5.60        5.60         Late (Risk)
# 207671   9.00         9.65         +0.65        0.65         Early (Safe)
# 218060   69.00        57.17        -11.83       11.83        Late (Risk)
# 220998   59.00        58.81        -0.19        0.19         Late (Risk)
# 233420   18.00        20.78        +2.78        2.78         Early (Safe)
# 236951   7.00         7.64         +0.64        0.64         Early (Safe)
# 249845   49.00        44.72        -4.28        4.28         Late (Risk)
# 252585   44.00        40.32        -3.68        3.68         Late (Risk)
# 274054   9.00         10.18        +1.18        1.18         Early (Safe)
# 276614   5.00         5.33         +0.33        0.33         Early (Safe)
# ================================================================================

# %%
def show_best_worst_predictions(y_true, y_pred, n=10):
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    abs_errors = np.abs(errors)
    
    best_idx = np.argsort(abs_errors)[:n]
    worst_idx = np.argsort(abs_errors)[-n:][::-1]
    
    print("\n" + "="*80)
    print(f"TOP {n} BEST PREDICTIONS")
    print("="*80)
    for idx in best_idx:
        print(f"{idx:<8} True={y_true[idx]:<8.2f} Pred={y_pred[idx]:<8.2f} Err={errors[idx]:<+8.2f}")

    print("\n" + "="*80)
    print(f"TOP {n} WORST PREDICTIONS")
    print("="*80)
    for idx in worst_idx:
        pred_type = "Late" if errors[idx] < 0 else "Early"
        print(f"{idx:<8} True={y_true[idx]:<8.2f} Pred={y_pred[idx]:<8.2f} Err={errors[idx]:<+8.2f} ({pred_type})")

show_best_worst_predictions(test_labels, test_predictions)
# Out:
# ================================================================================
# TOP 10 BEST PREDICTIONS
# ================================================================================
# 205570   True=12.00    Pred=12.00    Err=-0.00
# 235972   True=10.00    Pred=10.00    Err=-0.00
# 115749   True=1.00     Pred=1.00     Err=-0.00
# 234661   True=14.00    Pred=14.00    Err=+0.00
# 115752   True=1.00     Pred=1.00     Err=+0.00
# 238774   True=1.00     Pred=1.00     Err=+0.00
# 64938    True=56.00    Pred=56.00    Err=-0.00
# 238331   True=2.00     Pred=2.00     Err=-0.00
# 83665    True=36.00    Pred=36.00    Err=+0.00
# 238775   True=1.00     Pred=1.00     Err=+0.00
#
# ================================================================================
# TOP 10 WORST PREDICTIONS
# ================================================================================
# 119052   True=84.00    Pred=34.05    Err=-49.95   (Late)
# 118371   True=87.00    Pred=37.08    Err=-49.92   (Late)
# 119061   True=84.00    Pred=34.14    Err=-49.86   (Late)
# 119036   True=84.00    Pred=34.20    Err=-49.80   (Late)
# 119051   True=84.00    Pred=34.37    Err=-49.63   (Late)
# 119043   True=84.00    Pred=34.39    Err=-49.61   (Late)
# 119062   True=84.00    Pred=34.40    Err=-49.60   (Late)
# 119050   True=84.00    Pred=34.40    Err=-49.60   (Late)
# 119044   True=84.00    Pred=34.42    Err=-49.58   (Late)
# 119057   True=84.00    Pred=34.43    Err=-49.57   (Late)

# %%
def score_metric_fn(y_true, y_pred):
    diff = y_pred - y_true
    return np.mean(np.exp(np.maximum(diff, 0) / 10) - 1 + np.exp(np.maximum(-diff, 0) / 13) - 1)

def analyze_by_rul_ranges(y_true, y_pred):
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    ranges = [(0,25,"Critical"),(25,50,"High Risk"),(50,75,"Medium"),(75,100,"Low"),(100,1e9,"Safe")]
    
    print("\n" + "="*80)
    print("PERFORMANCE BY RUL RANGE")
    print("="*80)
    print(f"{'Range':<15}{'Count':<10}{'MAE':<10}{'RMSE':<10}{'NASA':<10}{'Late%':<10}")
    print("-"*80)
    
    for lo, hi, name in ranges:
        mask = (y_true >= lo) & (y_true < hi)
        if np.sum(mask) == 0: continue
        yt, yp = y_true[mask], y_pred[mask]
        mae = mean_absolute_error(yt, yp)
        rmse = root_mean_squared_error(yt, yp)
        score = score_metric_fn(yt, yp)
        late = np.sum((yp - yt) < 0) / len(yt) * 100
        print(f"{name:<15}{len(yt):<10}{mae:<10.2f}{rmse:<10.2f}{score:<10.2f}{late:<10.1f}")
    print("="*80 + "\n")

analyze_by_rul_ranges(test_labels, test_predictions)
# Out:
# ================================================================================
# PERFORMANCE BY RUL RANGE
# ================================================================================
# Range          Count     MAE       RMSE      NASA      Late%
# --------------------------------------------------------------------------------
# Critical       98295     2.10      2.61      0.24      19.6
# High Risk      99846     6.58      8.78      1.31      48.1
# Medium         73745     10.28     12.32     1.68      72.4
# Low            7432      28.75     30.37     10.70     100.0
# ================================================================================

# %%
def create_summary_report():
    print("\n" + "="*80)
    print("FINAL SUMMARY REPORT".center(80))
    print("="*80)
    
    print("\n📈 PERFORMANCE METRICS")
    print("-"*80)
    print("Validation Set:")
    for k,v in val_metrics.items(): print(f" {k:<15}: {v:.4f}")
    print("\nTest Set:")
    for k,v in test_metrics.items(): print(f" {k:<15}: {v:.4f}")

    test_errors = test_predictions.flatten() - test_labels.flatten()
    late = np.sum(test_errors < 0)
    early = np.sum(test_errors > 0)
    bias = np.mean(test_errors)

    print("\n⚠️ RISK ANALYSIS")
    print("-"*80)
    print(f"Late (Under): {late} ({late/len(test_errors)*100:.1f}%)")
    print(f"Early (Over): {early} ({early/len(test_errors)*100:.1f}%)")
    print(f"Mean Bias: {bias:+.2f}")
    print("="*80 + "\n")

create_summary_report()
# Out:
# ================================================================================
#                               FINAL SUMMARY REPORT
# ================================================================================
#
# 📈 PERFORMANCE METRICS
# --------------------------------------------------------------------------------
# Validation Set:
#  mae            : 4.6338
#  mse            : 52.9827
#  rmse           : 7.2789
#  nasa_score     : 0.7378
#  mape           : 14.7918
#  r2             : 0.8822
#
# Test Set:
#  mae            : 6.5678
#  mse            : 94.5460
#  rmse           : 9.7235
#  nasa_score     : 1.2818
#  mape           : 21.5137
#  r2             : 0.7860
#
# ⚠️ RISK ANALYSIS
# --------------------------------------------------------------------------------
# Late (Under): 128139 (45.9%)
# Early (Over): 151179 (54.1%)
# Mean Bias: -1.45
# ================================================================================

# %%
# ==========================================
# 📤 Export Predictions
# ==========================================
def export_predictions(y_true, y_pred, filename="predictions.csv"):
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    df = pd.DataFrame({
        "True_RUL": y_true,
        "Predicted_RUL": y_pred,
        "Error": errors,
        "Abs_Error": np.abs(errors),
        "Prediction_Type": ["Late" if e < 0 else "Early" for e in errors]
    })
    return df

predictions_df = export_predictions(test_labels, test_predictions)
predictions_df.head(10)
# Out:
#    True_RUL  Predicted_RUL      Error  Abs_Error Prediction_Type
# 0      65.0      69.922638   4.922638   4.922638           Early
# 1      65.0      69.169449   4.169449   4.169449           Early
# 2      65.0      71.585953   6.585953   6.585953           Early
# 3      65.0      74.201385   9.201385   9.201385           Early
# 4      65.0      74.494026   9.494026   9.494026           Early
# 5      65.0      74.875374   9.875374   9.875374           Early
# 6      65.0      75.052139  10.052139  10.052139           Early
# 7      65.0      75.156052  10.156052  10.156052           Early
# 8      65.0      75.293243  10.293243  10.293243           Early
# 9      65.0      75.363022  10.363022  10.363022           Early

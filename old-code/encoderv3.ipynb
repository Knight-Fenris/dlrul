# %%
# Cell 1: Imports and Setup
import gc
gc.collect()
import numpy as np
import pandas as pd
import os
import h5py
import time
import matplotlib.pyplot as plt
from pprint import pprint
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# TPU/GPU initialization
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.metrics import R2Score as RSquare

# # TPU strategy setup
# try:
#     tpu = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='local')
#     tf.config.experimental_connect_to_cluster(tpu)
#     tf.tpu.experimental.initialize_tpu_system(tpu)
#     tpu_strategy = tf.distribute.TPUStrategy(tpu)
#     print(f"Running on TPU with {tpu_strategy.num_replicas_in_sync} cores")
# except (ValueError, RuntimeError):
tf.config.experimental.set_memory_growth(
    tf.config.list_physical_devices('GPU')[0], True
)

# Enable gradient checkpointing (trades compute for memory)
tf.config.experimental.enable_tensor_float_32_execution(False)
tpu_strategy = tf.distribute.get_strategy()
print("Running on CPU/GPU")

# %%
# Cell 2: Load Data Files
all_files = []
for dirname, _, filenames in os.walk('./data_set'):
    for filename in filenames:
        all_files.append(os.path.join(dirname, filename))
all_files.sort()
pprint(all_files)
# Out:
# 2025-10-05 04:03:42.062462: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-05 04:03:42.069510: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759637022.077097  796767 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759637022.079507  796767 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-05 04:03:42.088106: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Running on CPU/GPU
# ['./data_set/N-CMAPSS_DS01-005.h5',
#  './data_set/N-CMAPSS_DS02-006.h5',
#  './data_set/N-CMAPSS_DS03-012.h5',
#  './data_set/N-CMAPSS_DS04.h5',
#  './data_set/N-CMAPSS_DS05.h5',
#  './data_set/N-CMAPSS_DS06.h5',
#  './data_set/N-CMAPSS_DS07.h5',
#  './data_set/N-CMAPSS_DS08a-009.h5',
#  './data_set/N-CMAPSS_DS08c-008.h5',
#  './data_set/N-CMAPSS_DS08d-010.h5',
#  './data_set/N-CMAPSS_Example_data_loading_and_exploration.ipynb',
#  './data_set/Run_to_Failure_Simulation_Under_Real_Flight_Conditions_Dataset.pdf',
#  './data_set/data-06-00005-v2.pdf',
#  './data_set/flight_profile_DS02.png',
#  './data_set/kde_DS02.png']

# %%
def read_hdf(filename):
    t = time.process_time()  
    with h5py.File(filename, 'r') as hdf:
        # Development set
        W_dev = np.array(hdf.get('W_dev'), dtype=np.float32)
        X_s_dev = np.array(hdf.get('X_s_dev'), dtype=np.float32)
        X_v_dev = np.array(hdf.get('X_v_dev'), dtype=np.float32)
        T_dev = np.array(hdf.get('T_dev'), dtype=np.float32)
        Y_dev = np.array(hdf.get('Y_dev'), dtype=np.float32)
        A_dev = np.array(hdf.get('A_dev'), dtype=np.float32)

        # Test set
        W_test = np.array(hdf.get('W_test'), dtype=np.float32)
        X_s_test = np.array(hdf.get('X_s_test'), dtype=np.float32)
        X_v_test = np.array(hdf.get('X_v_test'), dtype=np.float32)
        T_test = np.array(hdf.get('T_test'), dtype=np.float32)
        Y_test = np.array(hdf.get('Y_test'), dtype=np.float32)
        A_test = np.array(hdf.get('A_test'), dtype=np.float32)
        
        # Varnams
        W_var = np.array(hdf.get('W_var'))
        X_s_var = np.array(hdf.get('X_s_var'))  
        X_v_var = np.array(hdf.get('X_v_var')) 
        T_var = np.array(hdf.get('T_var'))
        A_var = np.array(hdf.get('A_var'))
        
        # from np.array to list dtype U4/U5
        W_var = list(np.array(W_var, dtype='U20'))
        X_s_var = list(np.array(X_s_var, dtype='U20'))  
        X_v_var = list(np.array(X_v_var, dtype='U20')) 
        T_var = list(np.array(T_var, dtype='U20'))
        A_var = list(np.array(A_var, dtype='U20'))
                        
    ## Train data
    df_a_dev=pd.DataFrame(A_dev,columns=A_var)
    df_t_dev=pd.DataFrame(T_dev,columns=T_var)
    df_w_dev=pd.DataFrame(W_dev,columns=W_var)
    df_xs_dev=pd.DataFrame(X_s_dev,columns=X_s_var)
    df_xv_dev=pd.DataFrame(X_v_dev,columns=X_v_var)
    df_y_dev=pd.DataFrame(Y_dev,columns=['RUL'])

    #get rul
    trainy=df_y_dev[['RUL']]

    #get x from sensors values
    trainx=pd.concat([df_xs_dev,df_w_dev],axis=1)

    print(type(trainy),trainy.shape, type(trainx), trainx.shape)

    ## Test data
    df_a_test=pd.DataFrame(A_test,columns=A_var)
    df_t_test=pd.DataFrame(T_test,columns=T_var)
    df_w_test=pd.DataFrame(W_test,columns=W_var)
    df_xs_test=pd.DataFrame(X_s_test,columns=X_s_var)
    df_xv_test=pd.DataFrame(X_v_test,columns=X_v_var)
    df_y_test=pd.DataFrame(Y_test,columns=['RUL'])

    #get health state from aux
    testy=df_y_test[['RUL']]

    #get x from sensors values
    testx=pd.concat([df_xs_test,df_w_test],axis=1)

    print(type(testy),testy.shape, type(testx), testx.shape)

    print('')
    print("Operation time (min): " , (time.process_time()-t)/60)
    print('')

    return (trainx,trainy,df_a_dev,testx,testy,df_a_test)

# %%
# %%
# Cell 4: Load Specific Dataset
curr_file = all_files[2]
print(curr_file)
trainx, trainy, adev, testx, testy, atest = read_hdf(filename=curr_file)
trainx.info(show_counts=True)
# Out:
# ./data_set/N-CMAPSS_DS03-012.h5
# <class 'pandas.core.frame.DataFrame'> (5571277, 1) <class 'pandas.core.frame.DataFrame'> (5571277, 18)
# <class 'pandas.core.frame.DataFrame'> (4251560, 1) <class 'pandas.core.frame.DataFrame'> (4251560, 18)
#
# Operation time (min):  0.028016491666666664
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5571277 entries, 0 to 5571276
# Data columns (total 18 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   T24     5571277 non-null  float32
#  1   T30     5571277 non-null  float32
#  2   T48     5571277 non-null  float32
#  3   T50     5571277 non-null  float32
#  4   P15     5571277 non-null  float32
#  5   P2      5571277 non-null  float32
#  6   P21     5571277 non-null  float32
#  7   P24     5571277 non-null  float32
#  8   Ps30    5571277 non-null  float32
#  9   P40     5571277 non-null  float32
#  10  P50     5571277 non-null  float32
#  11  Nf      5571277 non-null  float32
#  12  Nc      5571277 non-null  float32
#  13  Wf      5571277 non-null  float32
#  14  alt     5571277 non-null  float32
#  15  Mach    5571277 non-null  float32
#  16  TRA     5571277 non-null  float32
#  17  T2      5571277 non-null  float32
# dtypes: float32(18)
# memory usage: 382.5 MB

# %%
# %%
# Cell 5: Apply RUL Clipping (IMPORTANT!)
MAX_RUL = 125  # Standard for turbofan datasets

print(f"Before clipping - Train RUL range: [{trainy['RUL'].min():.1f}, {trainy['RUL'].max():.1f}]")
print(f"Before clipping - Test RUL range: [{testy['RUL'].min():.1f}, {testy['RUL'].max():.1f}]")

trainy['RUL'] = trainy['RUL'].clip(upper=MAX_RUL)
testy['RUL'] = testy['RUL'].clip(upper=MAX_RUL)

print(f"\nAfter clipping - Train RUL range: [{trainy['RUL'].min():.1f}, {trainy['RUL'].max():.1f}]")
print(f"After clipping - Test RUL range: [{testy['RUL'].min():.1f}, {testy['RUL'].max():.1f}]")

# %%
# Out:
# Before clipping - Train RUL range: [0.0, 92.0]
# Before clipping - Test RUL range: [0.0, 92.0]
#
# After clipping - Train RUL range: [0.0, 92.0]
# After clipping - Test RUL range: [0.0, 92.0]

# %%
# Cell 6: Remove Zero RUL Values
trainy = trainy[trainy != 0].dropna()
trainx = trainx.loc[trainy.index]
testy = testy[testy != 0].dropna()
testx = testx.loc[testy.index]

print(f"After filtering - Train: {trainx.shape}, Test: {testx.shape}")
# Out:
# After filtering - Train: (5486397, 18), Test: (4189932, 18)

# %%
# %%
# Cell 7: Feature Engineering Function
def add_degradation_features(df, unit_col='unit'):
    """Add rolling statistics and trends for better RUL prediction"""
    sensor_cols = [col for col in df.columns if col not in [unit_col, 'RUL']]
    
    print(f"Adding degradation features for {len(sensor_cols)} sensors...")
    
    for col in sensor_cols:
        # Rolling statistics (5 timesteps)
        df[f'{col}_roll5_mean'] = df.groupby(unit_col)[col].transform(
            lambda x: x.rolling(5, min_periods=1).mean()
        )
        df[f'{col}_roll5_std'] = df.groupby(unit_col)[col].transform(
            lambda x: x.rolling(5, min_periods=1).std().fillna(0)
        )
        
        # Exponential moving average (captures trends)
        df[f'{col}_ema'] = df.groupby(unit_col)[col].transform(
            lambda x: x.ewm(span=10, adjust=False).mean()
        )
        
        # Rate of change
        df[f'{col}_diff'] = df.groupby(unit_col)[col].diff().fillna(0)
    
    print(f"Feature engineering complete. New shape: {df.shape}")
    return df

# %%
# %%
# Cell 8: Standard Scaling
sc = StandardScaler()
sc.fit(trainx.values)
trainx_l_sc = sc.transform(trainx.values).astype(np.float32)
testx_l_sc = sc.transform(testx.values).astype(np.float32)

trainx_l_sc = pd.DataFrame(trainx_l_sc, columns=trainx.columns, index=trainx.index)
testx_l_sc = pd.DataFrame(testx_l_sc, columns=trainx.columns, index=testx.index)

print(f"Scaled data - Train: {trainx_l_sc.shape}, Test: {testx_l_sc.shape}")
# Out:
# Scaled data - Train: (5486397, 18), Test: (4189932, 18)

# %%
# %%
# Cell 9: Prepare Data with Features
# Training data
df_train = trainx_l_sc.copy()
df_train['unit'] = adev.loc[trainx_l_sc.index, 'unit'].values
df_train['RUL'] = trainy['RUL'].values
df_train = add_degradation_features(df_train, unit_col='unit')

# Test data
df_test = testx_l_sc.copy()
df_test['unit'] = atest.loc[testx_l_sc.index, 'unit'].values
df_test['RUL'] = testy['RUL'].values
df_test = add_degradation_features(df_test, unit_col='unit')

print(f"\nFinal feature counts:")
print(f"Train: {df_train.shape}")
print(f"Test: {df_test.shape}")
# Out:
# Adding degradation features for 18 sensors...
# Feature engineering complete. New shape: (5486397, 92)
# Adding degradation features for 18 sensors...
# Feature engineering complete. New shape: (4189932, 92)
#
# Final feature counts:
# Train: (5486397, 92)
# Test: (4189932, 92)

# %%
# %%
# Cell 10: Time Window Functions
def time_window_slicing_sample(input_array, window_length, unit, sequence_cols, stride=1):
    window_lst = []
    input_temp = input_array[input_array['unit'] == unit][sequence_cols].values.astype(np.float32)
    print(f"Unit {unit} input array shape: {input_temp.shape}")
    num_samples = int((input_temp.shape[0] - window_length) / stride) + 1

    for i in range(num_samples):
        window = input_temp[i*stride:i*stride + window_length, :]
        window_lst.append(window)

    sample_array = np.dstack(window_lst).astype(np.float32)
    print(f"sample_array.shape: {sample_array.shape}")
    return sample_array

def time_window_slicing_label(input_array, window_length, unit, sequence_cols='RUL', stride=1):
    window_lst = []
    input_temp = input_array[input_array['unit'] == unit][sequence_cols].values.astype(np.float32)
    num_samples = int((input_temp.shape[0] - window_length) / stride) + 1
    
    for i in range(num_samples):
        window = input_temp[i*stride:i*stride + window_length]
        window_lst.append(window)

    label_array = np.asarray(window_lst).astype(np.float32)
    return label_array[:, -1]

# %%
# %%
# Cell 11: Create Train/Val Split by Units (Prevent Data Leakage!)
WINDOW_SIZE = 50  # Increased from 30
STRIDE = 25       # Increased from 15

print("Creating train/validation split by units to prevent data leakage...")

# Split units (not samples!)
unique_units = df_train['unit'].unique()
train_units, val_units = train_test_split(unique_units, test_size=0.2, random_state=42)

print(f"Train units: {len(train_units)}, Val units: {len(val_units)}")
print(f"Train units: {sorted(train_units)}")
print(f"Val units: {sorted(val_units)}")
# Out:
# Creating train/validation split by units to prevent data leakage...
# Train units: 7, Val units: 2
# Train units: [np.float32(1.0), np.float32(3.0), np.float32(4.0), np.float32(5.0), np.float32(6.0), np.float32(7.0), np.float32(9.0)]
# Val units: [np.float32(2.0), np.float32(8.0)]

# %%
# %%
# Cell 12: Create Windows for Training Data
feature_cols = df_train.columns.difference(['unit', 'RUL'])
print(f"Using {len(feature_cols)} features for windowing")

# Training windows
print("\n--- Creating Training Windows ---")
train_data = []
train_labels = []
for un in train_units:
    train_data.append(time_window_slicing_sample(
        df_train, WINDOW_SIZE, un, feature_cols, STRIDE
    ))
    train_labels.extend(time_window_slicing_label(
        df_train, WINDOW_SIZE, un, stride=STRIDE
    ))

train_data = np.dstack(train_data).transpose(2, 0, 1).astype(np.float32)
train_labels = np.array(train_labels, dtype=np.float32).reshape(-1, 1)

print(f"\nTrain data shape: {train_data.shape}")
print(f"Train labels shape: {train_labels.shape}")
# Out:
# Using 90 features for windowing
#
# --- Creating Training Windows ---
# Unit 6.0 input array shape: (926215, 90)
# sample_array.shape: (50, 90, 37047)
# Unit 1.0 input array shape: (303829, 90)
# sample_array.shape: (50, 90, 12152)
# Unit 9.0 input array shape: (358827, 90)
# sample_array.shape: (50, 90, 14352)
# Unit 3.0 input array shape: (582325, 90)
# sample_array.shape: (50, 90, 23292)
# Unit 5.0 input array shape: (396645, 90)
# sample_array.shape: (50, 90, 15864)
# Unit 4.0 input array shape: (530938, 90)
# sample_array.shape: (50, 90, 21236)
# Unit 7.0 input array shape: (690621, 90)
# sample_array.shape: (50, 90, 27623)
#
# Train data shape: (151566, 50, 90)
# Train labels shape: (151566, 1)

# %%
# %%
# Cell 13: Create Windows for Validation Data
print("\n--- Creating Validation Windows ---")
val_data = []
val_labels = []
for un in val_units:
    val_data.append(time_window_slicing_sample(
        df_train, WINDOW_SIZE, un, feature_cols, STRIDE
    ))
    val_labels.extend(time_window_slicing_label(
        df_train, WINDOW_SIZE, un, stride=STRIDE
    ))

val_data = np.dstack(val_data).transpose(2, 0, 1).astype(np.float32)
val_labels = np.array(val_labels, dtype=np.float32).reshape(-1, 1)

print(f"\nVal data shape: {val_data.shape}")
print(f"Val labels shape: {val_labels.shape}")
# Out:
# --- Creating Validation Windows ---
# Unit 8.0 input array shape: (1059191, 90)
# sample_array.shape: (50, 90, 42366)
# Unit 2.0 input array shape: (637806, 90)
# sample_array.shape: (50, 90, 25511)
#
# Val data shape: (67877, 50, 90)
# Val labels shape: (67877, 1)

# %%
# %%
# Cell 14: Create Windows for Test Data
print("\n--- Creating Test Windows ---")
test_data = []
test_labels = []
for un in df_test['unit'].unique():
    test_data.append(time_window_slicing_sample(
        df_test, WINDOW_SIZE, un, feature_cols, STRIDE
    ))
    test_labels.extend(time_window_slicing_label(
        df_test, WINDOW_SIZE, un, stride=STRIDE
    ))

test_data = np.dstack(test_data).transpose(2, 0, 1).astype(np.float32)
test_labels = np.array(test_labels, dtype=np.float32).reshape(-1, 1)

print(f"\nTest data shape: {test_data.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Clean up memory
del df_train, df_test, trainx, trainy, trainx_l_sc
gc.collect()
# Out:
# --- Creating Test Windows ---
# Unit 10.0 input array shape: (938592, 90)
# sample_array.shape: (50, 90, 37542)
# Unit 11.0 input array shape: (814152, 90)
# sample_array.shape: (50, 90, 32565)
# Unit 12.0 input array shape: (399732, 90)
# sample_array.shape: (50, 90, 15988)
# Unit 13.0 input array shape: (1089493, 90)
# sample_array.shape: (50, 90, 43578)
# Unit 14.0 input array shape: (340824, 90)
# sample_array.shape: (50, 90, 13631)
# Unit 15.0 input array shape: (607139, 90)
# sample_array.shape: (50, 90, 24284)
#
# Test data shape: (167588, 50, 90)
# Test labels shape: (167588, 1)
# 0

# %%
# %%
# Cell 15: Create TensorFlow Datasets
# OPTIMIZED: Increased batch size for better GPU utilization
BATCH_SIZE = 2048 

BUFFER_SIZE = 5000

# print(f"Creating TensorFlow datasets with batch size: {BATCH_SIZE}")
# print(f"GPU Memory Usage: ~95% - Batch size optimized for your hardware")

train_ds = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
val_ds = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
test_ds = tf.data.Dataset.from_tensor_slices((test_data, test_labels))

train_gen = (
    train_ds
    .shuffle(buffer_size=BUFFER_SIZE, seed=42, reshuffle_each_iteration=False)
    .batch(BATCH_SIZE, drop_remainder=True)
    .cache()
    .prefetch(2)
)

val_gen = (
    val_ds
    .batch(BATCH_SIZE, drop_remainder=True)
    .cache()
    .prefetch(2)
)

test_gen = (
    test_ds
    .batch(BATCH_SIZE)
    .prefetch(2)
)

print(" TensorFlow data pipelines created successfully")
# Out:
# I0000 00:00:1759637069.678170  796767 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 17712 MB memory:  -> device: 0, name: NVIDIA RTX 4000 Ada Generation, pci bus id: 0000:01:00.0, compute capability: 8.9
#  TensorFlow data pipelines created successfully

# %%
# %%
# Cell 16: Custom Loss Function
def asymmetric_rul_loss(y_true, y_pred):
    """
    Asymmetric loss for RUL prediction
    Penalizes late predictions (underprediction) more heavily
    """
    error = y_true - y_pred
    # Underprediction (late failure prediction) is 2x worse
    return tf.reduce_mean(
        tf.where(error < 0, 
                tf.square(error) * 2.0,
                tf.square(error))
    )

# %%
# Cell 17: Model Architecture Components
class PositionalEncoding(tf.keras.layers.Layer):
    """Learnable positional encoding for sequential data"""
    def __init__(self, sequence_length, d_model, **kwargs):
        super(PositionalEncoding, self).__init__(**kwargs)
        self.sequence_length = sequence_length
        self.d_model = d_model
        
    def build(self, input_shape):
        self.pos_encoding = self.add_weight(
            name='pos_encoding',
            shape=(self.sequence_length, self.d_model),
            initializer='uniform',
            trainable=True
        )
        super(PositionalEncoding, self).build(input_shape)
    
    def call(self, inputs):
        return inputs + self.pos_encoding

def transformer_encoder_v4(inputs, head_size, num_heads, ff_dim, dropout, use_causal_mask=False):
    """Sequential-data optimized transformer block"""
    # Pre-LayerNorm
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs)
    
    # Multi-head attention
    attention_layer = tf.keras.layers.MultiHeadAttention(
        key_dim=head_size, 
        num_heads=num_heads, 
        dropout=dropout,
        use_bias=False
    )
    
    attention_output = attention_layer(x, x, use_causal_mask=use_causal_mask)    
    attention_output = tf.keras.layers.Dropout(dropout)(attention_output)
    res1 = attention_output + inputs

    # Feed-forward network
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(res1)
    x_ff = tf.keras.layers.Dense(ff_dim, activation="gelu", use_bias=False)(x)
    x_ff = tf.keras.layers.Dropout(dropout)(x_ff)
    x_ff = tf.keras.layers.Dense(inputs.shape[-1], use_bias=False)(x_ff)
    
    return x_ff + res1

def temporal_conv_block(inputs, filters, kernel_size, dropout):
    """1D convolutional block for local temporal patterns"""
    x = tf.keras.layers.Conv1D(
        filters=filters, 
        kernel_size=kernel_size, 
        padding='same', 
        activation='gelu',
        use_bias=False
    )(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    
    if inputs.shape[-1] == filters:
        x = x + inputs
    
    return x

class ReduceSumLayer(tf.keras.layers.Layer):
    def call(self, x):
        return tf.reduce_sum(x, axis=1)

# %%
# %%
# Cell 18: Model Builder Function
import keras_tuner

def build_improved_transformer(hp):
    """Enhanced transformer for RUL prediction"""
    input_shape = (WINDOW_SIZE, train_data.shape[2])
    
    # Hyperparameters
    head_size = hp.Choice("head_size", [16, 32, 64])
    num_heads = hp.Choice("num_heads", [4, 6, 8])
    ff_dim = hp.Choice("ff_dim", [128, 256, 512])
    num_blocks = hp.Int("num_blocks", 3, 8)
    dropout = hp.Float("dropout", 0.2, 0.5, step=0.1)
    learning_rate = hp.Choice("lr", [1e-3, 5e-4, 1e-4])
    
    # Architecture options
    use_causal_mask = hp.Boolean("use_causal_mask")
    use_temp_conv = hp.Boolean("use_temp_conv")
    aggregation = hp.Choice("aggregation", ["attention", "last", "mean", "max"])
    
    with tpu_strategy.scope():
        inputs = tf.keras.Input(shape=input_shape)
        
        # Gaussian noise augmentation
        x = tf.keras.layers.GaussianNoise(0.01)(inputs)
        
        # Temporal convolution (optional)
        if use_temp_conv:
            temp_filters = hp.Choice("temp_filters", [16, 32])
            temp_kernel = hp.Choice("temp_kernel", [3, 5])
            x = temporal_conv_block(x, temp_filters, temp_kernel, dropout)
            x = temporal_conv_block(x, input_shape[-1], 1, dropout)
        
        # Positional encoding
        x = PositionalEncoding(input_shape[0], input_shape[1])(x)
        
        # Transformer blocks
        for i in range(num_blocks):
            x = transformer_encoder_v4(x, head_size, num_heads, ff_dim, dropout, use_causal_mask)
        
        # Sequence aggregation
        if aggregation == "last":
            x = x[:, -1, :]
        elif aggregation == "mean":
            x = tf.keras.layers.GlobalAveragePooling1D()(x)
        elif aggregation == "max":
            x = tf.keras.layers.GlobalMaxPooling1D()(x)
        elif aggregation == "attention":
            attention_weights = tf.keras.layers.Dense(1, activation='softmax')(x)
            x = ReduceSumLayer()(x * attention_weights)
        
        # MLP head
        mlp_units = hp.Int("mlp_units", 1, 3)
        for i in range(mlp_units):
            dim = hp.Choice(f'dim_{i}', [64, 128, 256])
            mlp_dropout = hp.Float(f'mlp_dropout_{i}', 0.1, 0.5, step=0.1)
            x = tf.keras.layers.Dense(dim, activation='gelu', use_bias=False)(x)
            x = tf.keras.layers.BatchNormalization()(x)
            x = tf.keras.layers.Dropout(mlp_dropout)(x)
        
        # Output layer with ReLU for positive RUL
        outputs = tf.keras.layers.Dense(1, activation='relu')(x)
        
        model = tf.keras.Model(inputs, outputs)
        
        # Optimizer
        optimizer_type = hp.Choice('optimizer', ['adam', 'adamw'])
        
        if optimizer_type == 'adamw':
            optimizer = tf.keras.optimizers.AdamW(
                learning_rate=learning_rate, 
                weight_decay=1e-4,
                clipnorm=1.0
            )
        else:
            optimizer = tf.keras.optimizers.Adam(
                learning_rate=learning_rate,
                clipnorm=1.0
            )
        
        # Loss function
        loss_type = hp.Choice('loss', ['asymmetric', 'mse', 'huber'])
        if loss_type == 'asymmetric':
            loss = asymmetric_rul_loss
        elif loss_type == 'huber':
            loss = tf.keras.losses.Huber(delta=1.0)
        else:
            loss = tf.keras.losses.MeanSquaredError()
            
        model.compile(
            loss=loss,
            optimizer=optimizer, 
            metrics=["mean_absolute_error", "mean_squared_error"]
        )
    
    return model

# %%

# %%
# Cell 19: Test Model Creation
with tpu_strategy.scope():
    test_model = build_improved_transformer(keras_tuner.HyperParameters())
    test_model.summary()
    print(f"\nModel has {test_model.count_params():,} parameters")
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 50, 90)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_noise      │ (None, 50, 90)    │          0 │ input_layer[0][0] │
# │ (GaussianNoise)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encoding │ (None, 50, 90)    │      4,500 │ gaussian_noise[0… │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 50, 90)    │        180 │ positional_encod… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 50, 90)    │     23,040 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 50, 90)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 50, 90)    │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 50, 128)   │     11,520 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 50, 128)   │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 50, 90)    │     11,520 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 50, 90)    │          0 │ dense_1[0][0],    │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 50, 90)    │     23,040 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 50, 90)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 50, 90)    │          0 │ dropout_4[0][0],  │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 50, 128)   │     11,520 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 50, 128)   │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 50, 90)    │     11,520 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 50, 90)    │          0 │ dense_3[0][0],    │
# │                     │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 50, 90)    │     23,040 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 50, 90)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 50, 90)    │          0 │ dropout_7[0][0],  │
# │                     │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 50, 128)   │     11,520 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 50, 128)   │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 50, 90)    │     11,520 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 50, 90)    │          0 │ dense_5[0][0],    │
# │                     │                   │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 50, 1)     │         91 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 50, 90)    │          0 │ add_5[0][0],      │
# │                     │                   │            │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduce_sum_layer    │ (None, 90)        │          0 │ multiply[0][0]    │
# │ (ReduceSumLayer)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      5,760 │ reduce_sum_layer… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64)        │        256 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1)         │         65 │ dropout_9[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 149,992 (585.91 KB)
#  Trainable params: 149,864 (585.41 KB)
#  Non-trainable params: 128 (512.00 B)
# Model has 149,992 parameters

# %%
# %%
# Cell 20: Setup Hyperparameter Tuner
# OPTIMIZED: Reduced trials for faster training (75% time reduction)
tuner = keras_tuner.BayesianOptimization(
    hypermodel=build_improved_transformer,
    objective="val_mean_absolute_error",
    max_trials=50,           # Reduced from 100 (50% fewer trials)
    executions_per_trial=1,  # Reduced from 2 (50% faster per trial)
    overwrite=False,         # Set True when training new
    directory="keras_tuner_v3",
    project_name="rul",
    distribution_strategy=tpu_strategy,
    max_consecutive_failed_trials=5
)
# Out:
# Reloading Tuner from keras_tuner_v3/rul/tuner0.json

# %%
# %%
# Cell 21: Callbacks for Hyperparameter Search
os.makedirs('checkpoints', exist_ok=True)

search_callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=12, 
        restore_best_weights=True, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.7, 
        patience=5, 
        min_lr=1e-8, 
        monitor='val_loss'
    )
]

# %%
# %%
# Cell 22: Run Hyperparameter Search
# OPTIMIZED: Reduced epochs during search for faster iteration
print("Starting hyperparameter search...")
print(f"Training data: {train_data.shape}")
print(f"Validation data: {val_data.shape}")

history = tuner.search(
    train_gen,
    verbose=2,
    epochs=50,
    validation_data=val_gen, 
    callbacks=search_callbacks
)
# Out:
# Trial 50 Complete [00h 16m 28s]
# val_mean_absolute_error: 7.288594722747803
#
# Best val_mean_absolute_error So Far: 6.581711292266846
# Total elapsed time: 11h 58m 40s

# %%
# %%
# Cell 23: Get Best Hyperparameters
best_hps = tuner.get_best_hyperparameters()[0]

print("="*60)
print("OPTIMAL HYPERPARAMETERS")
print("="*60)
for hp_name in best_hps.values.keys():
    print(f"{hp_name:25s}: {best_hps.get(hp_name)}")
print("="*60)

# %%
# Cell 24: Build Best Model
with tpu_strategy.scope():
    best_model = build_improved_transformer(best_hps)
    
print("\n Best model built successfully")
best_model.summary()
# Out:
# ============================================================
# OPTIMAL HYPERPARAMETERS
# ============================================================
# head_size                : 32
# num_heads                : 8
# ff_dim                   : 128
# num_blocks               : 3
# dropout                  : 0.2
# lr                       : 0.0005
# use_causal_mask          : True
# use_temp_conv            : True
# aggregation              : mean
# mlp_units                : 2
# dim_0                    : 256
# mlp_dropout_0            : 0.5
# optimizer                : adamw
# loss                     : mse
# dim_1                    : 64
# mlp_dropout_1            : 0.1
# dim_2                    : 256
# mlp_dropout_2            : 0.2
# temp_filters             : 16
# temp_kernel              : 3
# ============================================================
#
#  Best model built successfully
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 50, 90)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_noise_1    │ (None, 50, 90)    │          0 │ input_layer_1[0]… │
# │ (GaussianNoise)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 50, 16)    │      4,320 │ gaussian_noise_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 16)    │         64 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 50, 16)    │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 50, 90)    │      1,440 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 90)    │        360 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 50, 90)    │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encodin… │ (None, 50, 90)    │      4,500 │ dropout_20[0][0]  │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ positional_encod… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 50, 90)    │     92,160 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 50, 90)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 50, 90)    │          0 │ dropout_22[0][0], │
# │                     │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 50, 128)   │     11,520 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 50, 128)   │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 50, 90)    │     11,520 │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 50, 90)    │          0 │ dense_15[0][0],   │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 50, 90)    │     92,160 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 50, 90)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 50, 90)    │          0 │ dropout_25[0][0], │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 50, 128)   │     11,520 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 50, 128)   │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 50, 90)    │     11,520 │ dropout_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 50, 90)    │          0 │ dense_17[0][0],   │
# │                     │                   │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 50, 90)    │     92,160 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 50, 90)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 50, 90)    │          0 │ dropout_28[0][0], │
# │                     │                   │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 90)    │        180 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 50, 128)   │     11,520 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 50, 128)   │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 50, 90)    │     11,520 │ dropout_29[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 50, 90)    │          0 │ dense_19[0][0],   │
# │                     │                   │            │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 90)        │          0 │ add_17[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 256)       │     23,040 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_20[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 64)        │     16,384 │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_21[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 1)         │         65 │ dropout_31[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 398,133 (1.52 MB)
#  Trainable params: 397,281 (1.52 MB)
#  Non-trainable params: 852 (3.33 KB)

# %%
# %%
# Cell 25: Final Training Callbacks
final_callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=25, 
        restore_best_weights=True, 
        monitor='val_loss',
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.7, 
        patience=5, 
        min_lr=1e-8, 
        monitor='val_loss',
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'checkpoints/best_model.weights.h5', 
        save_best_only=True, 
        save_weights_only=True, 
        monitor='val_loss',
        verbose=1
    )
]

# %%
# %%
# Cell 26: Train Final Model
print("="*60)
print("TRAINING FINAL MODEL")
print("="*60)

history = best_model.fit(
    train_gen, 
    validation_data=val_gen, 
    epochs=200,
    verbose=1,
    callbacks=final_callbacks
)

print("\n Training complete!")
# Out:
# ============================================================
# TRAINING FINAL MODEL
# ============================================================
# Epoch 1/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1687.1107 - mean_absolute_error: 35.8638 - mean_squared_error: 1687.1107
# Epoch 1: val_loss improved from None to 872.69189, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 1487.6320 - mean_absolute_error: 32.1636 - mean_squared_error: 1487.6320 - val_loss: 872.6919 - val_mean_absolute_error: 24.0271 - val_mean_squared_error: 872.6919 - learning_rate: 5.0000e-04
# Epoch 2/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1436.1248 - mean_absolute_error: 32.6835 - mean_squared_error: 1436.1248
# Epoch 2: val_loss improved from 872.69189 to 468.10062, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 1286.5675 - mean_absolute_error: 29.6507 - mean_squared_error: 1286.5675 - val_loss: 468.1006 - val_mean_absolute_error: 18.0413 - val_mean_squared_error: 468.1006 - learning_rate: 5.0000e-04
# Epoch 3/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1275.3350 - mean_absolute_error: 30.6104 - mean_squared_error: 1275.3350
# Epoch 3: val_loss did not improve from 468.10062
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 157ms/step - loss: 1130.0344 - mean_absolute_error: 27.6043 - mean_squared_error: 1130.0344 - val_loss: 1169.7661 - val_mean_absolute_error: 28.4386 - val_mean_squared_error: 1169.7661 - learning_rate: 5.0000e-04
# Epoch 4/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1146.9648 - mean_absolute_error: 28.6632 - mean_squared_error: 1146.9648
# Epoch 4: val_loss did not improve from 468.10062
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 1012.8959 - mean_absolute_error: 25.8156 - mean_squared_error: 1012.8959 - val_loss: 1100.4154 - val_mean_absolute_error: 27.6349 - val_mean_squared_error: 1100.4154 - learning_rate: 5.0000e-04
# Epoch 5/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1046.7703 - mean_absolute_error: 26.9646 - mean_squared_error: 1046.7703
# Epoch 5: val_loss did not improve from 468.10062
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 914.0360 - mean_absolute_error: 24.3103 - mean_squared_error: 914.0360 - val_loss: 715.1287 - val_mean_absolute_error: 22.3540 - val_mean_squared_error: 715.1287 - learning_rate: 5.0000e-04
# Epoch 6/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 964.3969 - mean_absolute_error: 25.5584 - mean_squared_error: 964.3969
# Epoch 6: val_loss did not improve from 468.10062
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - loss: 850.7747 - mean_absolute_error: 23.1629 - mean_squared_error: 850.7747 - val_loss: 566.9781 - val_mean_absolute_error: 18.6533 - val_mean_squared_error: 566.9781 - learning_rate: 5.0000e-04
# Epoch 7/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 926.5590 - mean_absolute_error: 24.9217 - mean_squared_error: 926.5590
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00035000001662410796.
#
# Epoch 7: val_loss did not improve from 468.10062
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 805.6343 - mean_absolute_error: 22.4619 - mean_squared_error: 805.6343 - val_loss: 641.9595 - val_mean_absolute_error: 20.5628 - val_mean_squared_error: 641.9595 - learning_rate: 5.0000e-04
# Epoch 8/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 842.8918 - mean_absolute_error: 23.5391 - mean_squared_error: 842.8918
# Epoch 8: val_loss did not improve from 468.10062
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 716.4621 - mean_absolute_error: 21.3455 - mean_squared_error: 716.4621 - val_loss: 491.7440 - val_mean_absolute_error: 17.4109 - val_mean_squared_error: 491.7440 - learning_rate: 3.5000e-04
# Epoch 9/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 756.7191 - mean_absolute_error: 22.4260 - mean_squared_error: 756.7191
# Epoch 9: val_loss improved from 468.10062 to 448.81863, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 173ms/step - loss: 658.7249 - mean_absolute_error: 20.4231 - mean_squared_error: 658.7249 - val_loss: 448.8186 - val_mean_absolute_error: 16.7285 - val_mean_squared_error: 448.8186 - learning_rate: 3.5000e-04
# Epoch 10/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 731.8441 - mean_absolute_error: 21.7551 - mean_squared_error: 731.8441
# Epoch 10: val_loss improved from 448.81863 to 444.70020, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - loss: 625.4427 - mean_absolute_error: 19.9196 - mean_squared_error: 625.4427 - val_loss: 444.7002 - val_mean_absolute_error: 16.6912 - val_mean_squared_error: 444.7002 - learning_rate: 3.5000e-04
# Epoch 11/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 689.1655 - mean_absolute_error: 21.1985 - mean_squared_error: 689.1655
# Epoch 11: val_loss improved from 444.70020 to 292.45627, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 597.6542 - mean_absolute_error: 19.6305 - mean_squared_error: 597.6542 - val_loss: 292.4563 - val_mean_absolute_error: 14.1462 - val_mean_squared_error: 292.4563 - learning_rate: 3.5000e-04
# Epoch 12/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 711.0573 - mean_absolute_error: 21.3053 - mean_squared_error: 711.0573
# Epoch 12: val_loss improved from 292.45627 to 161.14136, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 617.6208 - mean_absolute_error: 19.6769 - mean_squared_error: 617.6208 - val_loss: 161.1414 - val_mean_absolute_error: 10.6653 - val_mean_squared_error: 161.1414 - learning_rate: 3.5000e-04
# Epoch 13/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 658.4413 - mean_absolute_error: 20.9300 - mean_squared_error: 658.4413
# Epoch 13: val_loss did not improve from 161.14136
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 562.4330 - mean_absolute_error: 19.0785 - mean_squared_error: 562.4330 - val_loss: 302.9055 - val_mean_absolute_error: 13.4904 - val_mean_squared_error: 302.9055 - learning_rate: 3.5000e-04
# Epoch 14/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 622.0905 - mean_absolute_error: 20.1047 - mean_squared_error: 622.0905
# Epoch 14: val_loss did not improve from 161.14136
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 548.9153 - mean_absolute_error: 18.6997 - mean_squared_error: 548.9153 - val_loss: 304.4472 - val_mean_absolute_error: 13.6581 - val_mean_squared_error: 304.4472 - learning_rate: 3.5000e-04
# Epoch 15/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 705.1705 - mean_absolute_error: 21.4477 - mean_squared_error: 705.1705
# Epoch 15: val_loss did not improve from 161.14136
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 559.7373 - mean_absolute_error: 18.8282 - mean_squared_error: 559.7373 - val_loss: 264.8135 - val_mean_absolute_error: 12.8975 - val_mean_squared_error: 264.8135 - learning_rate: 3.5000e-04
# Epoch 16/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 608.9977 - mean_absolute_error: 19.8437 - mean_squared_error: 608.9977
# Epoch 16: val_loss did not improve from 161.14136
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 529.8016 - mean_absolute_error: 18.4053 - mean_squared_error: 529.8016 - val_loss: 300.9822 - val_mean_absolute_error: 13.4353 - val_mean_squared_error: 300.9822 - learning_rate: 3.5000e-04
# Epoch 17/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 589.3358 - mean_absolute_error: 19.6836 - mean_squared_error: 589.3358
# Epoch 17: val_loss improved from 161.14136 to 152.16515, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 507.8065 - mean_absolute_error: 18.2107 - mean_squared_error: 507.8065 - val_loss: 152.1651 - val_mean_absolute_error: 10.1956 - val_mean_squared_error: 152.1651 - learning_rate: 3.5000e-04
# Epoch 18/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 590.0474 - mean_absolute_error: 19.5622 - mean_squared_error: 590.0474
# Epoch 18: val_loss did not improve from 152.16515
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 158ms/step - loss: 519.2023 - mean_absolute_error: 18.1477 - mean_squared_error: 519.2023 - val_loss: 226.1702 - val_mean_absolute_error: 12.2236 - val_mean_squared_error: 226.1702 - learning_rate: 3.5000e-04
# Epoch 19/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 549.3312 - mean_absolute_error: 18.6949 - mean_squared_error: 549.3312
# Epoch 19: val_loss did not improve from 152.16515
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 476.1429 - mean_absolute_error: 17.3882 - mean_squared_error: 476.1429 - val_loss: 398.9588 - val_mean_absolute_error: 16.4038 - val_mean_squared_error: 398.9588 - learning_rate: 3.5000e-04
# Epoch 20/200
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 542.2010 - mean_absolute_error: 18.5172 - mean_squared_error: 542.2010
# Epoch 20: val_loss improved from 152.16515 to 137.18294, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 160ms/step - loss: 476.0059 - mean_absolute_error: 17.3941 - mean_squared_error: 476.0059 - val_loss: 137.1829 - val_mean_absolute_error: 9.6018 - val_mean_squared_error: 137.1829 - learning_rate: 3.5000e-04
# Epoch 21/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 562.2313 - mean_absolute_error: 19.1420 - mean_squared_error: 562.2313
# Epoch 21: val_loss improved from 137.18294 to 114.99524, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 173ms/step - loss: 464.7641 - mean_absolute_error: 17.2765 - mean_squared_error: 464.7641 - val_loss: 114.9952 - val_mean_absolute_error: 8.8966 - val_mean_squared_error: 114.9952 - learning_rate: 3.5000e-04
# Epoch 22/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 503.0492 - mean_absolute_error: 17.8780 - mean_squared_error: 503.0492
# Epoch 22: val_loss did not improve from 114.99524
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 446.4832 - mean_absolute_error: 16.6895 - mean_squared_error: 446.4832 - val_loss: 282.2161 - val_mean_absolute_error: 13.3553 - val_mean_squared_error: 282.2161 - learning_rate: 3.5000e-04
# Epoch 23/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 526.4956 - mean_absolute_error: 17.9685 - mean_squared_error: 526.4956
# Epoch 23: val_loss did not improve from 114.99524
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 158ms/step - loss: 456.9056 - mean_absolute_error: 17.0044 - mean_squared_error: 456.9056 - val_loss: 126.8966 - val_mean_absolute_error: 9.4811 - val_mean_squared_error: 126.8966 - learning_rate: 3.5000e-04
# Epoch 24/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 492.5555 - mean_absolute_error: 17.3346 - mean_squared_error: 492.5555
# Epoch 24: val_loss did not improve from 114.99524
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 438.7706 - mean_absolute_error: 16.6392 - mean_squared_error: 438.7706 - val_loss: 158.6241 - val_mean_absolute_error: 10.4978 - val_mean_squared_error: 158.6241 - learning_rate: 3.5000e-04
# Epoch 25/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 516.9108 - mean_absolute_error: 18.2697 - mean_squared_error: 516.9108
# Epoch 25: val_loss did not improve from 114.99524
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 430.6635 - mean_absolute_error: 16.6274 - mean_squared_error: 430.6635 - val_loss: 132.9863 - val_mean_absolute_error: 9.3221 - val_mean_squared_error: 132.9863 - learning_rate: 3.5000e-04
# Epoch 26/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 496.6011 - mean_absolute_error: 18.0588 - mean_squared_error: 496.6011
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00024500001163687554.
#
# Epoch 26: val_loss did not improve from 114.99524
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - loss: 403.0353 - mean_absolute_error: 16.1073 - mean_squared_error: 403.0353 - val_loss: 151.8689 - val_mean_absolute_error: 10.2602 - val_mean_squared_error: 151.8689 - learning_rate: 3.5000e-04
# Epoch 27/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 546.5151 - mean_absolute_error: 18.5216 - mean_squared_error: 546.5151
# Epoch 27: val_loss improved from 114.99524 to 104.10143, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 424.9012 - mean_absolute_error: 16.4065 - mean_squared_error: 424.9012 - val_loss: 104.1014 - val_mean_absolute_error: 8.3364 - val_mean_squared_error: 104.1014 - learning_rate: 2.4500e-04
# Epoch 28/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 467.0600 - mean_absolute_error: 17.2945 - mean_squared_error: 467.0600
# Epoch 28: val_loss improved from 104.10143 to 87.88071, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 160ms/step - loss: 381.8420 - mean_absolute_error: 15.6042 - mean_squared_error: 381.8420 - val_loss: 87.8807 - val_mean_absolute_error: 7.7390 - val_mean_squared_error: 87.8807 - learning_rate: 2.4500e-04
# Epoch 29/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 448.3130 - mean_absolute_error: 17.0761 - mean_squared_error: 448.3130
# Epoch 29: val_loss improved from 87.88071 to 86.39776, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 372.8123 - mean_absolute_error: 15.3689 - mean_squared_error: 372.8123 - val_loss: 86.3978 - val_mean_absolute_error: 7.5710 - val_mean_squared_error: 86.3978 - learning_rate: 2.4500e-04
# Epoch 30/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 423.0887 - mean_absolute_error: 16.4915 - mean_squared_error: 423.0887
# Epoch 30: val_loss improved from 86.39776 to 82.41686, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 361.1929 - mean_absolute_error: 15.0928 - mean_squared_error: 361.1929 - val_loss: 82.4169 - val_mean_absolute_error: 6.9450 - val_mean_squared_error: 82.4169 - learning_rate: 2.4500e-04
# Epoch 31/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 423.6871 - mean_absolute_error: 16.3168 - mean_squared_error: 423.6871
# Epoch 31: val_loss did not improve from 82.41686
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 158ms/step - loss: 354.0153 - mean_absolute_error: 14.7647 - mean_squared_error: 354.0153 - val_loss: 92.1690 - val_mean_absolute_error: 7.8133 - val_mean_squared_error: 92.1690 - learning_rate: 2.4500e-04
# Epoch 32/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 441.0580 - mean_absolute_error: 16.6428 - mean_squared_error: 441.0580
# Epoch 32: val_loss did not improve from 82.41686
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - loss: 366.9437 - mean_absolute_error: 15.1211 - mean_squared_error: 366.9437 - val_loss: 91.1127 - val_mean_absolute_error: 8.0016 - val_mean_squared_error: 91.1127 - learning_rate: 2.4500e-04
# Epoch 33/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 410.1328 - mean_absolute_error: 16.1007 - mean_squared_error: 410.1328
# Epoch 33: val_loss did not improve from 82.41686
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 158ms/step - loss: 356.0474 - mean_absolute_error: 14.9060 - mean_squared_error: 356.0474 - val_loss: 112.0506 - val_mean_absolute_error: 9.1193 - val_mean_squared_error: 112.0506 - learning_rate: 2.4500e-04
# Epoch 34/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 429.7424 - mean_absolute_error: 16.5741 - mean_squared_error: 429.7424
# Epoch 34: val_loss did not improve from 82.41686
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 349.8039 - mean_absolute_error: 14.7842 - mean_squared_error: 349.8039 - val_loss: 127.1861 - val_mean_absolute_error: 9.4664 - val_mean_squared_error: 127.1861 - learning_rate: 2.4500e-04
# Epoch 35/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 411.9491 - mean_absolute_error: 16.1012 - mean_squared_error: 411.9491
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00017150000203400848.
#
# Epoch 35: val_loss did not improve from 82.41686
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 344.2800 - mean_absolute_error: 14.5999 - mean_squared_error: 344.2800 - val_loss: 106.6906 - val_mean_absolute_error: 8.7785 - val_mean_squared_error: 106.6906 - learning_rate: 2.4500e-04
# Epoch 36/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 410.4526 - mean_absolute_error: 16.1952 - mean_squared_error: 410.4526
# Epoch 36: val_loss did not improve from 82.41686
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 157ms/step - loss: 344.2198 - mean_absolute_error: 14.6704 - mean_squared_error: 344.2198 - val_loss: 88.3152 - val_mean_absolute_error: 8.0001 - val_mean_squared_error: 88.3152 - learning_rate: 1.7150e-04
# Epoch 37/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 375.9909 - mean_absolute_error: 15.3794 - mean_squared_error: 375.9909
# Epoch 37: val_loss did not improve from 82.41686
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 325.1957 - mean_absolute_error: 14.1624 - mean_squared_error: 325.1957 - val_loss: 115.6122 - val_mean_absolute_error: 8.9241 - val_mean_squared_error: 115.6122 - learning_rate: 1.7150e-04
# Epoch 38/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 395.6443 - mean_absolute_error: 15.7265 - mean_squared_error: 395.6443
# Epoch 38: val_loss improved from 82.41686 to 76.33566, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 160ms/step - loss: 328.6592 - mean_absolute_error: 14.2670 - mean_squared_error: 328.6592 - val_loss: 76.3357 - val_mean_absolute_error: 7.3863 - val_mean_squared_error: 76.3357 - learning_rate: 1.7150e-04
# Epoch 39/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 379.6409 - mean_absolute_error: 15.4631 - mean_squared_error: 379.6409
# Epoch 39: val_loss did not improve from 76.33566
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 319.3209 - mean_absolute_error: 14.1015 - mean_squared_error: 319.3209 - val_loss: 88.7406 - val_mean_absolute_error: 7.7959 - val_mean_squared_error: 88.7406 - learning_rate: 1.7150e-04
# Epoch 40/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 389.2228 - mean_absolute_error: 15.6605 - mean_squared_error: 389.2228
# Epoch 40: val_loss did not improve from 76.33566
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 319.8540 - mean_absolute_error: 14.0630 - mean_squared_error: 319.8540 - val_loss: 97.0190 - val_mean_absolute_error: 8.4069 - val_mean_squared_error: 97.0190 - learning_rate: 1.7150e-04
# Epoch 41/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 379.4564 - mean_absolute_error: 15.5088 - mean_squared_error: 379.4564
# Epoch 41: val_loss improved from 76.33566 to 73.92020, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 160ms/step - loss: 315.9762 - mean_absolute_error: 14.0462 - mean_squared_error: 315.9762 - val_loss: 73.9202 - val_mean_absolute_error: 7.3067 - val_mean_squared_error: 73.9202 - learning_rate: 1.7150e-04
# Epoch 42/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 362.4467 - mean_absolute_error: 15.1554 - mean_squared_error: 362.4467
# Epoch 42: val_loss did not improve from 73.92020
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 310.3737 - mean_absolute_error: 13.8567 - mean_squared_error: 310.3737 - val_loss: 112.5808 - val_mean_absolute_error: 8.8744 - val_mean_squared_error: 112.5808 - learning_rate: 1.7150e-04
# Epoch 43/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 369.2577 - mean_absolute_error: 15.1211 - mean_squared_error: 369.2577
# Epoch 43: val_loss improved from 73.92020 to 61.56162, saving model to checkpoints/best_model.weights.h5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 160ms/step - loss: 311.9488 - mean_absolute_error: 13.8099 - mean_squared_error: 311.9488 - val_loss: 61.5616 - val_mean_absolute_error: 6.5695 - val_mean_squared_error: 61.5616 - learning_rate: 1.7150e-04
# Epoch 44/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 351.5733 - mean_absolute_error: 14.8454 - mean_squared_error: 351.5733
# Epoch 44: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 299.0562 - mean_absolute_error: 13.5896 - mean_squared_error: 299.0562 - val_loss: 63.7604 - val_mean_absolute_error: 6.6706 - val_mean_squared_error: 63.7604 - learning_rate: 1.7150e-04
# Epoch 45/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 360.1272 - mean_absolute_error: 15.0721 - mean_squared_error: 360.1272
# Epoch 45: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 302.3495 - mean_absolute_error: 13.6757 - mean_squared_error: 302.3495 - val_loss: 79.1546 - val_mean_absolute_error: 7.3191 - val_mean_squared_error: 79.1546 - learning_rate: 1.7150e-04
# Epoch 46/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 351.2612 - mean_absolute_error: 14.8571 - mean_squared_error: 351.2612
# Epoch 46: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 158ms/step - loss: 297.0300 - mean_absolute_error: 13.5377 - mean_squared_error: 297.0300 - val_loss: 79.5984 - val_mean_absolute_error: 7.4279 - val_mean_squared_error: 79.5984 - learning_rate: 1.7150e-04
# Epoch 47/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 345.0284 - mean_absolute_error: 14.7070 - mean_squared_error: 345.0284
# Epoch 47: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 294.1886 - mean_absolute_error: 13.4570 - mean_squared_error: 294.1886 - val_loss: 115.7278 - val_mean_absolute_error: 8.8459 - val_mean_squared_error: 115.7278 - learning_rate: 1.7150e-04
# Epoch 48/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 345.6455 - mean_absolute_error: 14.7006 - mean_squared_error: 345.6455
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.00012004999734926967.
#
# Epoch 48: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 295.7247 - mean_absolute_error: 13.5017 - mean_squared_error: 295.7247 - val_loss: 72.6455 - val_mean_absolute_error: 7.1603 - val_mean_squared_error: 72.6455 - learning_rate: 1.7150e-04
# Epoch 49/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 343.1057 - mean_absolute_error: 14.6734 - mean_squared_error: 343.1057
# Epoch 49: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 281.9050 - mean_absolute_error: 13.1474 - mean_squared_error: 281.9050 - val_loss: 79.1785 - val_mean_absolute_error: 7.4368 - val_mean_squared_error: 79.1785 - learning_rate: 1.2005e-04
# Epoch 50/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 340.6021 - mean_absolute_error: 14.6540 - mean_squared_error: 340.6021
# Epoch 50: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 281.9620 - mean_absolute_error: 13.1725 - mean_squared_error: 281.9620 - val_loss: 81.9319 - val_mean_absolute_error: 7.6630 - val_mean_squared_error: 81.9319 - learning_rate: 1.2005e-04
# Epoch 51/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 340.9853 - mean_absolute_error: 14.6355 - mean_squared_error: 340.9853
# Epoch 51: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 158ms/step - loss: 280.0296 - mean_absolute_error: 13.1261 - mean_squared_error: 280.0296 - val_loss: 84.2848 - val_mean_absolute_error: 7.6001 - val_mean_squared_error: 84.2848 - learning_rate: 1.2005e-04
# Epoch 52/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 326.8814 - mean_absolute_error: 14.2996 - mean_squared_error: 326.8814
# Epoch 52: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 272.7484 - mean_absolute_error: 12.9039 - mean_squared_error: 272.7484 - val_loss: 68.5160 - val_mean_absolute_error: 6.8623 - val_mean_squared_error: 68.5160 - learning_rate: 1.2005e-04
# Epoch 53/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 349.2273 - mean_absolute_error: 14.9143 - mean_squared_error: 349.2273
# Epoch 53: ReduceLROnPlateau reducing learning rate to 8.403499814448878e-05.
#
# Epoch 53: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 279.9040 - mean_absolute_error: 13.1625 - mean_squared_error: 279.9040 - val_loss: 83.1150 - val_mean_absolute_error: 7.4275 - val_mean_squared_error: 83.1150 - learning_rate: 1.2005e-04
# Epoch 54/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 326.4376 - mean_absolute_error: 14.2956 - mean_squared_error: 326.4376
# Epoch 54: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 268.1807 - mean_absolute_error: 12.8003 - mean_squared_error: 268.1807 - val_loss: 99.1413 - val_mean_absolute_error: 8.4345 - val_mean_squared_error: 99.1413 - learning_rate: 8.4035e-05
# Epoch 55/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 316.9822 - mean_absolute_error: 13.9965 - mean_squared_error: 316.9822
# Epoch 55: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - loss: 263.5074 - mean_absolute_error: 12.5952 - mean_squared_error: 263.5074 - val_loss: 94.3349 - val_mean_absolute_error: 8.1172 - val_mean_squared_error: 94.3349 - learning_rate: 8.4035e-05
# Epoch 56/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 313.5808 - mean_absolute_error: 13.9136 - mean_squared_error: 313.5808
# Epoch 56: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 260.7116 - mean_absolute_error: 12.5574 - mean_squared_error: 260.7116 - val_loss: 78.5777 - val_mean_absolute_error: 7.4600 - val_mean_squared_error: 78.5777 - learning_rate: 8.4035e-05
# Epoch 57/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 318.7585 - mean_absolute_error: 14.0600 - mean_squared_error: 318.7585
# Epoch 57: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 262.8430 - mean_absolute_error: 12.6080 - mean_squared_error: 262.8430 - val_loss: 70.2854 - val_mean_absolute_error: 7.0517 - val_mean_squared_error: 70.2854 - learning_rate: 8.4035e-05
# Epoch 58/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 327.6262 - mean_absolute_error: 14.2747 - mean_squared_error: 327.6262
# Epoch 58: ReduceLROnPlateau reducing learning rate to 5.882449768250808e-05.
#
# Epoch 58: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 265.1446 - mean_absolute_error: 12.6703 - mean_squared_error: 265.1446 - val_loss: 76.6281 - val_mean_absolute_error: 7.3992 - val_mean_squared_error: 76.6281 - learning_rate: 8.4035e-05
# Epoch 59/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 321.4626 - mean_absolute_error: 14.1992 - mean_squared_error: 321.4626
# Epoch 59: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 257.8235 - mean_absolute_error: 12.5488 - mean_squared_error: 257.8235 - val_loss: 80.9062 - val_mean_absolute_error: 7.6362 - val_mean_squared_error: 80.9062 - learning_rate: 5.8824e-05
# Epoch 60/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 309.4315 - mean_absolute_error: 13.8503 - mean_squared_error: 309.4315
# Epoch 60: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 252.1685 - mean_absolute_error: 12.3823 - mean_squared_error: 252.1685 - val_loss: 89.5465 - val_mean_absolute_error: 8.0257 - val_mean_squared_error: 89.5465 - learning_rate: 5.8824e-05
# Epoch 61/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 305.6767 - mean_absolute_error: 13.7456 - mean_squared_error: 305.6767
# Epoch 61: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 158ms/step - loss: 254.1859 - mean_absolute_error: 12.3856 - mean_squared_error: 254.1859 - val_loss: 91.0217 - val_mean_absolute_error: 7.9590 - val_mean_squared_error: 91.0217 - learning_rate: 5.8824e-05
# Epoch 62/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 334.0768 - mean_absolute_error: 14.4086 - mean_squared_error: 334.0768
# Epoch 62: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 259.3587 - mean_absolute_error: 12.5234 - mean_squared_error: 259.3587 - val_loss: 80.6367 - val_mean_absolute_error: 7.5217 - val_mean_squared_error: 80.6367 - learning_rate: 5.8824e-05
# Epoch 63/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 326.4881 - mean_absolute_error: 14.3348 - mean_squared_error: 326.4881
# Epoch 63: ReduceLROnPlateau reducing learning rate to 4.117714888707269e-05.
#
# Epoch 63: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 258.8395 - mean_absolute_error: 12.5994 - mean_squared_error: 258.8395 - val_loss: 79.6584 - val_mean_absolute_error: 7.5274 - val_mean_squared_error: 79.6584 - learning_rate: 5.8824e-05
# Epoch 64/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 306.4023 - mean_absolute_error: 13.7747 - mean_squared_error: 306.4023
# Epoch 64: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 249.8375 - mean_absolute_error: 12.3141 - mean_squared_error: 249.8375 - val_loss: 83.0904 - val_mean_absolute_error: 7.7043 - val_mean_squared_error: 83.0904 - learning_rate: 4.1177e-05
# Epoch 65/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 309.6647 - mean_absolute_error: 13.8780 - mean_squared_error: 309.6647
# Epoch 65: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 248.3686 - mean_absolute_error: 12.2944 - mean_squared_error: 248.3686 - val_loss: 78.8234 - val_mean_absolute_error: 7.4963 - val_mean_squared_error: 78.8234 - learning_rate: 4.1177e-05
# Epoch 66/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 310.1511 - mean_absolute_error: 13.9265 - mean_squared_error: 310.1511
# Epoch 66: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 159ms/step - loss: 248.2303 - mean_absolute_error: 12.3063 - mean_squared_error: 248.2303 - val_loss: 73.7360 - val_mean_absolute_error: 7.1997 - val_mean_squared_error: 73.7360 - learning_rate: 4.1177e-05
# Epoch 67/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 307.6576 - mean_absolute_error: 13.8487 - mean_squared_error: 307.6576
# Epoch 67: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - loss: 248.1730 - mean_absolute_error: 12.2824 - mean_squared_error: 248.1730 - val_loss: 80.7988 - val_mean_absolute_error: 7.6042 - val_mean_squared_error: 80.7988 - learning_rate: 4.1177e-05
# Epoch 68/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 304.5904 - mean_absolute_error: 13.7823 - mean_squared_error: 304.5904
# Epoch 68: ReduceLROnPlateau reducing learning rate to 2.88240029476583e-05.
#
# Epoch 68: val_loss did not improve from 61.56162
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - loss: 244.8132 - mean_absolute_error: 12.2192 - mean_squared_error: 244.8132 - val_loss: 75.8246 - val_mean_absolute_error: 7.3448 - val_mean_squared_error: 75.8246 - learning_rate: 4.1177e-05
# Epoch 68: early stopping
# Restoring model weights from the end of the best epoch: 43.
#
#  Training complete!

# %%
# %%
# Cell 27: Save Model
# best_model.save('bestv3.keras')
print(" Model saved as 'besv3.keras'")
# Out:
#  Model saved as 'besv3.keras'

# %%
# %%
# Cell 28: Evaluation Metrics Functions
def score_metric_fn(y_true, y_pred):
    """
    NASA's scoring function for RUL prediction
    Asymmetric - penalizes late predictions more than early predictions
    """
    score = 0
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    for i in range(len(y_pred)):
        diff = y_true[i] - y_pred[i]
        if diff <= 0:  # Late prediction (underprediction)
            score += np.exp(-diff / 10.0) - 1
        else:  # Early prediction (overprediction)
            score += np.exp(diff / 13.0) - 1
    return score

def calculate_all_metrics(y_true, y_pred, model_name="Model"):
    """Calculate and display all evaluation metrics"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Standard metrics
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    # NASA scoring function
    score = score_metric_fn(y_true, y_pred)
    
    # Additional metrics
    mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100
    r2 = 1 - (np.sum((y_true - y_pred)**2) / np.sum((y_true - np.mean(y_true))**2))
    
    # Print results
    print(f"\n{'='*60}")
    print(f"{model_name} - Evaluation Metrics")
    print(f"{'='*60}")
    print(f"MAE (Mean Absolute Error):        {mae:.4f}")
    print(f"MSE (Mean Squared Error):         {mse:.4f}")
    print(f"RMSE (Root Mean Squared Error):   {rmse:.4f}")
    print(f"NASA Score:                       {score:.4f}")
    print(f"MAPE (Mean Absolute % Error):     {mape:.2f}%")
    print(f"R² Score:                         {r2:.4f}")
    print(f"{'='*60}\n")
    
    return {
        'mae': mae,
        'mse': mse,
        'rmse': rmse,
        'nasa_score': score,
        'mape': mape,
        'r2': r2
    }

def error_analysis(y_true, y_pred, model_name="Model"):
    """Analyze prediction errors in detail"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    
    print(f"\n{'='*60}")
    print(f"{model_name} - Error Analysis")
    print(f"{'='*60}")
    print(f"Mean Error (Bias):              {np.mean(errors):.4f}")
    print(f"Std Dev of Errors:              {np.std(errors):.4f}")
    print(f"Min Error:                      {np.min(errors):.4f}")
    print(f"Max Error:                      {np.max(errors):.4f}")
    print(f"25th Percentile Error:          {np.percentile(errors, 25):.4f}")
    print(f"Median Error:                   {np.median(errors):.4f}")
    print(f"75th Percentile Error:          {np.percentile(errors, 75):.4f}")
    
    # Count late vs early predictions
    late_predictions = np.sum(errors < 0)
    early_predictions = np.sum(errors > 0)
    print(f"\nLate Predictions (risky):       {late_predictions} ({late_predictions/len(errors)*100:.1f}%)")
    print(f"Early Predictions (safe):       {early_predictions} ({early_predictions/len(errors)*100:.1f}%)")
    print(f"{'='*60}\n")
    
    return errors

# %%
# %%
# Cell 29: Comprehensive Visualization Function
def plot_comprehensive_results(y_true, y_pred, errors, metrics, history=None):
    """Create comprehensive visualization of results"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Determine number of subplots
    n_plots = 8 if history is not None else 6
    fig = plt.figure(figsize=(20, 12 if history is not None else 10))
    
    # 1. Predictions vs Ground Truth
    ax1 = plt.subplot(3, 3, 1)
    plt.scatter(y_true, y_pred, alpha=0.5, s=20)
    plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', lw=2)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Predicted RUL', fontsize=12)
    plt.title(f'Predictions vs Ground Truth\nMAE: {metrics["mae"]:.2f}, RMSE: {metrics["rmse"]:.2f}', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    # 2. Error Distribution
    ax2 = plt.subplot(3, 3, 2)
    plt.hist(errors, bins=50, edgecolor='black', alpha=0.7)
    plt.axvline(x=0, color='r', linestyle='--', linewidth=2, label='Zero Error')
    plt.axvline(x=np.mean(errors), color='g', linestyle='--', linewidth=2, label=f'Mean: {np.mean(errors):.2f}')
    plt.xlabel('Prediction Error (Pred - True)', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.title('Error Distribution', fontsize=12)
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 3. Error vs True RUL
    ax3 = plt.subplot(3, 3, 3)
    plt.scatter(y_true, errors, alpha=0.5, s=20, c=errors, cmap='RdYlGn_r')
    plt.axhline(y=0, color='r', linestyle='--', linewidth=2)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Prediction Error', fontsize=12)
    plt.title('Error vs True RUL', fontsize=12)
    plt.colorbar(label='Error')
    plt.grid(True, alpha=0.3)
    
    # 4. Absolute Error vs True RUL
    ax4 = plt.subplot(3, 3, 4)
    abs_errors = np.abs(errors)
    plt.scatter(y_true, abs_errors, alpha=0.5, s=20)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Absolute Error', fontsize=12)
    plt.title('Absolute Error vs True RUL', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    # 5. Cumulative Error Distribution
    ax5 = plt.subplot(3, 3, 5)
    sorted_abs_errors = np.sort(np.abs(errors))
    cumulative = np.arange(1, len(sorted_abs_errors) + 1) / len(sorted_abs_errors) * 100
    plt.plot(sorted_abs_errors, cumulative, linewidth=2)
    plt.xlabel('Absolute Error', fontsize=12)
    plt.ylabel('Cumulative %', fontsize=12)
    plt.title('Cumulative Error Distribution', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    for percentile in [50, 75, 90, 95]:
        error_at_percentile = np.percentile(abs_errors, percentile)
        plt.axvline(x=error_at_percentile, linestyle='--', alpha=0.5, 
                   label=f'{percentile}th: {error_at_percentile:.2f}')
    plt.legend(fontsize=9)
    
    # 6. Metrics Summary Box
    ax6 = plt.subplot(3, 3, 6)
    ax6.axis('off')
    
    metrics_text = f"""
    EVALUATION METRICS
    {'='*35}
    
    MAE:           {metrics['mae']:.4f}
    MSE:           {metrics['mse']:.4f}
    RMSE:          {metrics['rmse']:.4f}
    NASA Score:    {metrics['nasa_score']:.4f}
    R² Score:      {metrics['r2']:.4f}
    MAPE:          {metrics['mape']:.2f}%
    
    {'='*35}
    
    Mean Error:    {np.mean(errors):.4f}
    Std Dev:       {np.std(errors):.4f}
    
    Late Pred:     {np.sum(errors < 0)} ({np.sum(errors < 0)/len(errors)*100:.1f}%)
    Early Pred:    {np.sum(errors > 0)} ({np.sum(errors > 0)/len(errors)*100:.1f}%)
    """
    
    ax6.text(0.1, 0.5, metrics_text, fontsize=11, family='monospace',
             verticalalignment='center', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.3))
    
    # 7 & 8. Training History (if provided)
    if history is not None:
        ax7 = plt.subplot(3, 3, 7)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epochs', fontsize=12)
        plt.ylabel('Loss', fontsize=12)
        plt.title('Loss vs Epochs', fontsize=12)
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        ax8 = plt.subplot(3, 3, 8)
        plt.plot(history.history['mean_absolute_error'], label='Training MAE')
        plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
        plt.xlabel('Epochs', fontsize=12)
        plt.ylabel('MAE', fontsize=12)
        plt.title('MAE vs Epochs', fontsize=12)
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # 9. Learning Rate (if available)
        ax9 = plt.subplot(3, 3, 9)
        if 'lr' in history.history:
            plt.plot(history.history['lr'])
            plt.xlabel('Epochs', fontsize=12)
            plt.ylabel('Learning Rate', fontsize=12)
            plt.title('Learning Rate Schedule', fontsize=12)
            plt.yscale('log')
            plt.grid(True, alpha=0.3)
        else:
            ax9.axis('off')
            ax9.text(0.5, 0.5, 'Learning Rate\nHistory Not Available', 
                    ha='center', va='center', fontsize=14)
    
    plt.tight_layout()
    plt.savefig('comprehensive_evaluation.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print("📊 Comprehensive evaluation plot saved as 'comprehensive_evaluation.png'")

# %%

# %%
# Cell 30: Save Results Function
def save_results_to_file(results, filename='evaluation_results.txt'):
    """Save all metrics to a text file"""
    with open(filename, 'w') as f:
        f.write("="*60 + "\n")
        f.write("RUL PREDICTION - EVALUATION RESULTS\n")
        f.write("="*60 + "\n\n")
        
        for model_name, metrics in results.items():
            f.write(f"\n{model_name.upper()}\n")
            f.write("-"*40 + "\n")
            for metric_name, value in metrics.items():
                f.write(f"{metric_name.upper():20s}: {value:.4f}\n")
            f.write("\n")
    
    print(f" Results saved to '{filename}'")

# %%
# Cell 31: Evaluate on Test Set
print("\n" + "="*60)
print("FINAL MODEL EVALUATION ON TEST SET")
print("="*60)

# Make predictions
test_predictions = best_model.predict(test_gen, verbose=1)

# Calculate metrics
test_metrics = calculate_all_metrics(test_labels, test_predictions, "Best Model (Test Set)")

# Error analysis
test_errors = error_analysis(test_labels, test_predictions, "Best Model (Test Set)")
# Out:
# ============================================================
# FINAL MODEL EVALUATION ON TEST SET
# ============================================================
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step
#
# ============================================================
# Best Model (Test Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        8.3458
# MSE (Mean Squared Error):         107.1498
# RMSE (Root Mean Squared Error):   10.3513
# NASA Score:                       254029.6719
# MAPE (Mean Absolute % Error):     37.74%
# R² Score:                         0.7575
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              0.9723
# Std Dev of Errors:              10.3056
# Min Error:                      -42.9050
# Max Error:                      32.5130
# 25th Percentile Error:          -5.6759
# Median Error:                   1.4135
# 75th Percentile Error:          8.6498
#
# Late Predictions (risky):       76519 (45.7%)
# Early Predictions (safe):       91069 (54.3%)
# ============================================================

# %%
# %%
# Cell 32: Evaluate on Validation Set (for comparison)
print("\n" + "="*60)
print("MODEL EVALUATION ON VALIDATION SET")
print("="*60)

val_predictions = best_model.predict(val_gen, verbose=1)
val_metrics = calculate_all_metrics(val_labels, val_predictions, "Best Model (Validation Set)")
val_errors = error_analysis(val_labels, val_predictions, "Best Model (Validation Set)")

# %%
# Cell 33: Compare Test vs Validation Performance
comparison_results = {
    'validation': val_metrics,
    'test': test_metrics
}

comparison_df = pd.DataFrame(comparison_results).T
print("\n" + "="*60)
print("VALIDATION VS TEST COMPARISON")
print("="*60)
print(comparison_df.to_string())
print("\n")

# Check for overfitting
mae_diff = test_metrics['mae'] - val_metrics['mae']
rmse_diff = test_metrics['rmse'] - val_metrics['rmse']

print(f"MAE Difference (Test - Val):  {mae_diff:+.4f}")
print(f"RMSE Difference (Test - Val): {rmse_diff:+.4f}")

if mae_diff > 1.0:
    print("⚠️  Warning: Significant performance drop on test set - possible overfitting")
elif mae_diff < -1.0:
    print(" Model generalizes better on test set")
else:
    print(" Model shows consistent performance across validation and test sets")
# Out:
# ============================================================
# MODEL EVALUATION ON VALIDATION SET
# ============================================================
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 8
#       5 print("="*60)
#       7 val_predictions = best_model.predict(val_gen, verbose=1)
# ----> 8 val_metrics = calculate_all_metrics(val_labels, val_predictions, "Best Model (Validation Set)")
#       9 val_errors = error_analysis(val_labels, val_predictions, "Best Model (Validation Set)")
#      11 # %%
#      12 # Cell 33: Compare Test vs Validation Performance
#
# Cell In[25], line 26, in calculate_all_metrics(y_true, y_pred, model_name)
#      23 y_pred = np.array(y_pred).flatten()
#      25 # Standard metrics
# ---> 26 mae = mean_absolute_error(y_true, y_pred)
#      27 mse = mean_squared_error(y_true, y_pred)
#      28 rmse = np.sqrt(mse)
#
# File ~/miniconda3/envs/tfgpu3.11/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/miniconda3/envs/tfgpu3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:284, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     228 """Mean absolute error regression loss.
#     229
#     230 The mean absolute error is a non-negative floating point value, where best value
#    (...)    279 0.85...
#     280 """
#     281 xp, _ = get_namespace(y_true, y_pred, sample_weight, multioutput)
#     283 _, y_true, y_pred, sample_weight, multioutput = (
# --> 284     _check_reg_targets_with_floating_dtype(
#     285         y_true, y_pred, sample_weight, multioutput, xp=xp
#     286     )
#     287 )
#     289 output_errors = _average(
#     290     xp.abs(y_pred - y_true), weights=sample_weight, axis=0, xp=xp
#     291 )
#     292 if isinstance(multioutput, str):
#
# File ~/miniconda3/envs/tfgpu3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:209, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     160 """Ensures y_true, y_pred, and sample_weight correspond to same regression task.
#     161
#     162 Extends `_check_reg_targets` by automatically selecting a suitable floating-point
#    (...)    205     correct keyword.
#     206 """
#     207 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 209 y_type, y_true, y_pred, sample_weight, multioutput = _check_reg_targets(
#     210     y_true, y_pred, sample_weight, multioutput, dtype=dtype_name, xp=xp
#     211 )
#     213 return y_type, y_true, y_pred, sample_weight, multioutput
#
# File ~/miniconda3/envs/tfgpu3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:114, in _check_reg_targets(y_true, y_pred, sample_weight, multioutput, dtype, xp)
#      63 """Check that y_true, y_pred and sample_weight belong to the same regression task.
#      64
#      65 To reduce redundancy when calling `_find_matching_floating_dtype`,
#    (...)    110     correct keyword.
#     111 """
#     112 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
# --> 114 check_consistent_length(y_true, y_pred, sample_weight)
#     115 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     116 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/miniconda3/envs/tfgpu3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [67877, 67584]

# %%
# %%
# Cell 34: Create Comprehensive Visualization
plot_comprehensive_results(
    test_labels, 
    test_predictions, 
    test_errors, 
    test_metrics,
    history
)

# %%
# Out:
# 📊 Comprehensive evaluation plot saved as 'comprehensive_evaluation.png'

# %%
# Cell 35: Save All Results
# save_results_to_file(comparison_results, 'final_evaluation_results.txt')

# %%
# Cell 36: Prediction Samples Analysis
def show_prediction_samples(y_true, y_pred, n_samples=20):
    """Show sample predictions for inspection"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Random samples
    indices = np.random.choice(len(y_true), min(n_samples, len(y_true)), replace=False)
    
    print("\n" + "="*80)
    print("SAMPLE PREDICTIONS")
    print("="*80)
    print(f"{'Index':<8} {'True RUL':<12} {'Pred RUL':<12} {'Error':<12} {'Abs Error':<12} {'Type':<12}")
    print("-"*80)
    
    for idx in sorted(indices):
        true_val = y_true[idx]
        pred_val = y_pred[idx]
        error = pred_val - true_val
        abs_error = abs(error)
        pred_type = "Late (Risk)" if error < 0 else "Early (Safe)"
        
        print(f"{idx:<8} {true_val:<12.2f} {pred_val:<12.2f} {error:<+12.2f} {abs_error:<12.2f} {pred_type:<12}")
    
    print("="*80 + "\n")

show_prediction_samples(test_labels, test_predictions, n_samples=20)

# %%
# Cell 37: Best and Worst Predictions
def show_best_worst_predictions(y_true, y_pred, n=10):
    """Show best and worst predictions"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    abs_errors = np.abs(errors)
    
    # Best predictions (lowest error)
    best_indices = np.argsort(abs_errors)[:n]
    
    print("\n" + "="*80)
    print(f"TOP {n} BEST PREDICTIONS (Lowest Absolute Error)")
    print("="*80)
    print(f"{'Index':<8} {'True RUL':<12} {'Pred RUL':<12} {'Error':<12} {'Abs Error':<12}")
    print("-"*80)
    
    for idx in best_indices:
        print(f"{idx:<8} {y_true[idx]:<12.2f} {y_pred[idx]:<12.2f} {errors[idx]:<+12.2f} {abs_errors[idx]:<12.2f}")
    
    # Worst predictions (highest error)
    worst_indices = np.argsort(abs_errors)[-n:][::-1]
    
    print("\n" + "="*80)
    print(f"TOP {n} WORST PREDICTIONS (Highest Absolute Error)")
    print("="*80)
    print(f"{'Index':<8} {'True RUL':<12} {'Pred RUL':<12} {'Error':<12} {'Abs Error':<12} {'Type':<12}")
    print("-"*80)
    
    for idx in worst_indices:
        pred_type = "Late (Risk)" if errors[idx] < 0 else "Early (Safe)"
        print(f"{idx:<8} {y_true[idx]:<12.2f} {y_pred[idx]:<12.2f} {errors[idx]:<+12.2f} {abs_errors[idx]:<12.2f} {pred_type:<12}")
    
    print("="*80 + "\n")

show_best_worst_predictions(test_labels, test_predictions, n=10)
# Out:
# ================================================================================
# SAMPLE PREDICTIONS
# ================================================================================
# Index    True RUL     Pred RUL     Error        Abs Error    Type
# --------------------------------------------------------------------------------
# 25602    21.00        23.73        +2.73        2.73         Early (Safe)
# 31544    11.00        0.00         -11.00       11.00        Late (Risk)
# 48089    40.00        55.21        +15.21       15.21        Early (Safe)
# 51890    32.00        45.64        +13.64       13.64        Early (Safe)
# 74865    65.00        41.28        -23.72       23.72        Late (Risk)
# 79836    37.00        27.12        -9.88        9.88         Late (Risk)
# 83645    14.00        0.00         -14.00       14.00        Late (Risk)
# 86612    76.00        58.01        -17.99       17.99        Late (Risk)
# 88264    73.00        58.54        -14.46       14.46        Late (Risk)
# 95030    61.00        58.50        -2.50        2.50         Late (Risk)
# 99017    53.00        48.37        -4.63        4.63         Late (Risk)
# 104596   43.00        37.49        -5.51        5.51         Late (Risk)
# 105364   42.00        38.40        -3.60        3.60         Late (Risk)
# 124924   9.00         0.00         -9.00        9.00         Late (Risk)
# 136411   39.00        40.45        +1.45        1.45         Early (Safe)
# 136614   38.00        46.17        +8.17        8.17         Early (Safe)
# 143174   1.00         0.00         -1.00        1.00         Late (Risk)
# 143885   65.00        61.93        -3.07        3.07         Late (Risk)
# 147574   55.00        62.53        +7.53        7.53         Early (Safe)
# 160821   19.00        25.18        +6.18        6.18         Early (Safe)
# ================================================================================
#
#
# ================================================================================
# TOP 10 BEST PREDICTIONS (Lowest Absolute Error)
# ================================================================================
# Index    True RUL     Pred RUL     Error        Abs Error
# --------------------------------------------------------------------------------
# 100161   52.00        52.00        +0.00        0.00
# 106987   40.00        40.00        -0.00        0.00
# 2400     62.00        62.00        -0.00        0.00
# 132713   59.00        59.00        -0.00        0.00
# 102288   48.00        48.00        +0.00        0.00
# 101061   50.00        50.00        -0.00        0.00
# 110512   34.00        34.00        -0.00        0.00
# 79009    42.00        42.00        -0.00        0.00
# 96876    57.00        57.00        +0.00        0.00
# 78501    45.00        45.00        -0.00        0.00
#
# ================================================================================
# TOP 10 WORST PREDICTIONS (Highest Absolute Error)
# ================================================================================
# Index    True RUL     Pred RUL     Error        Abs Error    Type
# --------------------------------------------------------------------------------
# 70418    91.00        48.10        -42.90       42.90        Late (Risk)
# 70461    91.00        48.17        -42.83       42.83        Late (Risk)
# 71904    82.00        39.79        -42.21       42.21        Late (Risk)
# 71141    86.00        43.82        -42.18       42.18        Late (Risk)
# 70309    91.00        48.89        -42.11       42.11        Late (Risk)
# 70310    91.00        49.20        -41.80       41.80        Late (Risk)
# 71140    86.00        44.35        -41.65       41.65        Late (Risk)
# 70142    92.00        50.48        -41.52       41.52        Late (Risk)
# 71905    82.00        40.49        -41.51       41.51        Late (Risk)
# 71138    86.00        44.58        -41.42       41.42        Late (Risk)
# ================================================================================

# %%
# %%
# Cell 38: RUL Range Analysis
def analyze_by_rul_ranges(y_true, y_pred):
    """Analyze performance across different RUL ranges"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Define RUL ranges
    ranges = [
        (0, 25, "Critical (0-25)"),
        (25, 50, "High Risk (25-50)"),
        (50, 75, "Medium Risk (50-75)"),
        (75, 100, "Low Risk (75-100)"),
        (100, 150, "Safe (100+)")
    ]
    
    print("\n" + "="*90)
    print("PERFORMANCE BY RUL RANGE")
    print("="*90)
    print(f"{'Range':<20} {'Count':<10} {'MAE':<10} {'RMSE':<10} {'NASA Score':<15} {'Late%':<10}")
    print("-"*90)
    
    for min_rul, max_rul, label in ranges:
        mask = (y_true >= min_rul) & (y_true < max_rul)
        if np.sum(mask) == 0:
            continue
            
        range_true = y_true[mask]
        range_pred = y_pred[mask]
        
        range_mae = mean_absolute_error(range_true, range_pred)
        range_rmse = np.sqrt(mean_squared_error(range_true, range_pred))
        range_score = score_metric_fn(range_true, range_pred)
        
        range_errors = range_pred - range_true
        late_pct = np.sum(range_errors < 0) / len(range_errors) * 100
        
        print(f"{label:<20} {len(range_true):<10} {range_mae:<10.2f} {range_rmse:<10.2f} {range_score:<15.2f} {late_pct:<10.1f}%")
    
    print("="*90 + "\n")

analyze_by_rul_ranges(test_labels, test_predictions)

# %%
# Out:
# ==========================================================================================
# PERFORMANCE BY RUL RANGE
# ==========================================================================================
# Range                Count      MAE        RMSE       NASA Score      Late%
# ------------------------------------------------------------------------------------------
# Critical (0-25)      58977      6.90       8.47       65531.59        55.2      %
# High Risk (25-50)    59907      9.15       10.47      108438.52       15.6      %
# Medium Risk (50-75)  44247      7.35       9.29       45704.16        68.2      %
# Low Risk (75-100)    4457       26.53      27.36      34340.80        100.0     %
# ==========================================================================================

# %%
# Cell 39: Create Summary Report
def create_summary_report():
    """Generate a comprehensive summary report"""
    print("\n" + "="*80)
    print(" "*25 + "FINAL SUMMARY REPORT")
    print("="*80)
    
    print("\n📊 MODEL CONFIGURATION")
    print("-"*80)
    print(f"Window Size:              {WINDOW_SIZE}")
    print(f"Stride:                   {STRIDE}")
    print(f"Batch Size:               {BATCH_SIZE}")
    print(f"Max RUL Clipping:         {MAX_RUL}")
    print(f"Input Features:           {train_data.shape[2]}")
    print(f"Total Parameters:         {best_model.count_params():,}")
    
    print("\n📈 DATASET INFORMATION")
    print("-"*80)
    print(f"Training Samples:         {train_data.shape[0]:,}")
    print(f"Validation Samples:       {val_data.shape[0]:,}")
    print(f"Test Samples:             {test_data.shape[0]:,}")
    print(f"Training Units:           {len(train_units)}")
    print(f"Validation Units:         {len(val_units)}")
    
    print("\n🎯 PERFORMANCE METRICS")
    print("-"*80)
    print("\nValidation Set:")
    for metric, value in val_metrics.items():
        print(f"  {metric.upper():<20s}: {value:.4f}")
    
    print("\nTest Set:")
    for metric, value in test_metrics.items():
        print(f"  {metric.upper():<20s}: {value:.4f}")
    
    print("\n⚠️  RISK ANALYSIS")
    print("-"*80)
    test_errors = test_predictions.flatten() - test_labels.flatten()
    late_count = np.sum(test_errors < 0)
    early_count = np.sum(test_errors > 0)
    
    print(f"Late Predictions (Under-prediction):   {late_count:>6} ({late_count/len(test_errors)*100:>5.1f}%)")
    print(f"Early Predictions (Over-prediction):   {early_count:>6} ({early_count/len(test_errors)*100:>5.1f}%)")
    print(f"\nMean Bias:                             {np.mean(test_errors):>+7.2f}")
    
    if np.mean(test_errors) < -2:
        print("⚠️  Model tends to under-predict (late predictions) - Higher risk!")
    elif np.mean(test_errors) > 2:
        print(" Model tends to over-predict (early predictions) - More conservative")
    else:
        print(" Model is well-balanced")
    
    print("\n" + "="*80)
    print(" "*20 + "END OF SUMMARY REPORT")
    print("="*80 + "\n")

create_summary_report()
# Out:
# ================================================================================
#                          FINAL SUMMARY REPORT
# ================================================================================
#
# 📊 MODEL CONFIGURATION
# --------------------------------------------------------------------------------
# Window Size:              50
# Stride:                   25
# Batch Size:               2048
# Max RUL Clipping:         125
# Input Features:           90
# Total Parameters:         398,133
#
# 📈 DATASET INFORMATION
# --------------------------------------------------------------------------------
# Training Samples:         151,566
# Validation Samples:       67,877
# Test Samples:             167,588
# Training Units:           7
# Validation Units:         2
#
# 🎯 PERFORMANCE METRICS
# --------------------------------------------------------------------------------
#
# Validation Set:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 56
#      53     print(" "*20 + "END OF SUMMARY REPORT")
#      54     print("="*80 + "\n")
# ---> 56 create_summary_report()
#
# Cell In[32], line 28, in create_summary_report()
#      26 print("-"*80)
#      27 print("\nValidation Set:")
# ---> 28 for metric, value in val_metrics.items():
#      29     print(f"  {metric.upper():<20s}: {value:.4f}")
#      31 print("\nTest Set:")
#
# NameError: name 'val_metrics' is not defined

# %%
# %%
# Cell 40: Export Predictions to CSV
def export_predictions(y_true, y_pred, filename='predictions.csv'):
    """Export predictions to CSV file"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    
    df_pred = pd.DataFrame({
        'True_RUL': y_true,
        'Predicted_RUL': y_pred,
        'Error': errors,
        'Absolute_Error': np.abs(errors),
        'Prediction_Type': ['Late' if e < 0 else 'Early' for e in errors]
    })
    
    # df_pred.to_csv(filename, index=False)
    print(f" Predictions exported to '{filename}'")
    print(f"   Total records: {len(df_pred)}")
    
    return df_pred

predictions_df = export_predictions(test_labels, test_predictions, 'test_predictions.csv')
predictions_df.head(10)

# %%
# %%
# Cell 41: Final Model Summary
print("\n" + "🎉"*40)
print("\n" + " "*25 + "TRAINING COMPLETED SUCCESSFULLY!")
print("\n" + "🎉"*40)
print("\n📁 Generated Files:")
print("   - best_improved_model.keras (trained model)")
print("   - best_model.weights.h5 (model weights)")
print("   - comprehensive_evaluation.png (visualizations)")
print("   - final_evaluation_results.txt (metrics)")
print("   - test_predictions.csv (predictions)")
print("\n" + "="*80)

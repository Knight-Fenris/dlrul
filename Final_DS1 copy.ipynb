# %%
import gc
gc.collect()
import numpy as np
import pandas as pd
import os
import h5py
import time
import matplotlib.pyplot as plt
from pprint import pprint
# %matplotlib inline

# TPU initialization moved to top for better efficiency
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.metrics import R2Score as RSquare
from sklearn.preprocessing import StandardScaler

# Fixed TPU strategy setup for Kaggle TPUv5
# try:
#     tpu = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='local')
#     tf.config.experimental_connect_to_cluster(tpu)
#     tf.tpu.experimental.initialize_tpu_system(tpu)
#     tpu_strategy = tf.distribute.TPUStrategy(tpu)
#     print(f"Running on TPU with {tpu_strategy.num_replicas_in_sync} cores")
# except (ValueError, RuntimeError):
tpu_strategy = tf.distribute.get_strategy()
print("Running on CPU/GPU")

all_files=[]
for dirname, _, filenames in os.walk('./data_set'):
    for filename in filenames:
        all_files.append(os.path.join(dirname, filename))
all_files.sort()
pprint(all_files)
# Out:
# Running on CPU/GPU
# ['./data_set/N-CMAPSS_DS01-005.h5',
#  './data_set/N-CMAPSS_DS02-006.h5',
#  './data_set/N-CMAPSS_DS03-012.h5',
#  './data_set/N-CMAPSS_DS04.h5',
#  './data_set/N-CMAPSS_DS05.h5',
#  './data_set/N-CMAPSS_DS06.h5',
#  './data_set/N-CMAPSS_DS07.h5',
#  './data_set/N-CMAPSS_DS08a-009.h5',
#  './data_set/N-CMAPSS_DS08c-008.h5',
#  './data_set/N-CMAPSS_DS08d-010.h5',
#  './data_set/N-CMAPSS_Example_data_loading_and_exploration.ipynb',
#  './data_set/Run_to_Failure_Simulation_Under_Real_Flight_Conditions_Dataset.pdf',
#  './data_set/data-06-00005-v2.pdf',
#  './data_set/flight_profile_DS02.png',
#  './data_set/kde_DS02.png']

# %%
def read_hdf(filename):
    t = time.process_time()  
    with h5py.File(filename, 'r') as hdf:
        # Development set
        W_dev = np.array(hdf.get('W_dev'), dtype=np.float32)
        X_s_dev = np.array(hdf.get('X_s_dev'), dtype=np.float32)
        X_v_dev = np.array(hdf.get('X_v_dev'), dtype=np.float32)
        T_dev = np.array(hdf.get('T_dev'), dtype=np.float32)
        Y_dev = np.array(hdf.get('Y_dev'), dtype=np.float32)
        A_dev = np.array(hdf.get('A_dev'), dtype=np.float32)

        # Test set
        W_test = np.array(hdf.get('W_test'), dtype=np.float32)
        X_s_test = np.array(hdf.get('X_s_test'), dtype=np.float32)
        X_v_test = np.array(hdf.get('X_v_test'), dtype=np.float32)
        T_test = np.array(hdf.get('T_test'), dtype=np.float32)
        Y_test = np.array(hdf.get('Y_test'), dtype=np.float32)
        A_test = np.array(hdf.get('A_test'), dtype=np.float32)
        
        # Varnams
        W_var = np.array(hdf.get('W_var'))
        X_s_var = np.array(hdf.get('X_s_var'))  
        X_v_var = np.array(hdf.get('X_v_var')) 
        T_var = np.array(hdf.get('T_var'))
        A_var = np.array(hdf.get('A_var'))
        
        # from np.array to list dtype U4/U5
        W_var = list(np.array(W_var, dtype='U20'))
        X_s_var = list(np.array(X_s_var, dtype='U20'))  
        X_v_var = list(np.array(X_v_var, dtype='U20')) 
        T_var = list(np.array(T_var, dtype='U20'))
        A_var = list(np.array(A_var, dtype='U20'))
                        
    ## Train data
    df_a_dev=pd.DataFrame(A_dev,columns=A_var)
    df_t_dev=pd.DataFrame(T_dev,columns=T_var)
    df_w_dev=pd.DataFrame(W_dev,columns=W_var)
    df_xs_dev=pd.DataFrame(X_s_dev,columns=X_s_var)
    df_xv_dev=pd.DataFrame(X_v_dev,columns=X_v_var)
    df_y_dev=pd.DataFrame(Y_dev,columns=['RUL'])

    #get rul
    trainy=df_y_dev[['RUL']]

    #get x from sensors values
    trainx=pd.concat([df_xs_dev,df_w_dev],axis=1)

    print(type(trainy),trainy.shape, type(trainx), trainx.shape)

    ## Test data
    df_a_test=pd.DataFrame(A_test,columns=A_var)
    df_t_test=pd.DataFrame(T_test,columns=T_var)
    df_w_test=pd.DataFrame(W_test,columns=W_var)
    df_xs_test=pd.DataFrame(X_s_test,columns=X_s_var)
    df_xv_test=pd.DataFrame(X_v_test,columns=X_v_var)
    df_y_test=pd.DataFrame(Y_test,columns=['RUL'])

    #get health state from aux
    testy=df_y_test[['RUL']]

    #get x from sensors values
    testx=pd.concat([df_xs_test,df_w_test],axis=1)

    print(type(testy),testy.shape, type(testx), testx.shape)

    print('')
    print("Operation time (min): " , (time.process_time()-t)/60)
    print('')

    return (trainx,trainy,df_a_dev,testx,testy,df_a_test)

# %%
curr_file=all_files[0]
print(curr_file)
# Out:
# ./data_set/N-CMAPSS_DS01-005.h5

# %%
trainx,trainy,adev,testx,testy,atest = read_hdf(filename=curr_file)
# Out:
# <class 'pandas.core.frame.DataFrame'> (4906636, 1) <class 'pandas.core.frame.DataFrame'> (4906636, 18)
# <class 'pandas.core.frame.DataFrame'> (2735232, 1) <class 'pandas.core.frame.DataFrame'> (2735232, 18)
#
# Operation time (min):  0.03797399833333325

# %%
trainx.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4906636 entries, 0 to 4906635
# Data columns (total 18 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   T24     4906636 non-null  float32
#  1   T30     4906636 non-null  float32
#  2   T48     4906636 non-null  float32
#  3   T50     4906636 non-null  float32
#  4   P15     4906636 non-null  float32
#  5   P2      4906636 non-null  float32
#  6   P21     4906636 non-null  float32
#  7   P24     4906636 non-null  float32
#  8   Ps30    4906636 non-null  float32
#  9   P40     4906636 non-null  float32
#  10  P50     4906636 non-null  float32
#  11  Nf      4906636 non-null  float32
#  12  Nc      4906636 non-null  float32
#  13  Wf      4906636 non-null  float32
#  14  alt     4906636 non-null  float32
#  15  Mach    4906636 non-null  float32
#  16  TRA     4906636 non-null  float32
#  17  T2      4906636 non-null  float32
# dtypes: float32(18)
# memory usage: 336.9 MB

# %%
trainx.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4906636 entries, 0 to 4906635
# Data columns (total 18 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   T24     4906636 non-null  float32
#  1   T30     4906636 non-null  float32
#  2   T48     4906636 non-null  float32
#  3   T50     4906636 non-null  float32
#  4   P15     4906636 non-null  float32
#  5   P2      4906636 non-null  float32
#  6   P21     4906636 non-null  float32
#  7   P24     4906636 non-null  float32
#  8   Ps30    4906636 non-null  float32
#  9   P40     4906636 non-null  float32
#  10  P50     4906636 non-null  float32
#  11  Nf      4906636 non-null  float32
#  12  Nc      4906636 non-null  float32
#  13  Wf      4906636 non-null  float32
#  14  alt     4906636 non-null  float32
#  15  Mach    4906636 non-null  float32
#  16  TRA     4906636 non-null  float32
#  17  T2      4906636 non-null  float32
# dtypes: float32(18)
# memory usage: 336.9 MB

# %%
trainx.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4906636 entries, 0 to 4906635
# Data columns (total 18 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   T24     4906636 non-null  float32
#  1   T30     4906636 non-null  float32
#  2   T48     4906636 non-null  float32
#  3   T50     4906636 non-null  float32
#  4   P15     4906636 non-null  float32
#  5   P2      4906636 non-null  float32
#  6   P21     4906636 non-null  float32
#  7   P24     4906636 non-null  float32
#  8   Ps30    4906636 non-null  float32
#  9   P40     4906636 non-null  float32
#  10  P50     4906636 non-null  float32
#  11  Nf      4906636 non-null  float32
#  12  Nc      4906636 non-null  float32
#  13  Wf      4906636 non-null  float32
#  14  alt     4906636 non-null  float32
#  15  Mach    4906636 non-null  float32
#  16  TRA     4906636 non-null  float32
#  17  T2      4906636 non-null  float32
# dtypes: float32(18)
# memory usage: 336.9 MB

# %%
# Standard scale with memory optimization
sc=StandardScaler()
sc.fit(trainx.values)
trainx_l_sc=sc.transform(trainx.values).astype(np.float32)
testx_l_sc=sc.transform(testx.values).astype(np.float32)

print(trainx_l_sc.shape, testx_l_sc.shape, trainy.shape, testy.shape)

trainx_l_sc=pd.DataFrame(trainx_l_sc,columns=trainx.columns)
testx_l_sc=pd.DataFrame(testx_l_sc,columns=trainx.columns)

print(trainx_l_sc.shape, testx_l_sc.shape, trainy.shape, testy.shape)
# Out:
# (4906636, 18) (2735232, 18) (4906636, 1) (2735232, 1)
# (4906636, 18) (2735232, 18) (4906636, 1) (2735232, 1)

# %%
def time_window_slicing_sample(input_array, window_length, unit, sequence_cols, stride=1):
    window_lst = []
    input_temp = input_array[input_array['unit'] == unit][sequence_cols].values.astype(np.float32)
    print ("Unit%s input array shape: " %unit, input_temp.shape)
    num_samples = int((input_temp.shape[0] - window_length)/stride) + 1

    for i in range(num_samples):
        window = input_temp[i*stride:i*stride + window_length,:]
        window_lst.append(window)

    sample_array = np.dstack(window_lst).astype(np.float32)
    print ("sample_array.shape", sample_array.shape)
    return sample_array

def time_window_slicing_label(input_array, window_length, unit, sequence_cols = 'RUL', stride=1):
    window_lst = []
    input_temp = input_array[input_array['unit'] == unit][sequence_cols].values.astype(np.float32)
    num_samples = int((input_temp.shape[0] - window_length)/stride) + 1
    for i in range(num_samples):
        window = input_temp[i*stride:i*stride + window_length]
        window_lst.append(window)

    label_array = np.asarray(window_lst).astype(np.float32)
    return label_array[:,-1]

# %%
trainy = trainy[trainy!=0].dropna()
trainx_l_sc = trainx_l_sc.loc[trainy.index]
testy = testy[testy!=0].dropna()
testx_l_sc = testx_l_sc.loc[testy.index]

print(trainx_l_sc.shape, trainy.shape, testy.shape, testx_l_sc.shape)
# Out:
# (4849640, 18) (4849640, 1) (2699669, 1) (2699669, 18)

# %%
df=trainx_l_sc.copy()
df['unit']=adev['unit']
df['RUL']=trainy['RUL']

# %%
# Optimized windowing with reduced window size for memory efficiency
WINDOW_SIZE = 30  # Reduced from 50
STRIDE = 15      # Reduced from 25

all_units_data=[]
for un in adev.unit.unique():
    all_units_data.append(time_window_slicing_sample(df, WINDOW_SIZE, un, df.columns.difference(['unit','RUL']), STRIDE))

all_units_data=np.dstack(all_units_data)
all_units_data=all_units_data.transpose(2,0,1)
print(all_units_data.shape)
# Out:
# Unit1.0 input array shape:  (429144, 18)
# sample_array.shape (30, 18, 28608)
# Unit2.0 input array shape:  (1034408, 18)
# sample_array.shape (30, 18, 28608)
# Unit2.0 input array shape:  (1034408, 18)
# sample_array.shape (30, 18, 68959)
# Unit3.0 input array shape:  (882856, 18)
# sample_array.shape (30, 18, 58856)
# Unit4.0 input array shape:  (409991, 18)
# sample_array.shape (30, 18, 68959)
# Unit3.0 input array shape:  (882856, 18)
# sample_array.shape (30, 18, 58856)
# Unit4.0 input array shape:  (409991, 18)
# sample_array.shape (30, 18, 27331)
# Unit5.0 input array shape:  (1266631, 18)
# sample_array.shape (30, 18, 27331)
# Unit5.0 input array shape:  (1266631, 18)
# sample_array.shape (30, 18, 84441)
# Unit6.0 input array shape:  (826610, 18)
# sample_array.shape (30, 18, 55106)
# sample_array.shape (30, 18, 84441)
# Unit6.0 input array shape:  (826610, 18)
# sample_array.shape (30, 18, 55106)
# (323301, 30, 18)
# (323301, 30, 18)

# %%
all_labels=[]
for un in adev.unit.unique():
    all_labels=all_labels+time_window_slicing_label(df, WINDOW_SIZE, un, stride=STRIDE).tolist()

print(len(all_labels))
all_labels=np.array(all_labels, dtype=np.float32)
# Out:
# 323301

# %%
#test data
df=testx_l_sc.copy()
df['unit']=atest['unit']
df['RUL']=testy['RUL']

test_units_data=[]
for un in atest.unit.unique():
    test_units_data.append(time_window_slicing_sample(df, WINDOW_SIZE, un, df.columns.difference(['unit','RUL']), STRIDE))

test_units_data=np.dstack(test_units_data)
test_units_data=test_units_data.transpose(2,0,1)
print(test_units_data.shape)

test_labels=[]
for un in atest.unit.unique():
    test_labels=test_labels+time_window_slicing_label(df, WINDOW_SIZE, un, stride=STRIDE).tolist()

print(len(test_labels))
test_labels=np.array(test_labels, dtype=np.float32)
# Out:
# Unit7.0 input array shape:  (387207, 18)
# sample_array.shape (30, 18, 25812)
# Unit8.0 input array shape:  (790404, 18)
# Unit8.0 input array shape:  (790404, 18)
# sample_array.shape (30, 18, 52692)
# Unit9.0 input array shape:  (347023, 18)
# sample_array.shape (30, 18, 52692)
# Unit9.0 input array shape:  (347023, 18)
# sample_array.shape (30, 18, 23133)
# Unit10.0 input array shape:  (1175035, 18)
# sample_array.shape (30, 18, 23133)
# Unit10.0 input array shape:  (1175035, 18)
# sample_array.shape (30, 18, 78334)
# (179971, 30, 18)
# sample_array.shape (30, 18, 78334)
# (179971, 30, 18)
# 179971
# 179971

# %%
from sklearn.model_selection import train_test_split
xtrain,xval,ytrain,yval=train_test_split(all_units_data,all_labels,test_size=0.2, random_state=42)

ytrain = ytrain.reshape([-1, 1])
yval = yval.reshape([-1, 1])
test_labels = test_labels.reshape([-1, 1])

# ✅ Standardize RUL targets using StandardScaler
rul_scaler = StandardScaler()
rul_scaler.fit(ytrain)  # Fit only on training data to avoid data leakage
ytrain = rul_scaler.transform(ytrain).astype(np.float32)
yval = rul_scaler.transform(yval).astype(np.float32)
test_labels = rul_scaler.transform(test_labels).astype(np.float32)

print(f"Final shapes - Train: {xtrain.shape}, Val: {xval.shape}, Test: {test_units_data.shape}")
print(f"✅ RUL Standardization Stats:")
print(f"  Mean: {rul_scaler.mean_[0]:.2f}, Std: {rul_scaler.scale_[0]:.2f}")
print(f"  ytrain - Min: {ytrain.min():.4f}, Max: {ytrain.max():.4f}, Mean: {ytrain.mean():.4f}")
print(f"  yval - Min: {yval.min():.4f}, Max: {yval.max():.4f}, Mean: {yval.mean():.4f}")
print(f"  test_labels - Min: {test_labels.min():.4f}, Max: {test_labels.max():.4f}, Mean: {test_labels.mean():.4f}")

# Clean up memory
del all_units_data, all_labels, adev, trainx, trainy, trainx_l_sc
gc.collect()
# Out:
# Final shapes - Train: (258640, 30, 18), Val: (64661, 30, 18), Test: (179971, 30, 18)
# ✅ RUL Standardization Stats:
#   Mean: 45.33, Std: 26.35
#   ytrain - Min: -1.6826, Max: 2.0372, Mean: -0.0000
#   yval - Min: -1.6826, Max: 2.0372, Mean: 0.0063
#   test_labels - Min: -1.6826, Max: 1.6576, Mean: -0.0990
# 4

# %%
# Optimized batch size for TPUv5 and memory constraints
# Use smaller batch size to avoid memory issues

# BATCH_SIZE = 32
BATCH_SIZE = 2048

BUFFER_SIZE = 5000  # Further reduced buffer size

# Ensure data types
xtrain = xtrain.astype(np.float32)
ytrain = ytrain.astype(np.float32)
xval = xval.astype(np.float32)
yval = yval.astype(np.float32)
test_units_data = test_units_data.astype(np.float32)
test_labels = test_labels.astype(np.float32)

# Optimized tf.data pipeline
train_ds = tf.data.Dataset.from_tensor_slices((xtrain, ytrain))
val_ds = tf.data.Dataset.from_tensor_slices((xval, yval))
test_ds = tf.data.Dataset.from_tensor_slices((test_units_data, test_labels))

AUTOTUNE = tf.data.AUTOTUNE

# More efficient data pipeline with explicit options
train_gen = (
    train_ds
    .shuffle(buffer_size=BUFFER_SIZE, seed=42, reshuffle_each_iteration=False)
    .batch(BATCH_SIZE, drop_remainder=True)
    .cache()
    .prefetch(2)  # Fixed prefetch value instead of AUTOTUNE
)

val_gen = (
    val_ds
    .batch(BATCH_SIZE)
    .cache()
    .prefetch(2)  # Fixed prefetch value
)

test_gen = (
    test_ds
    .batch(BATCH_SIZE)
    .prefetch(2)  # Fixed prefetch value
)

print("✅ Optimized tf.data pipelines created successfully.")
# Out:
# ✅ Optimized tf.data pipelines created successfully.

# %%
# Enhanced transformer encoder for sequential data
class Shape(tf.keras.layers.Layer):
    def call(self,x):
        return tf.shape(x)

def transformer_encoder_v4(inputs, head_size, num_heads, ff_dim, dropout, use_causal_mask=False):
    """Sequential-data optimized transformer block with causal attention option."""
    
    # Pre-LayerNorm for better gradient flow
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs)
    
    # Multi-head attention with causal masking for sequential data
    attention_layer = tf.keras.layers.MultiHeadAttention(
        key_dim=head_size, 
        num_heads=num_heads, 
        dropout=dropout,
        use_bias=False
    )
    
    attention_output = attention_layer(x, x, use_causal_mask=use_causal_mask)    
    attention_output = tf.keras.layers.Dropout(dropout)(attention_output)
    res1 = attention_output + inputs

    # Enhanced feed-forward with residual connections
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(res1)
    
    # Two-layer feed-forward with residual connection
    x_ff = tf.keras.layers.Dense(ff_dim, activation="gelu", use_bias=False)(x)
    x_ff = tf.keras.layers.Dropout(dropout)(x_ff)
    x_ff = tf.keras.layers.Dense(inputs.shape[-1], use_bias=False)(x_ff)
    
    return x_ff + res1

# Positional encoding for sequential data
def positional_encoding_layer(sequence_length, d_model, max_wavelength=10000):
    """Sinusoidal positional encoding for sequential data."""
    position = tf.cast(tf.range(sequence_length)[:, tf.newaxis], dtype=tf.float32)
    div_term = tf.exp(tf.cast(tf.range(0, d_model, 2), dtype=tf.float32) * 
                      -(tf.math.log(float(max_wavelength)) / d_model))
    
    pos_encoding = tf.zeros((sequence_length, d_model))
    pos_encoding = tf.concat([
        tf.sin(position * div_term),
        tf.cos(position * div_term)
    ], axis=-1)
    
    if d_model % 2 == 1:
        pos_encoding = pos_encoding[:, :-1]
    
    return pos_encoding

class PositionalEncoding(tf.keras.layers.Layer):
    """Learnable positional encoding layer for sequential data."""
    def __init__(self, sequence_length, d_model, **kwargs):
        super(PositionalEncoding, self).__init__(**kwargs)
        self.sequence_length = sequence_length
        self.d_model = d_model
        
    def build(self, input_shape):
        self.pos_encoding = self.add_weight(
            name='pos_encoding',
            shape=(self.sequence_length, self.d_model),
            initializer='uniform',
            trainable=True
        )
        super(PositionalEncoding, self).build(input_shape)
    
    def call(self, inputs):
        return inputs + self.pos_encoding

# Temporal convolutional layer for local sequential patterns
def temporal_conv_block(inputs, filters, kernel_size, dropout):
    """1D convolutional block to capture local temporal patterns."""
    x = tf.keras.layers.Conv1D(
        filters=filters, 
        kernel_size=kernel_size, 
        padding='same', 
        activation='gelu',
        use_bias=False
    )(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    
    # Residual connection if dimensions match
    if inputs.shape[-1] == filters:
        x = x + inputs
    
    return x

# %%
import keras_tuner
import keras_nlp
class ReduceSumLayer(tf.keras.layers.Layer):
    def call(self,x):
        return tf.reduce_sum(x,axis=1)
def build_sequential_transformer(hp):
    """Enhanced transformer model specifically designed for sequential RUL prediction."""
    # Reduced input shape due to smaller window
    input_shape = (WINDOW_SIZE, 18)
    
    # Hyperparameters optimized for sequential data
    head_size = hp.Choice("head_size", [8, 16, 32])
    num_heads = hp.Choice("num_heads", [2, 4, 6])  # Even numbers work better
    ff_dim = hp.Choice("ff_dim", [64, 128, 256])
    num_transformer_blocks = hp.Int("num_blocks", min_value=2, max_value=6, step=1)
    mlp_units = hp.Int("mlp_units", min_value=1, max_value=3, step=1)
    learning_rate = hp.Choice("learning_rate", [1e-3, 5e-4, 1e-4, 5e-5])
    
    # Sequential data specific parameters
    # use_causal_mask = True  # For degradation prediction
    use_causal_mask = hp.Boolean("use_causal_mask")  # For degradation prediction
    use_temp_conv = hp.Boolean("use_temp_conv")      # Local temporal patterns
    pos_encoding_type = hp.Choice("pos_encoding", ["learnable", "sinusoidal", "none"])
    
    with tpu_strategy.scope():
        inputs = tf.keras.Input(shape=input_shape)
        x = inputs
        
        # Temporal convolutional preprocessing for local patterns
        if use_temp_conv:
            temp_filters = hp.Choice("temp_filters", [16, 32])
            temp_kernel = hp.Choice("temp_kernel", [3, 5])
            temp_dropout = hp.Float('temp_dropout', min_value=0.1, max_value=0.3, step=0.1)
            x = temporal_conv_block(x, temp_filters, temp_kernel, temp_dropout)
            x = temporal_conv_block(x, input_shape[-1], 1, temp_dropout)  # Project back
        
        # Positional encoding for sequential awareness
        if pos_encoding_type == "learnable":
            x = PositionalEncoding(input_shape[0], input_shape[1])(x)
        elif pos_encoding_type == "sinusoidal":
            pos_enc = positional_encoding_layer(input_shape[0], input_shape[1])
            x = x + pos_enc
        
        # Transformer blocks for long-range dependencies
        for i in range(num_transformer_blocks):
            dropout_rate = hp.Float(f'dropout_{i}', min_value=0.1, max_value=0.4, step=0.1)
            x = transformer_encoder_v4(x, head_size, num_heads, ff_dim, dropout_rate, use_causal_mask)
        
        # Sequence aggregation strategies
        aggregation = hp.Choice("aggregation", ["attention","last", "mean", "max"])
        
        if aggregation == "last":
            # Last timestep - most relevant for RUL
            x = x[:, -1, :]
        elif aggregation == "mean":
            x = tf.keras.layers.GlobalAveragePooling1D()(x)
        elif aggregation == "max":
            x = tf.keras.layers.GlobalMaxPooling1D()(x)
        elif aggregation == "attention":
            # Learnable attention weighting
            attention_weights = tf.keras.layers.Dense(1, activation='softmax')(x)
            # x = tf.reduce_sum(x * attention_weights, axis=1)
            x = ReduceSumLayer()(x*attention_weights)
        
        # Enhanced MLP head with skip connections
        original_dim = x.shape[-1]
        for i in range(mlp_units):
            dim = hp.Choice(f'dim_{i}', [32, 64, 128, 256])
            mlp_dropout = hp.Float(f'mlp_dropout_{i}', min_value=0.1, max_value=0.5, step=0.1)
            mlp_activation = hp.Choice(f'mlp_activ_{i}', ['gelu', 'swish', 'relu'])
            
            x_dense = tf.keras.layers.Dense(dim, activation=mlp_activation, use_bias=False)(x)
            x_dense = tf.keras.layers.BatchNormalization()(x_dense)
            x_dense = tf.keras.layers.Dropout(mlp_dropout)(x_dense)
            
            # Skip connection if dimensions allow
            if i == 0 and original_dim == dim:
                x = x_dense + x
            else:
                x = x_dense
        
        # Final regression layer with optional activation
        final_activation = hp.Choice("final_activation", ["linear", "relu"])
        outputs = tf.keras.layers.Dense(1, activation=final_activation)(x)
        
        model = tf.keras.Model(inputs, outputs)

        # Enhanced optimizer selection with schedule
        optimizer_type = hp.Choice('optimizer', ['adam', 'adamw', 'rmsprop'])
        # use_schedule = hp.Boolean('use_lr_schedule')

        
        if optimizer_type == 'adamw':
            optimizer = tf.keras.optimizers.AdamW(
                learning_rate=learning_rate, 
                weight_decay=1e-4,
                clipnorm=1.0
            )
        elif optimizer_type == 'rmsprop':
            optimizer = tf.keras.optimizers.RMSprop(
                learning_rate=learning_rate,
                clipnorm=1.0
            )
        else:
            optimizer = tf.keras.optimizers.Adam(
                learning_rate=learning_rate,
                clipnorm=1.0
            )
        
        # Enhanced loss function for RUL prediction
        loss_type = hp.Choice('loss', ['mse', 'mae', 'huber'])
        if loss_type == 'huber':
            loss = tf.keras.losses.Huber(delta=1.0)  # Robust to outliers
        elif loss_type == 'mae':
            loss = tf.keras.losses.MeanAbsoluteError()
        else:
            loss = tf.keras.losses.MeanSquaredError()
            
        model.compile(
            loss=loss,
            optimizer=optimizer, 
            metrics=["mean_absolute_error", "mean_squared_error"]
        )
    
    return model

# %%
# Test the sequential model creation
# with tpu_strategy.scope():
#     test_model = build_sequential_transformer(keras_tuner.HyperParameters())
#     test_model.summary()
#     print(f"Model has {test_model.count_params():,} parameters")

# %%
tuner = keras_tuner.BayesianOptimization(
    hypermodel=build_sequential_transformer,
    objective="val_mean_absolute_error",
    max_trials=100,  
    executions_per_trial=2,
    overwrite=False,#set True when training new
    directory="keras_tuner_sequential",
    project_name="sequential_transformer_rul",
    distribution_strategy=tpu_strategy,
    max_consecutive_failed_trials=5
)

# tuner.search_space_summary()
# Out:
# Reloading Tuner from keras_tuner_sequential/sequential_transformer_rul/tuner0.json

# %%
# Enhanced callbacks for sequential training
import os
os.makedirs('checkpoints', exist_ok=True)

# ✅ Store the RUL scaler globally for later inverse transform during evaluation
RUL_SCALER = rul_scaler

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=12, 
        restore_best_weights=True, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.7, 
        patience=5, 
        min_lr=1e-8, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'checkpoints/best_sequential_model.weights.h5', 
        save_best_only=True, 
        save_weights_only=True, 
        monitor='val_loss'
    )
]
# callbacks.append(lr_sche)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Sequential model training with fallback
# try:
#     print("Starting sequential transformer hyperparameter search...")
#     history = tuner.search(
#         train_gen,
#         verbose=2,
#         epochs=100,
#         validation_data=val_gen, 
#         callbacks=callbacks[:2]  # Skip checkpoint for tuning
#     )
    
#     # Get best model
#     with tpu_strategy.scope():
#         best_hps = tuner.get_best_hyperparameters()[0]
#         print("Optimal hyperparameters for sequential model:")
#         for hp_name in best_hps.values.keys():
#             print(f"{hp_name}: {best_hps.get(hp_name)}")
        
#         model = build_sequential_transformer(best_hps)
    
# except Exception as e:
#     print(f"Sequential tuner failed with error: {e}")

# %%
best_hps = tuner.get_best_hyperparameters()[1]

# %%
print("The hyperparameter search is complete. Here are the optimal values:")
for hp_name in best_hps.values.keys():
    print(f"{hp_name}: {best_hps.get(hp_name)}")
# Out:
# The hyperparameter search is complete. Here are the optimal values:
# head_size: 16
# num_heads: 4
# ff_dim: 128
# num_blocks: 6
# mlp_units: 2
# learning_rate: 0.001
# use_causal_mask: False
# use_temp_conv: True
# pos_encoding: none
# dropout_0: 0.2
# dropout_1: 0.1
# aggregation: mean
# dim_0: 128
# mlp_dropout_0: 0.4
# mlp_activ_0: relu
# final_activation: linear
# optimizer: rmsprop
# use_lr_schedule: False
# loss: mae
# temp_filters: 32
# temp_kernel: 3
# temp_dropout: 0.1
# dropout_2: 0.2
# dropout_3: 0.4
# dim_1: 32
# mlp_dropout_1: 0.1
# mlp_activ_1: relu
# dropout_4: 0.30000000000000004
# dim_2: 32
# mlp_dropout_2: 0.2
# mlp_activ_2: relu
# dropout_5: 0.30000000000000004

# %%
# print("The hyperparameter search is complete. Here are the optimal values:")
# for hp_name in best_hps.values.keys():
#     print(f"{hp_name}: {best_hps.get(hp_name)}")
"""
The hyperparameter search is complete. Here are the optimal values:
head_size: 32
num_heads: 6
ff_dim: 64
num_blocks: 3
mlp_units: 3
learning_rate: 0.001
use_causal_mask: False
use_temp_conv: True
pos_encoding: sinusoidal
dropout_0: 0.4
dropout_1: 0.2
aggregation: mean
dim_0: 128
mlp_dropout_0: 0.1
mlp_activ_0: swish
final_activation: linear
optimizer: rmsprop
use_lr_schedule: False
loss: mae
temp_filters: 32
temp_kernel: 3
temp_dropout: 0.1
dropout_2: 0.1
dropout_3: 0.4
dim_1: 64
mlp_dropout_1: 0.2
mlp_activ_1: gelu
dropout_4: 0.30000000000000004
dim_2: 128
mlp_dropout_2: 0.2
mlp_activ_2: swish
dropout_5: 0.2
"""
# Out:
# '\nThe hyperparameter search is complete. Here are the optimal values:\nhead_size: 32\nnum_heads: 6\nff_dim: 64\nnum_blocks: 3\nmlp_units: 3\nlearning_rate: 0.001\nuse_causal_mask: False\nuse_temp_conv: True\npos_encoding: sinusoidal\ndropout_0: 0.4\ndropout_1: 0.2\naggregation: mean\ndim_0: 128\nmlp_dropout_0: 0.1\nmlp_activ_0: swish\nfinal_activation: linear\noptimizer: rmsprop\nuse_lr_schedule: False\nloss: mae\ntemp_filters: 32\ntemp_kernel: 3\ntemp_dropout: 0.1\ndropout_2: 0.1\ndropout_3: 0.4\ndim_1: 64\nmlp_dropout_1: 0.2\nmlp_activ_1: gelu\ndropout_4: 0.30000000000000004\ndim_2: 128\nmlp_dropout_2: 0.2\nmlp_activ_2: swish\ndropout_5: 0.2\n'

# %%
# with tpu_strategy.scope():
#         best_hps = tuner.get_best_hyperparameters()[0]
#         print("Optimal hyperparameters for sequential model:")
#         for hp_name in best_hps.values.keys():
#             print(f"{hp_name}: {best_hps.get(hp_name)}")
        
#         # model2 = build_sequential_transformer(best_hps)

# %%
model2 = tuner.get_best_models(num_models=2)[1]

# %%
# # Final training with best hyperparameters
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=25, 
        restore_best_weights=True, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.7, 
        patience=5, 
        min_lr=1e-8, 
        monitor='val_loss'
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'checkpoints/best4.weights.h5', 
        save_best_only=True, 
        save_weights_only=True, 
        monitor='val_loss'
    )
]

history = model2.fit(
    train_gen, 
    validation_data=val_gen, 
    epochs=200,
    verbose=1,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - loss: 30.9572 - mean_absolute_error: 30.9572 - mean_squared_error: 1294.5979 - val_loss: 23.7203 - val_mean_absolute_error: 23.7203 - val_mean_squared_error: 1141.2677 - learning_rate: 0.0010
# Epoch 2/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - loss: 30.9572 - mean_absolute_error: 30.9572 - mean_squared_error: 1294.5979 - val_loss: 23.7203 - val_mean_absolute_error: 23.7203 - val_mean_squared_error: 1141.2677 - learning_rate: 0.0010
# Epoch 2/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 23.5655 - mean_absolute_error: 23.5655 - mean_squared_error: 867.8338 - val_loss: 18.0460 - val_mean_absolute_error: 18.0460 - val_mean_squared_error: 469.2583 - learning_rate: 0.0010
# Epoch 3/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 23.5655 - mean_absolute_error: 23.5655 - mean_squared_error: 867.8338 - val_loss: 18.0460 - val_mean_absolute_error: 18.0460 - val_mean_squared_error: 469.2583 - learning_rate: 0.0010
# Epoch 3/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 17.2166 - mean_absolute_error: 17.2166 - mean_squared_error: 486.0497 - val_loss: 12.3568 - val_mean_absolute_error: 12.3568 - val_mean_squared_error: 287.7722 - learning_rate: 0.0010
# Epoch 4/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 17.2166 - mean_absolute_error: 17.2166 - mean_squared_error: 486.0497 - val_loss: 12.3568 - val_mean_absolute_error: 12.3568 - val_mean_squared_error: 287.7722 - learning_rate: 0.0010
# Epoch 4/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 11.8840 - mean_absolute_error: 11.8840 - mean_squared_error: 268.2206 - val_loss: 7.6550 - val_mean_absolute_error: 7.6550 - val_mean_squared_error: 156.1655 - learning_rate: 0.0010
# Epoch 5/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 11.8840 - mean_absolute_error: 11.8840 - mean_squared_error: 268.2206 - val_loss: 7.6550 - val_mean_absolute_error: 7.6550 - val_mean_squared_error: 156.1655 - learning_rate: 0.0010
# Epoch 5/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 7.5709 - mean_absolute_error: 7.5709 - mean_squared_error: 119.5088 - val_loss: 5.2449 - val_mean_absolute_error: 5.2449 - val_mean_squared_error: 56.9755 - learning_rate: 0.0010
# Epoch 6/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 7.5709 - mean_absolute_error: 7.5709 - mean_squared_error: 119.5088 - val_loss: 5.2449 - val_mean_absolute_error: 5.2449 - val_mean_squared_error: 56.9755 - learning_rate: 0.0010
# Epoch 6/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 4.2747 - mean_absolute_error: 4.2747 - mean_squared_error: 37.6656 - val_loss: 3.7068 - val_mean_absolute_error: 3.7068 - val_mean_squared_error: 17.4903 - learning_rate: 0.0010
# Epoch 7/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 4.2747 - mean_absolute_error: 4.2747 - mean_squared_error: 37.6656 - val_loss: 3.7068 - val_mean_absolute_error: 3.7068 - val_mean_squared_error: 17.4903 - learning_rate: 0.0010
# Epoch 7/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 1.9879 - mean_absolute_error: 1.9879 - mean_squared_error: 7.0386 - val_loss: 1.8273 - val_mean_absolute_error: 1.8273 - val_mean_squared_error: 3.8753 - learning_rate: 0.0010
# Epoch 8/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 1.9879 - mean_absolute_error: 1.9879 - mean_squared_error: 7.0386 - val_loss: 1.8273 - val_mean_absolute_error: 1.8273 - val_mean_squared_error: 3.8753 - learning_rate: 0.0010
# Epoch 8/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.6844 - mean_absolute_error: 0.6844 - mean_squared_error: 0.7940 - val_loss: 0.7334 - val_mean_absolute_error: 0.7334 - val_mean_squared_error: 0.8316 - learning_rate: 0.0010
# Epoch 9/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.6844 - mean_absolute_error: 0.6844 - mean_squared_error: 0.7940 - val_loss: 0.7334 - val_mean_absolute_error: 0.7334 - val_mean_squared_error: 0.8316 - learning_rate: 0.0010
# Epoch 9/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.3686 - mean_absolute_error: 0.3686 - mean_squared_error: 0.2342 - val_loss: 0.4217 - val_mean_absolute_error: 0.4217 - val_mean_squared_error: 0.3512 - learning_rate: 0.0010
# Epoch 10/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.3686 - mean_absolute_error: 0.3686 - mean_squared_error: 0.2342 - val_loss: 0.4217 - val_mean_absolute_error: 0.4217 - val_mean_squared_error: 0.3512 - learning_rate: 0.0010
# Epoch 10/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.3342 - mean_absolute_error: 0.3342 - mean_squared_error: 0.1961 - val_loss: 0.4798 - val_mean_absolute_error: 0.4798 - val_mean_squared_error: 0.4544 - learning_rate: 0.0010
# Epoch 11/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.3342 - mean_absolute_error: 0.3342 - mean_squared_error: 0.1961 - val_loss: 0.4798 - val_mean_absolute_error: 0.4798 - val_mean_squared_error: 0.4544 - learning_rate: 0.0010
# Epoch 11/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.3134 - mean_absolute_error: 0.3134 - mean_squared_error: 0.1759 - val_loss: 0.3597 - val_mean_absolute_error: 0.3597 - val_mean_squared_error: 0.2855 - learning_rate: 0.0010
# Epoch 12/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.3134 - mean_absolute_error: 0.3134 - mean_squared_error: 0.1759 - val_loss: 0.3597 - val_mean_absolute_error: 0.3597 - val_mean_squared_error: 0.2855 - learning_rate: 0.0010
# Epoch 12/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.3021 - mean_absolute_error: 0.3021 - mean_squared_error: 0.1651 - val_loss: 0.4386 - val_mean_absolute_error: 0.4386 - val_mean_squared_error: 0.3798 - learning_rate: 0.0010
# Epoch 13/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.3021 - mean_absolute_error: 0.3021 - mean_squared_error: 0.1651 - val_loss: 0.4386 - val_mean_absolute_error: 0.4386 - val_mean_squared_error: 0.3798 - learning_rate: 0.0010
# Epoch 13/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2932 - mean_absolute_error: 0.2932 - mean_squared_error: 0.1568 - val_loss: 0.4542 - val_mean_absolute_error: 0.4542 - val_mean_squared_error: 0.3913 - learning_rate: 0.0010
# Epoch 14/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2932 - mean_absolute_error: 0.2932 - mean_squared_error: 0.1568 - val_loss: 0.4542 - val_mean_absolute_error: 0.4542 - val_mean_squared_error: 0.3913 - learning_rate: 0.0010
# Epoch 14/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2864 - mean_absolute_error: 0.2864 - mean_squared_error: 0.1513 - val_loss: 0.3317 - val_mean_absolute_error: 0.3317 - val_mean_squared_error: 0.2259 - learning_rate: 0.0010
# Epoch 15/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2864 - mean_absolute_error: 0.2864 - mean_squared_error: 0.1513 - val_loss: 0.3317 - val_mean_absolute_error: 0.3317 - val_mean_squared_error: 0.2259 - learning_rate: 0.0010
# Epoch 15/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2836 - mean_absolute_error: 0.2836 - mean_squared_error: 0.1489 - val_loss: 0.3565 - val_mean_absolute_error: 0.3565 - val_mean_squared_error: 0.2727 - learning_rate: 0.0010
# Epoch 16/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2836 - mean_absolute_error: 0.2836 - mean_squared_error: 0.1489 - val_loss: 0.3565 - val_mean_absolute_error: 0.3565 - val_mean_squared_error: 0.2727 - learning_rate: 0.0010
# Epoch 16/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2805 - mean_absolute_error: 0.2805 - mean_squared_error: 0.1458 - val_loss: 0.3680 - val_mean_absolute_error: 0.3680 - val_mean_squared_error: 0.2741 - learning_rate: 0.0010
# Epoch 17/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2805 - mean_absolute_error: 0.2805 - mean_squared_error: 0.1458 - val_loss: 0.3680 - val_mean_absolute_error: 0.3680 - val_mean_squared_error: 0.2741 - learning_rate: 0.0010
# Epoch 17/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2772 - mean_absolute_error: 0.2772 - mean_squared_error: 0.1425 - val_loss: 0.3791 - val_mean_absolute_error: 0.3791 - val_mean_squared_error: 0.2952 - learning_rate: 0.0010
# Epoch 18/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2772 - mean_absolute_error: 0.2772 - mean_squared_error: 0.1425 - val_loss: 0.3791 - val_mean_absolute_error: 0.3791 - val_mean_squared_error: 0.2952 - learning_rate: 0.0010
# Epoch 18/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2762 - mean_absolute_error: 0.2762 - mean_squared_error: 0.1414 - val_loss: 0.3345 - val_mean_absolute_error: 0.3345 - val_mean_squared_error: 0.2327 - learning_rate: 0.0010
# Epoch 19/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2762 - mean_absolute_error: 0.2762 - mean_squared_error: 0.1414 - val_loss: 0.3345 - val_mean_absolute_error: 0.3345 - val_mean_squared_error: 0.2327 - learning_rate: 0.0010
# Epoch 19/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2748 - mean_absolute_error: 0.2748 - mean_squared_error: 0.1404 - val_loss: 0.4170 - val_mean_absolute_error: 0.4170 - val_mean_squared_error: 0.3309 - learning_rate: 0.0010
# Epoch 20/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2748 - mean_absolute_error: 0.2748 - mean_squared_error: 0.1404 - val_loss: 0.4170 - val_mean_absolute_error: 0.4170 - val_mean_squared_error: 0.3309 - learning_rate: 0.0010
# Epoch 20/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2640 - mean_absolute_error: 0.2640 - mean_squared_error: 0.1303 - val_loss: 0.3269 - val_mean_absolute_error: 0.3269 - val_mean_squared_error: 0.2087 - learning_rate: 7.0000e-04
# Epoch 21/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2640 - mean_absolute_error: 0.2640 - mean_squared_error: 0.1303 - val_loss: 0.3269 - val_mean_absolute_error: 0.3269 - val_mean_squared_error: 0.2087 - learning_rate: 7.0000e-04
# Epoch 21/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2632 - mean_absolute_error: 0.2632 - mean_squared_error: 0.1298 - val_loss: 0.3617 - val_mean_absolute_error: 0.3617 - val_mean_squared_error: 0.2598 - learning_rate: 7.0000e-04
# Epoch 22/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2632 - mean_absolute_error: 0.2632 - mean_squared_error: 0.1298 - val_loss: 0.3617 - val_mean_absolute_error: 0.3617 - val_mean_squared_error: 0.2598 - learning_rate: 7.0000e-04
# Epoch 22/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2623 - mean_absolute_error: 0.2623 - mean_squared_error: 0.1286 - val_loss: 0.3584 - val_mean_absolute_error: 0.3584 - val_mean_squared_error: 0.2752 - learning_rate: 7.0000e-04
# Epoch 23/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2623 - mean_absolute_error: 0.2623 - mean_squared_error: 0.1286 - val_loss: 0.3584 - val_mean_absolute_error: 0.3584 - val_mean_squared_error: 0.2752 - learning_rate: 7.0000e-04
# Epoch 23/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2608 - mean_absolute_error: 0.2608 - mean_squared_error: 0.1272 - val_loss: 0.3923 - val_mean_absolute_error: 0.3923 - val_mean_squared_error: 0.3136 - learning_rate: 7.0000e-04
# Epoch 24/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2608 - mean_absolute_error: 0.2608 - mean_squared_error: 0.1272 - val_loss: 0.3923 - val_mean_absolute_error: 0.3923 - val_mean_squared_error: 0.3136 - learning_rate: 7.0000e-04
# Epoch 24/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2596 - mean_absolute_error: 0.2596 - mean_squared_error: 0.1264 - val_loss: 0.3093 - val_mean_absolute_error: 0.3093 - val_mean_squared_error: 0.1895 - learning_rate: 7.0000e-04
# Epoch 25/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2596 - mean_absolute_error: 0.2596 - mean_squared_error: 0.1264 - val_loss: 0.3093 - val_mean_absolute_error: 0.3093 - val_mean_squared_error: 0.1895 - learning_rate: 7.0000e-04
# Epoch 25/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2590 - mean_absolute_error: 0.2590 - mean_squared_error: 0.1258 - val_loss: 0.3288 - val_mean_absolute_error: 0.3288 - val_mean_squared_error: 0.2276 - learning_rate: 7.0000e-04
# Epoch 26/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2590 - mean_absolute_error: 0.2590 - mean_squared_error: 0.1258 - val_loss: 0.3288 - val_mean_absolute_error: 0.3288 - val_mean_squared_error: 0.2276 - learning_rate: 7.0000e-04
# Epoch 26/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2584 - mean_absolute_error: 0.2584 - mean_squared_error: 0.1253 - val_loss: 0.3238 - val_mean_absolute_error: 0.3238 - val_mean_squared_error: 0.2202 - learning_rate: 7.0000e-04
# Epoch 27/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2584 - mean_absolute_error: 0.2584 - mean_squared_error: 0.1253 - val_loss: 0.3238 - val_mean_absolute_error: 0.3238 - val_mean_squared_error: 0.2202 - learning_rate: 7.0000e-04
# Epoch 27/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2591 - mean_absolute_error: 0.2591 - mean_squared_error: 0.1256 - val_loss: 0.3305 - val_mean_absolute_error: 0.3305 - val_mean_squared_error: 0.2248 - learning_rate: 7.0000e-04
# Epoch 28/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2591 - mean_absolute_error: 0.2591 - mean_squared_error: 0.1256 - val_loss: 0.3305 - val_mean_absolute_error: 0.3305 - val_mean_squared_error: 0.2248 - learning_rate: 7.0000e-04
# Epoch 28/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2579 - mean_absolute_error: 0.2579 - mean_squared_error: 0.1247 - val_loss: 0.3214 - val_mean_absolute_error: 0.3214 - val_mean_squared_error: 0.2327 - learning_rate: 7.0000e-04
# Epoch 29/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2579 - mean_absolute_error: 0.2579 - mean_squared_error: 0.1247 - val_loss: 0.3214 - val_mean_absolute_error: 0.3214 - val_mean_squared_error: 0.2327 - learning_rate: 7.0000e-04
# Epoch 29/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2572 - mean_absolute_error: 0.2572 - mean_squared_error: 0.1241 - val_loss: 0.3131 - val_mean_absolute_error: 0.3131 - val_mean_squared_error: 0.2183 - learning_rate: 7.0000e-04
# Epoch 30/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2572 - mean_absolute_error: 0.2572 - mean_squared_error: 0.1241 - val_loss: 0.3131 - val_mean_absolute_error: 0.3131 - val_mean_squared_error: 0.2183 - learning_rate: 7.0000e-04
# Epoch 30/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2513 - mean_absolute_error: 0.2513 - mean_squared_error: 0.1191 - val_loss: 0.2716 - val_mean_absolute_error: 0.2716 - val_mean_squared_error: 0.1484 - learning_rate: 4.9000e-04
# Epoch 31/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2513 - mean_absolute_error: 0.2513 - mean_squared_error: 0.1191 - val_loss: 0.2716 - val_mean_absolute_error: 0.2716 - val_mean_squared_error: 0.1484 - learning_rate: 4.9000e-04
# Epoch 31/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2510 - mean_absolute_error: 0.2510 - mean_squared_error: 0.1185 - val_loss: 0.3033 - val_mean_absolute_error: 0.3033 - val_mean_squared_error: 0.2033 - learning_rate: 4.9000e-04
# Epoch 32/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2510 - mean_absolute_error: 0.2510 - mean_squared_error: 0.1185 - val_loss: 0.3033 - val_mean_absolute_error: 0.3033 - val_mean_squared_error: 0.2033 - learning_rate: 4.9000e-04
# Epoch 32/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2500 - mean_absolute_error: 0.2500 - mean_squared_error: 0.1177 - val_loss: 0.3072 - val_mean_absolute_error: 0.3072 - val_mean_squared_error: 0.1948 - learning_rate: 4.9000e-04
# Epoch 33/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2500 - mean_absolute_error: 0.2500 - mean_squared_error: 0.1177 - val_loss: 0.3072 - val_mean_absolute_error: 0.3072 - val_mean_squared_error: 0.1948 - learning_rate: 4.9000e-04
# Epoch 33/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2496 - mean_absolute_error: 0.2496 - mean_squared_error: 0.1173 - val_loss: 0.2770 - val_mean_absolute_error: 0.2770 - val_mean_squared_error: 0.1677 - learning_rate: 4.9000e-04
# Epoch 34/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2496 - mean_absolute_error: 0.2496 - mean_squared_error: 0.1173 - val_loss: 0.2770 - val_mean_absolute_error: 0.2770 - val_mean_squared_error: 0.1677 - learning_rate: 4.9000e-04
# Epoch 34/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2491 - mean_absolute_error: 0.2491 - mean_squared_error: 0.1170 - val_loss: 0.2963 - val_mean_absolute_error: 0.2963 - val_mean_squared_error: 0.1921 - learning_rate: 4.9000e-04
# Epoch 35/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2491 - mean_absolute_error: 0.2491 - mean_squared_error: 0.1170 - val_loss: 0.2963 - val_mean_absolute_error: 0.2963 - val_mean_squared_error: 0.1921 - learning_rate: 4.9000e-04
# Epoch 35/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2485 - mean_absolute_error: 0.2485 - mean_squared_error: 0.1166 - val_loss: 0.2523 - val_mean_absolute_error: 0.2523 - val_mean_squared_error: 0.1394 - learning_rate: 4.9000e-04
# Epoch 36/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2485 - mean_absolute_error: 0.2485 - mean_squared_error: 0.1166 - val_loss: 0.2523 - val_mean_absolute_error: 0.2523 - val_mean_squared_error: 0.1394 - learning_rate: 4.9000e-04
# Epoch 36/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2486 - mean_absolute_error: 0.2486 - mean_squared_error: 0.1168 - val_loss: 0.2988 - val_mean_absolute_error: 0.2988 - val_mean_squared_error: 0.1975 - learning_rate: 4.9000e-04
# Epoch 37/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2486 - mean_absolute_error: 0.2486 - mean_squared_error: 0.1168 - val_loss: 0.2988 - val_mean_absolute_error: 0.2988 - val_mean_squared_error: 0.1975 - learning_rate: 4.9000e-04
# Epoch 37/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2483 - mean_absolute_error: 0.2483 - mean_squared_error: 0.1164 - val_loss: 0.2968 - val_mean_absolute_error: 0.2968 - val_mean_squared_error: 0.1951 - learning_rate: 4.9000e-04
# Epoch 38/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2483 - mean_absolute_error: 0.2483 - mean_squared_error: 0.1164 - val_loss: 0.2968 - val_mean_absolute_error: 0.2968 - val_mean_squared_error: 0.1951 - learning_rate: 4.9000e-04
# Epoch 38/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2474 - mean_absolute_error: 0.2474 - mean_squared_error: 0.1156 - val_loss: 0.3234 - val_mean_absolute_error: 0.3234 - val_mean_squared_error: 0.2223 - learning_rate: 4.9000e-04
# Epoch 39/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2474 - mean_absolute_error: 0.2474 - mean_squared_error: 0.1156 - val_loss: 0.3234 - val_mean_absolute_error: 0.3234 - val_mean_squared_error: 0.2223 - learning_rate: 4.9000e-04
# Epoch 39/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2473 - mean_absolute_error: 0.2473 - mean_squared_error: 0.1156 - val_loss: 0.2671 - val_mean_absolute_error: 0.2671 - val_mean_squared_error: 0.1623 - learning_rate: 4.9000e-04
# Epoch 40/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2473 - mean_absolute_error: 0.2473 - mean_squared_error: 0.1156 - val_loss: 0.2671 - val_mean_absolute_error: 0.2671 - val_mean_squared_error: 0.1623 - learning_rate: 4.9000e-04
# Epoch 40/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2472 - mean_absolute_error: 0.2472 - mean_squared_error: 0.1155 - val_loss: 0.3029 - val_mean_absolute_error: 0.3029 - val_mean_squared_error: 0.2019 - learning_rate: 4.9000e-04
# Epoch 41/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2472 - mean_absolute_error: 0.2472 - mean_squared_error: 0.1155 - val_loss: 0.3029 - val_mean_absolute_error: 0.3029 - val_mean_squared_error: 0.2019 - learning_rate: 4.9000e-04
# Epoch 41/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2435 - mean_absolute_error: 0.2435 - mean_squared_error: 0.1126 - val_loss: 0.2475 - val_mean_absolute_error: 0.2475 - val_mean_squared_error: 0.1337 - learning_rate: 3.4300e-04
# Epoch 42/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2435 - mean_absolute_error: 0.2435 - mean_squared_error: 0.1126 - val_loss: 0.2475 - val_mean_absolute_error: 0.2475 - val_mean_squared_error: 0.1337 - learning_rate: 3.4300e-04
# Epoch 42/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2433 - mean_absolute_error: 0.2433 - mean_squared_error: 0.1124 - val_loss: 0.2658 - val_mean_absolute_error: 0.2658 - val_mean_squared_error: 0.1602 - learning_rate: 3.4300e-04
# Epoch 43/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2433 - mean_absolute_error: 0.2433 - mean_squared_error: 0.1124 - val_loss: 0.2658 - val_mean_absolute_error: 0.2658 - val_mean_squared_error: 0.1602 - learning_rate: 3.4300e-04
# Epoch 43/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2429 - mean_absolute_error: 0.2429 - mean_squared_error: 0.1121 - val_loss: 0.2310 - val_mean_absolute_error: 0.2310 - val_mean_squared_error: 0.1149 - learning_rate: 3.4300e-04
# Epoch 44/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2429 - mean_absolute_error: 0.2429 - mean_squared_error: 0.1121 - val_loss: 0.2310 - val_mean_absolute_error: 0.2310 - val_mean_squared_error: 0.1149 - learning_rate: 3.4300e-04
# Epoch 44/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2424 - mean_absolute_error: 0.2424 - mean_squared_error: 0.1118 - val_loss: 0.2633 - val_mean_absolute_error: 0.2633 - val_mean_squared_error: 0.1541 - learning_rate: 3.4300e-04
# Epoch 45/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2424 - mean_absolute_error: 0.2424 - mean_squared_error: 0.1118 - val_loss: 0.2633 - val_mean_absolute_error: 0.2633 - val_mean_squared_error: 0.1541 - learning_rate: 3.4300e-04
# Epoch 45/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2419 - mean_absolute_error: 0.2419 - mean_squared_error: 0.1114 - val_loss: 0.2491 - val_mean_absolute_error: 0.2491 - val_mean_squared_error: 0.1393 - learning_rate: 3.4300e-04
# Epoch 46/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2419 - mean_absolute_error: 0.2419 - mean_squared_error: 0.1114 - val_loss: 0.2491 - val_mean_absolute_error: 0.2491 - val_mean_squared_error: 0.1393 - learning_rate: 3.4300e-04
# Epoch 46/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2413 - mean_absolute_error: 0.2413 - mean_squared_error: 0.1109 - val_loss: 0.2763 - val_mean_absolute_error: 0.2763 - val_mean_squared_error: 0.1709 - learning_rate: 3.4300e-04
# Epoch 47/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2413 - mean_absolute_error: 0.2413 - mean_squared_error: 0.1109 - val_loss: 0.2763 - val_mean_absolute_error: 0.2763 - val_mean_squared_error: 0.1709 - learning_rate: 3.4300e-04
# Epoch 47/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2409 - mean_absolute_error: 0.2409 - mean_squared_error: 0.1105 - val_loss: 0.2612 - val_mean_absolute_error: 0.2612 - val_mean_squared_error: 0.1433 - learning_rate: 3.4300e-04
# Epoch 48/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2409 - mean_absolute_error: 0.2409 - mean_squared_error: 0.1105 - val_loss: 0.2612 - val_mean_absolute_error: 0.2612 - val_mean_squared_error: 0.1433 - learning_rate: 3.4300e-04
# Epoch 48/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2411 - mean_absolute_error: 0.2411 - mean_squared_error: 0.1107 - val_loss: 0.2644 - val_mean_absolute_error: 0.2644 - val_mean_squared_error: 0.1588 - learning_rate: 3.4300e-04
# Epoch 49/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2411 - mean_absolute_error: 0.2411 - mean_squared_error: 0.1107 - val_loss: 0.2644 - val_mean_absolute_error: 0.2644 - val_mean_squared_error: 0.1588 - learning_rate: 3.4300e-04
# Epoch 49/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2390 - mean_absolute_error: 0.2390 - mean_squared_error: 0.1088 - val_loss: 0.2425 - val_mean_absolute_error: 0.2425 - val_mean_squared_error: 0.1313 - learning_rate: 2.4010e-04
# Epoch 50/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2390 - mean_absolute_error: 0.2390 - mean_squared_error: 0.1088 - val_loss: 0.2425 - val_mean_absolute_error: 0.2425 - val_mean_squared_error: 0.1313 - learning_rate: 2.4010e-04
# Epoch 50/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2384 - mean_absolute_error: 0.2384 - mean_squared_error: 0.1082 - val_loss: 0.2492 - val_mean_absolute_error: 0.2492 - val_mean_squared_error: 0.1389 - learning_rate: 2.4010e-04
# Epoch 51/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2384 - mean_absolute_error: 0.2384 - mean_squared_error: 0.1082 - val_loss: 0.2492 - val_mean_absolute_error: 0.2492 - val_mean_squared_error: 0.1389 - learning_rate: 2.4010e-04
# Epoch 51/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2387 - mean_absolute_error: 0.2387 - mean_squared_error: 0.1086 - val_loss: 0.2577 - val_mean_absolute_error: 0.2577 - val_mean_squared_error: 0.1505 - learning_rate: 2.4010e-04
# Epoch 52/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2387 - mean_absolute_error: 0.2387 - mean_squared_error: 0.1086 - val_loss: 0.2577 - val_mean_absolute_error: 0.2577 - val_mean_squared_error: 0.1505 - learning_rate: 2.4010e-04
# Epoch 52/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2384 - mean_absolute_error: 0.2384 - mean_squared_error: 0.1082 - val_loss: 0.2585 - val_mean_absolute_error: 0.2585 - val_mean_squared_error: 0.1505 - learning_rate: 2.4010e-04
# Epoch 53/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2384 - mean_absolute_error: 0.2384 - mean_squared_error: 0.1082 - val_loss: 0.2585 - val_mean_absolute_error: 0.2585 - val_mean_squared_error: 0.1505 - learning_rate: 2.4010e-04
# Epoch 53/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2380 - mean_absolute_error: 0.2380 - mean_squared_error: 0.1081 - val_loss: 0.2619 - val_mean_absolute_error: 0.2619 - val_mean_squared_error: 0.1522 - learning_rate: 2.4010e-04
# Epoch 54/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2380 - mean_absolute_error: 0.2380 - mean_squared_error: 0.1081 - val_loss: 0.2619 - val_mean_absolute_error: 0.2619 - val_mean_squared_error: 0.1522 - learning_rate: 2.4010e-04
# Epoch 54/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2366 - mean_absolute_error: 0.2366 - mean_squared_error: 0.1067 - val_loss: 0.2283 - val_mean_absolute_error: 0.2283 - val_mean_squared_error: 0.1150 - learning_rate: 1.6807e-04
# Epoch 55/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2366 - mean_absolute_error: 0.2366 - mean_squared_error: 0.1067 - val_loss: 0.2283 - val_mean_absolute_error: 0.2283 - val_mean_squared_error: 0.1150 - learning_rate: 1.6807e-04
# Epoch 55/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2361 - mean_absolute_error: 0.2361 - mean_squared_error: 0.1067 - val_loss: 0.2326 - val_mean_absolute_error: 0.2326 - val_mean_squared_error: 0.1177 - learning_rate: 1.6807e-04
# Epoch 56/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2361 - mean_absolute_error: 0.2361 - mean_squared_error: 0.1067 - val_loss: 0.2326 - val_mean_absolute_error: 0.2326 - val_mean_squared_error: 0.1177 - learning_rate: 1.6807e-04
# Epoch 56/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2360 - mean_absolute_error: 0.2360 - mean_squared_error: 0.1065 - val_loss: 0.2354 - val_mean_absolute_error: 0.2354 - val_mean_squared_error: 0.1254 - learning_rate: 1.6807e-04
# Epoch 57/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2360 - mean_absolute_error: 0.2360 - mean_squared_error: 0.1065 - val_loss: 0.2354 - val_mean_absolute_error: 0.2354 - val_mean_squared_error: 0.1254 - learning_rate: 1.6807e-04
# Epoch 57/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2362 - mean_absolute_error: 0.2362 - mean_squared_error: 0.1067 - val_loss: 0.2361 - val_mean_absolute_error: 0.2361 - val_mean_squared_error: 0.1241 - learning_rate: 1.6807e-04
# Epoch 58/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2362 - mean_absolute_error: 0.2362 - mean_squared_error: 0.1067 - val_loss: 0.2361 - val_mean_absolute_error: 0.2361 - val_mean_squared_error: 0.1241 - learning_rate: 1.6807e-04
# Epoch 58/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2358 - mean_absolute_error: 0.2358 - mean_squared_error: 0.1062 - val_loss: 0.2432 - val_mean_absolute_error: 0.2432 - val_mean_squared_error: 0.1326 - learning_rate: 1.6807e-04
# Epoch 59/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2358 - mean_absolute_error: 0.2358 - mean_squared_error: 0.1062 - val_loss: 0.2432 - val_mean_absolute_error: 0.2432 - val_mean_squared_error: 0.1326 - learning_rate: 1.6807e-04
# Epoch 59/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2355 - mean_absolute_error: 0.2355 - mean_squared_error: 0.1061 - val_loss: 0.2354 - val_mean_absolute_error: 0.2354 - val_mean_squared_error: 0.1231 - learning_rate: 1.6807e-04
# Epoch 60/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2355 - mean_absolute_error: 0.2355 - mean_squared_error: 0.1061 - val_loss: 0.2354 - val_mean_absolute_error: 0.2354 - val_mean_squared_error: 0.1231 - learning_rate: 1.6807e-04
# Epoch 60/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2346 - mean_absolute_error: 0.2346 - mean_squared_error: 0.1053 - val_loss: 0.2276 - val_mean_absolute_error: 0.2276 - val_mean_squared_error: 0.1161 - learning_rate: 1.1765e-04
# Epoch 61/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2346 - mean_absolute_error: 0.2346 - mean_squared_error: 0.1053 - val_loss: 0.2276 - val_mean_absolute_error: 0.2276 - val_mean_squared_error: 0.1161 - learning_rate: 1.1765e-04
# Epoch 61/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2345 - mean_absolute_error: 0.2345 - mean_squared_error: 0.1053 - val_loss: 0.2368 - val_mean_absolute_error: 0.2368 - val_mean_squared_error: 0.1260 - learning_rate: 1.1765e-04
# Epoch 62/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2345 - mean_absolute_error: 0.2345 - mean_squared_error: 0.1053 - val_loss: 0.2368 - val_mean_absolute_error: 0.2368 - val_mean_squared_error: 0.1260 - learning_rate: 1.1765e-04
# Epoch 62/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2345 - mean_absolute_error: 0.2345 - mean_squared_error: 0.1051 - val_loss: 0.2290 - val_mean_absolute_error: 0.2290 - val_mean_squared_error: 0.1170 - learning_rate: 1.1765e-04
# Epoch 63/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2345 - mean_absolute_error: 0.2345 - mean_squared_error: 0.1051 - val_loss: 0.2290 - val_mean_absolute_error: 0.2290 - val_mean_squared_error: 0.1170 - learning_rate: 1.1765e-04
# Epoch 63/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2342 - mean_absolute_error: 0.2342 - mean_squared_error: 0.1051 - val_loss: 0.2205 - val_mean_absolute_error: 0.2205 - val_mean_squared_error: 0.1073 - learning_rate: 1.1765e-04
# Epoch 64/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2342 - mean_absolute_error: 0.2342 - mean_squared_error: 0.1051 - val_loss: 0.2205 - val_mean_absolute_error: 0.2205 - val_mean_squared_error: 0.1073 - learning_rate: 1.1765e-04
# Epoch 64/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2338 - mean_absolute_error: 0.2338 - mean_squared_error: 0.1047 - val_loss: 0.2242 - val_mean_absolute_error: 0.2242 - val_mean_squared_error: 0.1118 - learning_rate: 1.1765e-04
# Epoch 65/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2338 - mean_absolute_error: 0.2338 - mean_squared_error: 0.1047 - val_loss: 0.2242 - val_mean_absolute_error: 0.2242 - val_mean_squared_error: 0.1118 - learning_rate: 1.1765e-04
# Epoch 65/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2338 - mean_absolute_error: 0.2338 - mean_squared_error: 0.1047 - val_loss: 0.2275 - val_mean_absolute_error: 0.2275 - val_mean_squared_error: 0.1150 - learning_rate: 1.1765e-04
# Epoch 66/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2338 - mean_absolute_error: 0.2338 - mean_squared_error: 0.1047 - val_loss: 0.2275 - val_mean_absolute_error: 0.2275 - val_mean_squared_error: 0.1150 - learning_rate: 1.1765e-04
# Epoch 66/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2335 - mean_absolute_error: 0.2335 - mean_squared_error: 0.1046 - val_loss: 0.2239 - val_mean_absolute_error: 0.2239 - val_mean_squared_error: 0.1109 - learning_rate: 1.1765e-04
# Epoch 67/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2335 - mean_absolute_error: 0.2335 - mean_squared_error: 0.1046 - val_loss: 0.2239 - val_mean_absolute_error: 0.2239 - val_mean_squared_error: 0.1109 - learning_rate: 1.1765e-04
# Epoch 67/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2333 - mean_absolute_error: 0.2333 - mean_squared_error: 0.1043 - val_loss: 0.2289 - val_mean_absolute_error: 0.2289 - val_mean_squared_error: 0.1171 - learning_rate: 1.1765e-04
# Epoch 68/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2333 - mean_absolute_error: 0.2333 - mean_squared_error: 0.1043 - val_loss: 0.2289 - val_mean_absolute_error: 0.2289 - val_mean_squared_error: 0.1171 - learning_rate: 1.1765e-04
# Epoch 68/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2333 - mean_absolute_error: 0.2333 - mean_squared_error: 0.1043 - val_loss: 0.2299 - val_mean_absolute_error: 0.2299 - val_mean_squared_error: 0.1177 - learning_rate: 1.1765e-04
# Epoch 69/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2333 - mean_absolute_error: 0.2333 - mean_squared_error: 0.1043 - val_loss: 0.2299 - val_mean_absolute_error: 0.2299 - val_mean_squared_error: 0.1177 - learning_rate: 1.1765e-04
# Epoch 69/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2324 - mean_absolute_error: 0.2324 - mean_squared_error: 0.1037 - val_loss: 0.2235 - val_mean_absolute_error: 0.2235 - val_mean_squared_error: 0.1108 - learning_rate: 8.2354e-05
# Epoch 70/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2324 - mean_absolute_error: 0.2324 - mean_squared_error: 0.1037 - val_loss: 0.2235 - val_mean_absolute_error: 0.2235 - val_mean_squared_error: 0.1108 - learning_rate: 8.2354e-05
# Epoch 70/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2320 - mean_absolute_error: 0.2320 - mean_squared_error: 0.1035 - val_loss: 0.2245 - val_mean_absolute_error: 0.2245 - val_mean_squared_error: 0.1121 - learning_rate: 8.2354e-05
# Epoch 71/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2320 - mean_absolute_error: 0.2320 - mean_squared_error: 0.1035 - val_loss: 0.2245 - val_mean_absolute_error: 0.2245 - val_mean_squared_error: 0.1121 - learning_rate: 8.2354e-05
# Epoch 71/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2325 - mean_absolute_error: 0.2325 - mean_squared_error: 0.1038 - val_loss: 0.2232 - val_mean_absolute_error: 0.2232 - val_mean_squared_error: 0.1109 - learning_rate: 8.2354e-05
# Epoch 72/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2325 - mean_absolute_error: 0.2325 - mean_squared_error: 0.1038 - val_loss: 0.2232 - val_mean_absolute_error: 0.2232 - val_mean_squared_error: 0.1109 - learning_rate: 8.2354e-05
# Epoch 72/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2327 - mean_absolute_error: 0.2327 - mean_squared_error: 0.1039 - val_loss: 0.2212 - val_mean_absolute_error: 0.2212 - val_mean_squared_error: 0.1084 - learning_rate: 8.2354e-05
# Epoch 73/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2327 - mean_absolute_error: 0.2327 - mean_squared_error: 0.1039 - val_loss: 0.2212 - val_mean_absolute_error: 0.2212 - val_mean_squared_error: 0.1084 - learning_rate: 8.2354e-05
# Epoch 73/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2322 - mean_absolute_error: 0.2322 - mean_squared_error: 0.1034 - val_loss: 0.2277 - val_mean_absolute_error: 0.2277 - val_mean_squared_error: 0.1177 - learning_rate: 8.2354e-05
# Epoch 74/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2322 - mean_absolute_error: 0.2322 - mean_squared_error: 0.1034 - val_loss: 0.2277 - val_mean_absolute_error: 0.2277 - val_mean_squared_error: 0.1177 - learning_rate: 8.2354e-05
# Epoch 74/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2315 - mean_absolute_error: 0.2315 - mean_squared_error: 0.1029 - val_loss: 0.2211 - val_mean_absolute_error: 0.2211 - val_mean_squared_error: 0.1085 - learning_rate: 5.7648e-05
# Epoch 75/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2315 - mean_absolute_error: 0.2315 - mean_squared_error: 0.1029 - val_loss: 0.2211 - val_mean_absolute_error: 0.2211 - val_mean_squared_error: 0.1085 - learning_rate: 5.7648e-05
# Epoch 75/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2319 - mean_absolute_error: 0.2319 - mean_squared_error: 0.1032 - val_loss: 0.2223 - val_mean_absolute_error: 0.2223 - val_mean_squared_error: 0.1094 - learning_rate: 5.7648e-05
# Epoch 76/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2319 - mean_absolute_error: 0.2319 - mean_squared_error: 0.1032 - val_loss: 0.2223 - val_mean_absolute_error: 0.2223 - val_mean_squared_error: 0.1094 - learning_rate: 5.7648e-05
# Epoch 76/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2316 - mean_absolute_error: 0.2316 - mean_squared_error: 0.1029 - val_loss: 0.2217 - val_mean_absolute_error: 0.2217 - val_mean_squared_error: 0.1090 - learning_rate: 5.7648e-05
# Epoch 77/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2316 - mean_absolute_error: 0.2316 - mean_squared_error: 0.1029 - val_loss: 0.2217 - val_mean_absolute_error: 0.2217 - val_mean_squared_error: 0.1090 - learning_rate: 5.7648e-05
# Epoch 77/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2317 - mean_absolute_error: 0.2317 - mean_squared_error: 0.1032 - val_loss: 0.2200 - val_mean_absolute_error: 0.2200 - val_mean_squared_error: 0.1074 - learning_rate: 5.7648e-05
# Epoch 78/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2317 - mean_absolute_error: 0.2317 - mean_squared_error: 0.1032 - val_loss: 0.2200 - val_mean_absolute_error: 0.2200 - val_mean_squared_error: 0.1074 - learning_rate: 5.7648e-05
# Epoch 78/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2318 - mean_absolute_error: 0.2318 - mean_squared_error: 0.1031 - val_loss: 0.2203 - val_mean_absolute_error: 0.2203 - val_mean_squared_error: 0.1077 - learning_rate: 5.7648e-05
# Epoch 79/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2318 - mean_absolute_error: 0.2318 - mean_squared_error: 0.1031 - val_loss: 0.2203 - val_mean_absolute_error: 0.2203 - val_mean_squared_error: 0.1077 - learning_rate: 5.7648e-05
# Epoch 79/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2312 - mean_absolute_error: 0.2312 - mean_squared_error: 0.1027 - val_loss: 0.2200 - val_mean_absolute_error: 0.2200 - val_mean_squared_error: 0.1071 - learning_rate: 5.7648e-05
# Epoch 80/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2312 - mean_absolute_error: 0.2312 - mean_squared_error: 0.1027 - val_loss: 0.2200 - val_mean_absolute_error: 0.2200 - val_mean_squared_error: 0.1071 - learning_rate: 5.7648e-05
# Epoch 80/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2314 - mean_absolute_error: 0.2314 - mean_squared_error: 0.1027 - val_loss: 0.2220 - val_mean_absolute_error: 0.2220 - val_mean_squared_error: 0.1099 - learning_rate: 5.7648e-05
# Epoch 81/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2314 - mean_absolute_error: 0.2314 - mean_squared_error: 0.1027 - val_loss: 0.2220 - val_mean_absolute_error: 0.2220 - val_mean_squared_error: 0.1099 - learning_rate: 5.7648e-05
# Epoch 81/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2309 - mean_absolute_error: 0.2309 - mean_squared_error: 0.1026 - val_loss: 0.2189 - val_mean_absolute_error: 0.2189 - val_mean_squared_error: 0.1061 - learning_rate: 5.7648e-05
# Epoch 82/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2309 - mean_absolute_error: 0.2309 - mean_squared_error: 0.1026 - val_loss: 0.2189 - val_mean_absolute_error: 0.2189 - val_mean_squared_error: 0.1061 - learning_rate: 5.7648e-05
# Epoch 82/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2313 - mean_absolute_error: 0.2313 - mean_squared_error: 0.1029 - val_loss: 0.2186 - val_mean_absolute_error: 0.2186 - val_mean_squared_error: 0.1060 - learning_rate: 5.7648e-05
# Epoch 83/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2313 - mean_absolute_error: 0.2313 - mean_squared_error: 0.1029 - val_loss: 0.2186 - val_mean_absolute_error: 0.2186 - val_mean_squared_error: 0.1060 - learning_rate: 5.7648e-05
# Epoch 83/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2311 - mean_absolute_error: 0.2311 - mean_squared_error: 0.1026 - val_loss: 0.2188 - val_mean_absolute_error: 0.2188 - val_mean_squared_error: 0.1036 - learning_rate: 5.7648e-05
# Epoch 84/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2311 - mean_absolute_error: 0.2311 - mean_squared_error: 0.1026 - val_loss: 0.2188 - val_mean_absolute_error: 0.2188 - val_mean_squared_error: 0.1036 - learning_rate: 5.7648e-05
# Epoch 84/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2313 - mean_absolute_error: 0.2313 - mean_squared_error: 0.1027 - val_loss: 0.2190 - val_mean_absolute_error: 0.2190 - val_mean_squared_error: 0.1069 - learning_rate: 5.7648e-05
# Epoch 85/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2313 - mean_absolute_error: 0.2313 - mean_squared_error: 0.1027 - val_loss: 0.2190 - val_mean_absolute_error: 0.2190 - val_mean_squared_error: 0.1069 - learning_rate: 5.7648e-05
# Epoch 85/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2313 - mean_absolute_error: 0.2313 - mean_squared_error: 0.1029 - val_loss: 0.2197 - val_mean_absolute_error: 0.2197 - val_mean_squared_error: 0.1073 - learning_rate: 5.7648e-05
# Epoch 86/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2313 - mean_absolute_error: 0.2313 - mean_squared_error: 0.1029 - val_loss: 0.2197 - val_mean_absolute_error: 0.2197 - val_mean_squared_error: 0.1073 - learning_rate: 5.7648e-05
# Epoch 86/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2309 - mean_absolute_error: 0.2309 - mean_squared_error: 0.1023 - val_loss: 0.2203 - val_mean_absolute_error: 0.2203 - val_mean_squared_error: 0.1072 - learning_rate: 5.7648e-05
# Epoch 87/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2309 - mean_absolute_error: 0.2309 - mean_squared_error: 0.1023 - val_loss: 0.2203 - val_mean_absolute_error: 0.2203 - val_mean_squared_error: 0.1072 - learning_rate: 5.7648e-05
# Epoch 87/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2311 - mean_absolute_error: 0.2311 - mean_squared_error: 0.1024 - val_loss: 0.2229 - val_mean_absolute_error: 0.2229 - val_mean_squared_error: 0.1113 - learning_rate: 5.7648e-05
# Epoch 88/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2311 - mean_absolute_error: 0.2311 - mean_squared_error: 0.1024 - val_loss: 0.2229 - val_mean_absolute_error: 0.2229 - val_mean_squared_error: 0.1113 - learning_rate: 5.7648e-05
# Epoch 88/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2305 - mean_absolute_error: 0.2305 - mean_squared_error: 0.1022 - val_loss: 0.2178 - val_mean_absolute_error: 0.2178 - val_mean_squared_error: 0.1051 - learning_rate: 4.0354e-05
# Epoch 89/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2305 - mean_absolute_error: 0.2305 - mean_squared_error: 0.1022 - val_loss: 0.2178 - val_mean_absolute_error: 0.2178 - val_mean_squared_error: 0.1051 - learning_rate: 4.0354e-05
# Epoch 89/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2305 - mean_absolute_error: 0.2305 - mean_squared_error: 0.1020 - val_loss: 0.2211 - val_mean_absolute_error: 0.2211 - val_mean_squared_error: 0.1088 - learning_rate: 4.0354e-05
# Epoch 90/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2305 - mean_absolute_error: 0.2305 - mean_squared_error: 0.1020 - val_loss: 0.2211 - val_mean_absolute_error: 0.2211 - val_mean_squared_error: 0.1088 - learning_rate: 4.0354e-05
# Epoch 90/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2301 - mean_absolute_error: 0.2301 - mean_squared_error: 0.1020 - val_loss: 0.2206 - val_mean_absolute_error: 0.2206 - val_mean_squared_error: 0.1083 - learning_rate: 4.0354e-05
# Epoch 91/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2301 - mean_absolute_error: 0.2301 - mean_squared_error: 0.1020 - val_loss: 0.2206 - val_mean_absolute_error: 0.2206 - val_mean_squared_error: 0.1083 - learning_rate: 4.0354e-05
# Epoch 91/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2306 - mean_absolute_error: 0.2306 - mean_squared_error: 0.1020 - val_loss: 0.2208 - val_mean_absolute_error: 0.2208 - val_mean_squared_error: 0.1089 - learning_rate: 4.0354e-05
# Epoch 92/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2306 - mean_absolute_error: 0.2306 - mean_squared_error: 0.1020 - val_loss: 0.2208 - val_mean_absolute_error: 0.2208 - val_mean_squared_error: 0.1089 - learning_rate: 4.0354e-05
# Epoch 92/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2303 - mean_absolute_error: 0.2303 - mean_squared_error: 0.1019 - val_loss: 0.2213 - val_mean_absolute_error: 0.2213 - val_mean_squared_error: 0.1089 - learning_rate: 4.0354e-05
# Epoch 93/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2303 - mean_absolute_error: 0.2303 - mean_squared_error: 0.1019 - val_loss: 0.2213 - val_mean_absolute_error: 0.2213 - val_mean_squared_error: 0.1089 - learning_rate: 4.0354e-05
# Epoch 93/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2303 - mean_absolute_error: 0.2303 - mean_squared_error: 0.1017 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1043 - learning_rate: 4.0354e-05
# Epoch 94/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2303 - mean_absolute_error: 0.2303 - mean_squared_error: 0.1017 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1043 - learning_rate: 4.0354e-05
# Epoch 94/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2301 - mean_absolute_error: 0.2301 - mean_squared_error: 0.1019 - val_loss: 0.2192 - val_mean_absolute_error: 0.2192 - val_mean_squared_error: 0.1067 - learning_rate: 4.0354e-05
# Epoch 95/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2301 - mean_absolute_error: 0.2301 - mean_squared_error: 0.1019 - val_loss: 0.2192 - val_mean_absolute_error: 0.2192 - val_mean_squared_error: 0.1067 - learning_rate: 4.0354e-05
# Epoch 95/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2300 - mean_absolute_error: 0.2300 - mean_squared_error: 0.1017 - val_loss: 0.2182 - val_mean_absolute_error: 0.2182 - val_mean_squared_error: 0.1060 - learning_rate: 4.0354e-05
# Epoch 96/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2300 - mean_absolute_error: 0.2300 - mean_squared_error: 0.1017 - val_loss: 0.2182 - val_mean_absolute_error: 0.2182 - val_mean_squared_error: 0.1060 - learning_rate: 4.0354e-05
# Epoch 96/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2298 - mean_absolute_error: 0.2298 - mean_squared_error: 0.1016 - val_loss: 0.2180 - val_mean_absolute_error: 0.2180 - val_mean_squared_error: 0.1048 - learning_rate: 4.0354e-05
# Epoch 97/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2298 - mean_absolute_error: 0.2298 - mean_squared_error: 0.1016 - val_loss: 0.2180 - val_mean_absolute_error: 0.2180 - val_mean_squared_error: 0.1048 - learning_rate: 4.0354e-05
# Epoch 97/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2303 - mean_absolute_error: 0.2303 - mean_squared_error: 0.1020 - val_loss: 0.2167 - val_mean_absolute_error: 0.2167 - val_mean_squared_error: 0.1031 - learning_rate: 4.0354e-05
# Epoch 98/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2303 - mean_absolute_error: 0.2303 - mean_squared_error: 0.1020 - val_loss: 0.2167 - val_mean_absolute_error: 0.2167 - val_mean_squared_error: 0.1031 - learning_rate: 4.0354e-05
# Epoch 98/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2299 - mean_absolute_error: 0.2299 - mean_squared_error: 0.1018 - val_loss: 0.2173 - val_mean_absolute_error: 0.2173 - val_mean_squared_error: 0.1051 - learning_rate: 4.0354e-05
# Epoch 99/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2299 - mean_absolute_error: 0.2299 - mean_squared_error: 0.1018 - val_loss: 0.2173 - val_mean_absolute_error: 0.2173 - val_mean_squared_error: 0.1051 - learning_rate: 4.0354e-05
# Epoch 99/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2298 - mean_absolute_error: 0.2298 - mean_squared_error: 0.1017 - val_loss: 0.2183 - val_mean_absolute_error: 0.2183 - val_mean_squared_error: 0.1051 - learning_rate: 4.0354e-05
# Epoch 100/200
# ...
# Epoch 116/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2293 - mean_absolute_error: 0.2293 - mean_squared_error: 0.1012 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1038 - learning_rate: 1.3841e-05
# Epoch 116/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1010 - val_loss: 0.2168 - val_mean_absolute_error: 0.2168 - val_mean_squared_error: 0.1033 - learning_rate: 1.3841e-05
# Epoch 117/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1010 - val_loss: 0.2168 - val_mean_absolute_error: 0.2168 - val_mean_squared_error: 0.1033 - learning_rate: 1.3841e-05
# Epoch 117/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2293 - mean_absolute_error: 0.2293 - mean_squared_error: 0.1013 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1040 - learning_rate: 1.3841e-05
# Epoch 118/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2293 - mean_absolute_error: 0.2293 - mean_squared_error: 0.1013 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1040 - learning_rate: 1.3841e-05
# Epoch 118/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2287 - mean_absolute_error: 0.2287 - mean_squared_error: 0.1008 - val_loss: 0.2168 - val_mean_absolute_error: 0.2168 - val_mean_squared_error: 0.1035 - learning_rate: 9.6889e-06
# Epoch 119/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2287 - mean_absolute_error: 0.2287 - mean_squared_error: 0.1008 - val_loss: 0.2168 - val_mean_absolute_error: 0.2168 - val_mean_squared_error: 0.1035 - learning_rate: 9.6889e-06
# Epoch 119/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1008 - val_loss: 0.2178 - val_mean_absolute_error: 0.2178 - val_mean_squared_error: 0.1046 - learning_rate: 9.6889e-06
# Epoch 120/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1008 - val_loss: 0.2178 - val_mean_absolute_error: 0.2178 - val_mean_squared_error: 0.1046 - learning_rate: 9.6889e-06
# Epoch 120/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2287 - mean_absolute_error: 0.2287 - mean_squared_error: 0.1008 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1040 - learning_rate: 9.6889e-06
# Epoch 121/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2287 - mean_absolute_error: 0.2287 - mean_squared_error: 0.1008 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1040 - learning_rate: 9.6889e-06
# Epoch 121/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1008 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1039 - learning_rate: 9.6889e-06
# Epoch 122/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1008 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1039 - learning_rate: 9.6889e-06
# Epoch 122/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1011 - val_loss: 0.2166 - val_mean_absolute_error: 0.2166 - val_mean_squared_error: 0.1033 - learning_rate: 9.6889e-06
# Epoch 123/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1011 - val_loss: 0.2166 - val_mean_absolute_error: 0.2166 - val_mean_squared_error: 0.1033 - learning_rate: 9.6889e-06
# Epoch 123/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1009 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1044 - learning_rate: 6.7822e-06
# Epoch 124/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1009 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1044 - learning_rate: 6.7822e-06
# Epoch 124/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1011 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1043 - learning_rate: 6.7822e-06
# Epoch 125/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1011 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1043 - learning_rate: 6.7822e-06
# Epoch 125/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1007 - val_loss: 0.2171 - val_mean_absolute_error: 0.2171 - val_mean_squared_error: 0.1040 - learning_rate: 6.7822e-06
# Epoch 126/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1007 - val_loss: 0.2171 - val_mean_absolute_error: 0.2171 - val_mean_squared_error: 0.1040 - learning_rate: 6.7822e-06
# Epoch 126/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2291 - mean_absolute_error: 0.2291 - mean_squared_error: 0.1012 - val_loss: 0.2169 - val_mean_absolute_error: 0.2169 - val_mean_squared_error: 0.1038 - learning_rate: 6.7822e-06
# Epoch 127/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2291 - mean_absolute_error: 0.2291 - mean_squared_error: 0.1012 - val_loss: 0.2169 - val_mean_absolute_error: 0.2169 - val_mean_squared_error: 0.1038 - learning_rate: 6.7822e-06
# Epoch 127/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1009 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1046 - learning_rate: 6.7822e-06
# Epoch 128/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1009 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1046 - learning_rate: 6.7822e-06
# Epoch 128/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1009 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1045 - learning_rate: 4.7476e-06
# Epoch 129/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1009 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1045 - learning_rate: 4.7476e-06
# Epoch 129/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1010 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.1044 - learning_rate: 4.7476e-06
# Epoch 130/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1010 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.1044 - learning_rate: 4.7476e-06
# Epoch 130/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1010 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1042 - learning_rate: 4.7476e-06
# Epoch 131/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1010 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1042 - learning_rate: 4.7476e-06
# Epoch 131/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1012 - val_loss: 0.2173 - val_mean_absolute_error: 0.2173 - val_mean_squared_error: 0.1038 - learning_rate: 4.7476e-06
# Epoch 132/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2290 - mean_absolute_error: 0.2290 - mean_squared_error: 0.1012 - val_loss: 0.2173 - val_mean_absolute_error: 0.2173 - val_mean_squared_error: 0.1038 - learning_rate: 4.7476e-06
# Epoch 132/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1009 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1039 - learning_rate: 4.7476e-06
# Epoch 133/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1009 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - val_mean_squared_error: 0.1039 - learning_rate: 4.7476e-06
# Epoch 133/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1008 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 3.3233e-06
# Epoch 134/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1008 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 3.3233e-06
# Epoch 134/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1008 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 3.3233e-06
# Epoch 135/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1008 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 3.3233e-06
# Epoch 135/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1009 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1042 - learning_rate: 3.3233e-06
# Epoch 136/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1009 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1042 - learning_rate: 3.3233e-06
# Epoch 136/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2287 - mean_absolute_error: 0.2287 - mean_squared_error: 0.1008 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 3.3233e-06
# Epoch 137/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2287 - mean_absolute_error: 0.2287 - mean_squared_error: 0.1008 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 3.3233e-06
# Epoch 137/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1006 - val_loss: 0.2177 - val_mean_absolute_error: 0.2177 - val_mean_squared_error: 0.1045 - learning_rate: 3.3233e-06
# Epoch 138/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1006 - val_loss: 0.2177 - val_mean_absolute_error: 0.2177 - val_mean_squared_error: 0.1045 - learning_rate: 3.3233e-06
# Epoch 138/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1007 - val_loss: 0.2177 - val_mean_absolute_error: 0.2177 - val_mean_squared_error: 0.1047 - learning_rate: 2.3263e-06
# Epoch 139/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1007 - val_loss: 0.2177 - val_mean_absolute_error: 0.2177 - val_mean_squared_error: 0.1047 - learning_rate: 2.3263e-06
# Epoch 139/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1007 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.1044 - learning_rate: 2.3263e-06
# Epoch 140/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1007 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.1044 - learning_rate: 2.3263e-06
# Epoch 140/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1009 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1042 - learning_rate: 2.3263e-06
# Epoch 141/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1009 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1042 - learning_rate: 2.3263e-06
# Epoch 141/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2285 - mean_absolute_error: 0.2285 - mean_squared_error: 0.1009 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.1045 - learning_rate: 2.3263e-06
# Epoch 142/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2285 - mean_absolute_error: 0.2285 - mean_squared_error: 0.1009 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.1045 - learning_rate: 2.3263e-06
# Epoch 142/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1008 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 2.3263e-06
# Epoch 143/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2289 - mean_absolute_error: 0.2289 - mean_squared_error: 0.1008 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 2.3263e-06
# Epoch 143/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2285 - mean_absolute_error: 0.2285 - mean_squared_error: 0.1005 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.1044 - learning_rate: 1.6284e-06
# Epoch 144/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2285 - mean_absolute_error: 0.2285 - mean_squared_error: 0.1005 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.1044 - learning_rate: 1.6284e-06
# Epoch 144/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1007 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 1.6284e-06
# Epoch 145/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1007 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1043 - learning_rate: 1.6284e-06
# Epoch 145/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1009 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1044 - learning_rate: 1.6284e-06
# Epoch 146/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2288 - mean_absolute_error: 0.2288 - mean_squared_error: 0.1009 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.1044 - learning_rate: 1.6284e-06
# Epoch 146/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2287 - mean_absolute_error: 0.2287 - mean_squared_error: 0.1006 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1043 - learning_rate: 1.6284e-06
# Epoch 147/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2287 - mean_absolute_error: 0.2287 - mean_squared_error: 0.1006 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1043 - learning_rate: 1.6284e-06
# Epoch 147/200
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1006 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1042 - learning_rate: 1.6284e-06
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2286 - mean_absolute_error: 0.2286 - mean_squared_error: 0.1006 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.1042 - learning_rate: 1.6284e-06

# %%
# model2.save('best_6.keras')
# from IPython.display import FileLink
# FileLink(r'best_3.keras')

# %%
# model_path = "best_6.keras"
# best_model = keras.models.load_model(
#     model_path,
#     custom_objects={"PositionalEncoding": PositionalEncoding}
# )
best_model = model2

# %%
from tensorflow.keras.utils import plot_model
# Plot the model and save it as an image
plot_model(best_model, to_file='model2_architecture.png', show_shapes=True, show_layer_names=True)

# %%
# %%
# Cell 28: Evaluation Metrics Functions
def score_metric_fn(y_true, y_pred):
    """
    NASA's scoring function for RUL prediction
    Score = (1/t) * sum(exp(alpha * |Y_pred - Y_true|) - 1)
    where alpha = 1/13 if (Y_pred - Y_true) < 0, else 1/10
    Asymmetric - penalizes late predictions more than early predictions
    """
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    diff = y_pred - y_true
    alpha = np.where(diff < 0, 1/13, 1/10)  # 1/13 for late, 1/10 for early
    score = np.mean(np.exp(alpha * np.abs(diff)) - 1)
    return score
from sklearn.metrics import mean_squared_error, mean_absolute_error

def calculate_all_metrics(y_true, y_pred, model_name="Model"):
    """Calculate and display all evaluation metrics"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Standard metrics
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    # NASA scoring function
    score = score_metric_fn(y_true, y_pred)
    
    # Additional metrics
    mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100
    r2 = 1 - (np.sum((y_true - y_pred)**2) / np.sum((y_true - np.mean(y_true))**2))
    
    # Print results
    print(f"\n{'='*60}")
    print(f"{model_name} - Evaluation Metrics")
    print(f"{'='*60}")
    print(f"MAE (Mean Absolute Error):        {mae:.4f}")
    print(f"MSE (Mean Squared Error):         {mse:.4f}")
    print(f"RMSE (Root Mean Squared Error):   {rmse:.4f}")
    print(f"NASA Score:                       {score:.4f}")
    print(f"MAPE (Mean Absolute % Error):     {mape:.2f}%")
    print(f"R² Score:                         {r2:.4f}")
    print(f"{'='*60}\n")
    
    return {
        'mae': mae,
        'mse': mse,
        'rmse': rmse,
        'nasa_score': score,
        'mape': mape,
        'r2': r2
    }

def error_analysis(y_true, y_pred, model_name="Model"):
    """Analyze prediction errors in detail"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    
    print(f"\n{'='*60}")
    print(f"{model_name} - Error Analysis")
    print(f"{'='*60}")
    print(f"Mean Error (Bias):              {np.mean(errors):.4f}")
    print(f"Std Dev of Errors:              {np.std(errors):.4f}")
    print(f"Min Error:                      {np.min(errors):.4f}")
    print(f"Max Error:                      {np.max(errors):.4f}")
    print(f"25th Percentile Error:          {np.percentile(errors, 25):.4f}")
    print(f"Median Error:                   {np.median(errors):.4f}")
    print(f"75th Percentile Error:          {np.percentile(errors, 75):.4f}")
    
    # Count late vs early predictions
    late_predictions = np.sum(errors < 0)
    early_predictions = np.sum(errors > 0)
    print(f"\nLate Predictions (risky):       {late_predictions} ({late_predictions/len(errors)*100:.1f}%)")
    print(f"Early Predictions (safe):       {early_predictions} ({early_predictions/len(errors)*100:.1f}%)")
    print(f"{'='*60}\n")
    
    return errors

# %%
# %%
# Cell 29: Comprehensive Visualization Function
def plot_comprehensive_results(y_true, y_pred, errors, metrics, history=None):
    """Create comprehensive visualization of results"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Determine number of subplots
    n_plots = 8 if history is not None else 6
    fig = plt.figure(figsize=(20, 12 if history is not None else 10))
    
    # 1. Predictions vs Ground Truth
    ax1 = plt.subplot(3, 3, 1)
    plt.scatter(y_true, y_pred, alpha=0.5, s=20)
    plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', lw=2)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Predicted RUL', fontsize=12)
    plt.title(f'Predictions vs Ground Truth\nMAE: {metrics["mae"]:.2f}, RMSE: {metrics["rmse"]:.2f}', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    # 2. Error Distribution
    ax2 = plt.subplot(3, 3, 2)
    plt.hist(errors, bins=50, edgecolor='black', alpha=0.7)
    plt.axvline(x=0, color='r', linestyle='--', linewidth=2, label='Zero Error')
    plt.axvline(x=np.mean(errors), color='g', linestyle='--', linewidth=2, label=f'Mean: {np.mean(errors):.2f}')
    plt.xlabel('Prediction Error (Pred - True)', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.title('Error Distribution', fontsize=12)
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 3. Error vs True RUL
    ax3 = plt.subplot(3, 3, 3)
    plt.scatter(y_true, errors, alpha=0.5, s=20, c=errors, cmap='RdYlGn_r')
    plt.axhline(y=0, color='r', linestyle='--', linewidth=2)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Prediction Error', fontsize=12)
    plt.title('Error vs True RUL', fontsize=12)
    plt.colorbar(label='Error')
    plt.grid(True, alpha=0.3)
    
    # 4. Absolute Error vs True RUL
    ax4 = plt.subplot(3, 3, 4)
    abs_errors = np.abs(errors)
    plt.scatter(y_true, abs_errors, alpha=0.5, s=20)
    plt.xlabel('True RUL', fontsize=12)
    plt.ylabel('Absolute Error', fontsize=12)
    plt.title('Absolute Error vs True RUL', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    # 5. Cumulative Error Distribution
    ax5 = plt.subplot(3, 3, 5)
    sorted_abs_errors = np.sort(np.abs(errors))
    cumulative = np.arange(1, len(sorted_abs_errors) + 1) / len(sorted_abs_errors) * 100
    plt.plot(sorted_abs_errors, cumulative, linewidth=2)
    plt.xlabel('Absolute Error', fontsize=12)
    plt.ylabel('Cumulative %', fontsize=12)
    plt.title('Cumulative Error Distribution', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    for percentile in [50, 75, 90, 95]:
        error_at_percentile = np.percentile(abs_errors, percentile)
        plt.axvline(x=error_at_percentile, linestyle='--', alpha=0.5, 
                   label=f'{percentile}th: {error_at_percentile:.2f}')
    plt.legend(fontsize=9)
    
    # 6. Metrics Summary Box
    ax6 = plt.subplot(3, 3, 6)
    ax6.axis('off')
    
    metrics_text = f"""
    EVALUATION METRICS
    {'='*35}
    
    MAE:           {metrics['mae']:.4f}
    MSE:           {metrics['mse']:.4f}
    RMSE:          {metrics['rmse']:.4f}
    NASA Score:    {metrics['nasa_score']:.4f}
    R² Score:      {metrics['r2']:.4f}
    MAPE:          {metrics['mape']:.2f}%
    
    {'='*35}
    
    Mean Error:    {np.mean(errors):.4f}
    Std Dev:       {np.std(errors):.4f}
    
    Late Pred:     {np.sum(errors < 0)} ({np.sum(errors < 0)/len(errors)*100:.1f}%)
    Early Pred:    {np.sum(errors > 0)} ({np.sum(errors > 0)/len(errors)*100:.1f}%)
    """
    
    ax6.text(0.1, 0.5, metrics_text, fontsize=11, family='monospace',
             verticalalignment='center', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.3))
    
    # 7 & 8. Training History (if provided)
    if history is not None:
        ax7 = plt.subplot(3, 3, 7)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epochs', fontsize=12)
        plt.ylabel('Loss', fontsize=12)
        plt.title('Loss vs Epochs', fontsize=12)
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        ax8 = plt.subplot(3, 3, 8)
        plt.plot(history.history['mean_absolute_error'], label='Training MAE')
        plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
        plt.xlabel('Epochs', fontsize=12)
        plt.ylabel('MAE', fontsize=12)
        plt.title('MAE vs Epochs', fontsize=12)
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # 9. Learning Rate (if available)
        ax9 = plt.subplot(3, 3, 9)
        if 'lr' in history.history:
            plt.plot(history.history['lr'])
            plt.xlabel('Epochs', fontsize=12)
            plt.ylabel('Learning Rate', fontsize=12)
            plt.title('Learning Rate Schedule', fontsize=12)
            plt.yscale('log')
            plt.grid(True, alpha=0.3)
        else:
            ax9.axis('off')
            ax9.text(0.5, 0.5, 'Learning Rate\nHistory Not Available', 
                    ha='center', va='center', fontsize=14)
    
    plt.tight_layout()
    plt.savefig('comprehensive_evaluation.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print("Comprehensive evaluation plot saved as 'comprehensive_evaluation.png'")

# %%

# %%
# Cell 30: Save Results Function
def save_results_to_file(results, filename='evaluation_results.txt'):
    """Save all metrics to a text file"""
    with open(filename, 'w') as f:
        f.write("="*60 + "\n")
        f.write("RUL PREDICTION - EVALUATION RESULTS\n")
        f.write("="*60 + "\n\n")
        
        for model_name, metrics in results.items():
            f.write(f"\n{model_name.upper()}\n")
            f.write("-"*40 + "\n")
            for metric_name, value in metrics.items():
                f.write(f"{metric_name.upper():20s}: {value:.4f}\n")
            f.write("\n")
    
    print(f" Results saved to '{filename}'")

# %%
# Cell 31: Evaluate on Test Set
print("\n" + "="*60)
print("FINAL MODEL EVALUATION ON TEST SET")
print("="*60)

# Make predictions
test_predictions = best_model.predict(test_gen, verbose=1)

# Calculate metrics
test_metrics = calculate_all_metrics(test_labels, test_predictions, "Best Model (Test Set)")

# Error analysis
test_errors = error_analysis(test_labels, test_predictions, "Best Model (Test Set)")
# Out:
# ============================================================
# FINAL MODEL EVALUATION ON TEST SET
# ============================================================
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step
#
# ============================================================
# Best Model (Test Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        0.1926
# MSE (Mean Squared Error):         0.0796
# RMSE (Root Mean Squared Error):   0.2822
# NASA Score:                       0.0174
# MAPE (Mean Absolute % Error):     82.47%
# R² Score:                         0.9052
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              0.0007
# Std Dev of Errors:              0.2822
# Min Error:                      -1.4250
# Max Error:                      1.8539
# 25th Percentile Error:          -0.1311
# Median Error:                   -0.0157
# 75th Percentile Error:          0.0936
#
# Late Predictions (risky):       98460 (54.7%)
# Early Predictions (safe):       81511 (45.3%)
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        0.1926
# MSE (Mean Squared Error):         0.0796
# RMSE (Root Mean Squared Error):   0.2822
# NASA Score:                       0.0174
# MAPE (Mean Absolute % Error):     82.47%
# R² Score:                         0.9052
# ============================================================
#
#
# ============================================================
# Best Model (Test Set) - Error Analysis
# ============================================================
# Mean Error (Bias):              0.0007
# Std Dev of Errors:              0.2822
# Min Error:                      -1.4250
# Max Error:                      1.8539
# 25th Percentile Error:          -0.1311
# Median Error:                   -0.0157
# 75th Percentile Error:          0.0936
#
# Late Predictions (risky):       98460 (54.7%)
# Early Predictions (safe):       81511 (45.3%)
# ============================================================

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error
# Extract labels from tf.data.Dataset
def extract_labels(dataset):
    """Extracts all y_true and y_pred arrays from a tf.data.Dataset."""
    y_true_all = []
    for _, y in dataset:
        y_true_all.extend(y.numpy().flatten())
    return np.array(y_true_all)

# Extract standardized labels (still in standardized scale)
val_labels_std = extract_labels(val_gen)
test_labels_std = extract_labels(test_gen)

# Ensure predictions are flattened (still in standardized scale)
val_predictions_std = best_model.predict(val_gen, verbose=1).flatten()
test_predictions_std = best_model.predict(test_gen, verbose=1).flatten()

# ✅ Calculate metrics on standardized scale (absolute metrics)
print("\n" + "="*80)
print("METRICS ON STANDARDIZED SCALE (Absolute)")
print("="*80)
val_metrics_std = calculate_all_metrics(val_labels_std, val_predictions_std, "Validation Set (Standardized)")
test_metrics_std = calculate_all_metrics(test_labels_std, test_predictions_std, "Test Set (Standardized)")

# ✅ Inverse transform predictions and labels back to original RUL scale for reference
val_labels = RUL_SCALER.inverse_transform(val_labels_std.reshape(-1, 1)).flatten()
test_labels = RUL_SCALER.inverse_transform(test_labels_std.reshape(-1, 1)).flatten()
val_predictions = RUL_SCALER.inverse_transform(val_predictions_std.reshape(-1, 1)).flatten()
test_predictions = RUL_SCALER.inverse_transform(test_predictions_std.reshape(-1, 1)).flatten()

print("\n" + "="*80)
print("METRICS ON ORIGINAL SCALE (Reference Only)")
print("="*80)
val_metrics_orig = calculate_all_metrics(val_labels, val_predictions, "Validation Set (Original Scale)")
test_metrics_orig = calculate_all_metrics(test_labels, test_predictions, "Test Set (Original Scale)")

print("\n✅ Predictions and labels inverse-transformed to original RUL scale for reference")
print(f"Original scale - Val labels: Min={val_labels.min():.2f}, Max={val_labels.max():.2f}, Mean={val_labels.mean():.2f}")
print(f"Original scale - Test labels: Min={test_labels.min():.2f}, Max={test_labels.max():.2f}, Mean={test_labels.mean():.2f}")
# Out:
# 16/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2025-11-28 16:04:45.869109: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#
# ================================================================================
# METRICS ON STANDARDIZED SCALE (Absolute)
# ================================================================================
#
# ============================================================
# Validation Set (Standardized) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        0.2166
# MSE (Mean Squared Error):         0.1033
# RMSE (Root Mean Squared Error):   0.3213
# NASA Score:                       0.0189
# MAPE (Mean Absolute % Error):     67.09%
# R² Score:                         0.8967
# ============================================================
#
#
# ============================================================
# Test Set (Standardized) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        0.1926
# MSE (Mean Squared Error):         0.0796
# RMSE (Root Mean Squared Error):   0.2822
# NASA Score:                       0.0174
# MAPE (Mean Absolute % Error):     82.47%
# R² Score:                         0.9052
# ============================================================
#
#
# ================================================================================
# METRICS ON ORIGINAL SCALE (Reference Only)
# ================================================================================
#
# ============================================================
# Validation Set (Original Scale) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        5.7062
# MSE (Mean Squared Error):         71.6681
# RMSE (Root Mean Squared Error):   8.4657
# NASA Score:                       0.9596
# MAPE (Mean Absolute % Error):     21.58%
# R² Score:                         0.8967
# ============================================================
#
#
# ============================================================
# Test Set (Original Scale) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        5.0733
# MSE (Mean Squared Error):         55.2793
# RMSE (Root Mean Squared Error):   7.4350
# NASA Score:                       0.8864
# MAPE (Mean Absolute % Error):     13.24%
# R² Score:                         0.9052
# ============================================================
#
#
# ✅ Predictions and labels inverse-transformed to original RUL scale for reference
# Original scale - Val labels: Min=1.00, Max=99.00, Mean=45.50
# Original scale - Test labels: Min=1.00, Max=89.00, Mean=42.72
#
# ================================================================================
# METRICS ON STANDARDIZED SCALE (Absolute)
# ================================================================================
#
# ============================================================
# Validation Set (Standardized) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        0.2166
# MSE (Mean Squared Error):         0.1033
# RMSE (Root Mean Squared Error):   0.3213
# NASA Score:                       0.0189
# MAPE (Mean Absolute % Error):     67.09%
# R² Score:                         0.8967
# ============================================================
#
#
# ============================================================
# Test Set (Standardized) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        0.1926
# MSE (Mean Squared Error):         0.0796
# RMSE (Root Mean Squared Error):   0.2822
# NASA Score:                       0.0174
# MAPE (Mean Absolute % Error):     82.47%
# R² Score:                         0.9052
# ============================================================
#
#
# ================================================================================
# METRICS ON ORIGINAL SCALE (Reference Only)
# ================================================================================
#
# ============================================================
# Validation Set (Original Scale) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        5.7062
# MSE (Mean Squared Error):         71.6681
# RMSE (Root Mean Squared Error):   8.4657
# NASA Score:                       0.9596
# MAPE (Mean Absolute % Error):     21.58%
# R² Score:                         0.8967
# ============================================================
#
#
# ============================================================
# Test Set (Original Scale) - Evaluation Metrics
# ============================================================
# MAE (Mean Absolute Error):        5.0733
# MSE (Mean Squared Error):         55.2793
# RMSE (Root Mean Squared Error):   7.4350
# NASA Score:                       0.8864
# MAPE (Mean Absolute % Error):     13.24%
# R² Score:                         0.9052
# ============================================================
#
#
# ✅ Predictions and labels inverse-transformed to original RUL scale for reference
# Original scale - Val labels: Min=1.00, Max=99.00, Mean=45.50
# Original scale - Test labels: Min=1.00, Max=89.00, Mean=42.72

# %%
mae_diff_std = test_metrics_std["mae"] - val_metrics_std["mae"]
rmse_diff_std = test_metrics_std["rmse"] - val_metrics_std["rmse"]
nasa_diff_std = test_metrics_std["nasa_score"] - val_metrics_std["nasa_score"]

print("\n" + "="*80)
print("STANDARDIZED SCALE - VALIDATION VS TEST COMPARISON")
print("="*80)
print(f"MAE Difference (Test - Val): {mae_diff_std:+.4f}")
print(f"RMSE Difference (Test - Val): {rmse_diff_std:+.4f}")
print(f"NASA Score Difference (Test - Val): {nasa_diff_std:+.4f}")

if mae_diff_std > 0.2:
    print("⚠️ Warning: Performance drop on test set — possible overfitting")
elif mae_diff_std < -0.2:
    print("✅ Model generalizes better on test set")
else:
    print("✅ Model shows consistent performance across validation and test sets")
# Out:
# ================================================================================
# STANDARDIZED SCALE - VALIDATION VS TEST COMPARISON
# ================================================================================
# MAE Difference (Test - Val): -0.0240
# RMSE Difference (Test - Val): -0.0391
# NASA Score Difference (Test - Val): -0.0015
# ✅ Model shows consistent performance across validation and test sets

# %%
def plot_comprehensive_results(y_true, y_pred, metrics, history=None, title="Comprehensive Evaluation"):
    """Comprehensive performance visualization."""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()

    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    # 1️⃣ True vs Predicted
    axs[0].plot(y_true, label="True RUL", alpha=0.7)
    axs[0].plot(y_pred, label="Predicted RUL", alpha=0.7)
    axs[0].set_title("Predicted vs True RUL")
    axs[0].set_xlabel("Sample Index")
    axs[0].set_ylabel("RUL")
    axs[0].legend()
    axs[0].grid(True)

    # 2️⃣ Scatter
    axs[1].scatter(y_true, y_pred, alpha=0.5)
    lims = [min(y_true.min(), y_pred.min()), max(y_true.max(), y_pred.max())]
    axs[1].plot(lims, lims, "r--", label="Ideal Fit")
    axs[1].set_xlim(lims)
    axs[1].set_ylim(lims)
    axs[1].set_title("True vs Predicted Scatter")
    axs[1].set_xlabel("True RUL")
    axs[1].set_ylabel("Predicted RUL")
    axs[1].legend()
    axs[1].grid(True)

    # 3️⃣ Training History (if available)
    if history is not None:
        axs[2].plot(history.history.get("mae", []), label="Train MAE")
        axs[2].plot(history.history.get("val_mae", []), label="Val MAE")
        axs[2].plot(history.history.get("loss", []), label="Train Loss")
        axs[2].plot(history.history.get("val_loss", []), label="Val Loss")
        axs[2].set_title("Training History")
        axs[2].set_xlabel("Epochs")
        axs[2].set_ylabel("Metric Value")
        axs[2].legend()
        axs[2].grid(True)
    else:
        axs[2].axis("off")
        axs[2].text(0.5, 0.5, "No training history provided", ha="center", va="center")

    plt.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()


# Run visualization
plot_comprehensive_results(test_labels, test_predictions, test_metrics)

# %%
def show_prediction_samples(y_true, y_pred, n_samples=20):
    """Show random sample predictions."""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    indices = np.random.choice(len(y_true), min(n_samples, len(y_true)), replace=False)
    print("\n" + "="*80)
    print("SAMPLE PREDICTIONS")
    print("="*80)
    print(f"{'Index':<8} {'True RUL':<12} {'Pred RUL':<12} {'Error':<12} {'Abs Error':<12} {'Type':<12}")
    print("-"*80)
    for idx in sorted(indices):
        error = y_pred[idx] - y_true[idx]
        pred_type = "Late (Risk)" if error < 0 else "Early (Safe)"
        print(f"{idx:<8} {y_true[idx]:<12.2f} {y_pred[idx]:<12.2f} {error:<+12.2f} {abs(error):<12.2f} {pred_type:<12}")
    print("="*80 + "\n")

show_prediction_samples(test_labels, test_predictions)
# Out:
# ================================================================================
# SAMPLE PREDICTIONS
# ================================================================================
# Index    True RUL     Pred RUL     Error        Abs Error    Type
# --------------------------------------------------------------------------------
# 14439    41.00        55.29        +14.29       14.29        Early (Safe)
# 22124    12.00        14.09        +2.09        2.09         Early (Safe)
# 27258    85.00        91.44        +6.44        6.44         Early (Safe)
# 29817    81.00        56.07        -24.93       24.93        Late (Risk)
# 47932    51.00        49.92        -1.08        1.08         Late (Risk)
# 51025    46.00        43.94        -2.06        2.06         Late (Risk)
# 60036    30.00        25.29        -4.71        4.71         Late (Risk)
# 87210    51.00        60.53        +9.53        9.53         Early (Safe)
# 90197    41.00        39.87        -1.13        1.13         Late (Risk)
# 97061    17.00        22.76        +5.76        5.76         Early (Safe)
# 101884   81.00        68.04        -12.96       12.96        Late (Risk)
# 113908   69.00        60.87        -8.13        8.13         Late (Risk)
# 114293   68.00        67.07        -0.93        0.93         Late (Risk)
# 128300   54.00        51.83        -2.17        2.17         Late (Risk)
# 135387   47.00        41.36        -5.64        5.64         Late (Risk)
# 136530   46.00        48.51        +2.51        2.51         Early (Safe)
# 145684   37.00        36.60        -0.40        0.40         Late (Risk)
# 150877   31.00        26.64        -4.36        4.36         Late (Risk)
# 166045   16.00        15.85        -0.15        0.15         Late (Risk)
# 173204   8.00         8.97         +0.97        0.97         Early (Safe)
# ================================================================================

# %%
def show_best_worst_predictions(y_true, y_pred, n=10):
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    abs_errors = np.abs(errors)
    
    best_idx = np.argsort(abs_errors)[:n]
    worst_idx = np.argsort(abs_errors)[-n:][::-1]
    
    print("\n" + "="*80)
    print(f"TOP {n} BEST PREDICTIONS")
    print("="*80)
    for idx in best_idx:
        print(f"{idx:<8} True={y_true[idx]:<8.2f} Pred={y_pred[idx]:<8.2f} Err={errors[idx]:<+8.2f}")

    print("\n" + "="*80)
    print(f"TOP {n} WORST PREDICTIONS")
    print("="*80)
    for idx in worst_idx:
        pred_type = "Late" if errors[idx] < 0 else "Early"
        print(f"{idx:<8} True={y_true[idx]:<8.2f} Pred={y_pred[idx]:<8.2f} Err={errors[idx]:<+8.2f} ({pred_type})")

show_best_worst_predictions(test_labels, test_predictions)
# Out:
# ================================================================================
# TOP 10 BEST PREDICTIONS
# ================================================================================
# 41105    True=62.00    Pred=62.00    Err=-0.00
# 7274     True=65.00    Pred=65.00    Err=+0.00
# 46208    True=54.00    Pred=54.00    Err=-0.00
# 163745   True=18.00    Pred=18.00    Err=-0.00
# 177131   True=4.00     Pred=4.00     Err=+0.00
# 120538   True=62.00    Pred=62.00    Err=+0.00
# 76144    True=4.00     Pred=4.00     Err=+0.00
# 78110    True=1.00     Pred=1.00     Err=+0.00
# 134027   True=48.00    Pred=48.00    Err=-0.00
# 72583    True=11.00    Pred=11.00    Err=-0.00
#
# ================================================================================
# TOP 10 WORST PREDICTIONS
# ================================================================================
# 90446    True=40.00    Pred=88.84    Err=+48.84   (Early)
# 90447    True=40.00    Pred=84.85    Err=+44.85   (Early)
# 88354    True=48.00    Pred=92.54    Err=+44.54   (Early)
# 88282    True=48.00    Pred=92.49    Err=+44.49   (Early)
# 88283    True=48.00    Pred=91.76    Err=+43.76   (Early)
# 89706    True=43.00    Pred=86.71    Err=+43.71   (Early)
# 89698    True=43.00    Pred=86.30    Err=+43.30   (Early)
# 89697    True=43.00    Pred=86.24    Err=+43.24   (Early)
# 89705    True=43.00    Pred=85.87    Err=+42.87   (Early)
# 89700    True=43.00    Pred=85.77    Err=+42.77   (Early)

# %%
def analyze_by_rul_ranges(y_true, y_pred, y_true_orig=None, y_pred_orig=None):
    """Analyze performance by RUL ranges using standardized values"""
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # If original scale values provided, use them for binning
    if y_true_orig is not None:
        y_true_orig = np.array(y_true_orig).flatten()
        ranges = [(0,25,"Critical"),(25,50,"High Risk"),(50,75,"Medium"),(75,100,"Low"),(100,1e9,"Safe")]
    else:
        # Use standardized scale percentiles
        ranges = [(np.percentile(y_true, 0), np.percentile(y_true, 20), "Bottom 20%"),
                  (np.percentile(y_true, 20), np.percentile(y_true, 40), "20-40%"),
                  (np.percentile(y_true, 40), np.percentile(y_true, 60), "40-60%"),
                  (np.percentile(y_true, 60), np.percentile(y_true, 80), "60-80%"),
                  (np.percentile(y_true, 80), np.percentile(y_true, 100), "Top 20%")]
    
    print("\n" + "="*80)
    print("PERFORMANCE BY RUL RANGES (Using Standardized Metrics)")
    print("="*80)
    print(f"{'Range':<15}{'Count':<10}{'MAE':<10}{'RMSE':<10}{'NASA':<10}{'Late%':<10}")
    print("-"*80)
    
    for lo, hi, name in ranges:
        if y_true_orig is not None:
            mask = (y_true_orig >= lo) & (y_true_orig < hi)
        else:
            mask = (y_true >= lo) & (y_true < hi)
        
        if np.sum(mask) == 0: 
            continue
            
        yt, yp = y_true[mask], y_pred[mask]
        mae = mean_absolute_error(yt, yp)
        rmse = root_mean_squared_error(yt, yp)
        score = score_metric_fn(yt, yp)
        late = np.sum((yp - yt) < 0) / len(yt) * 100
        print(f"{name:<15}{len(yt):<10}{mae:<10.4f}{rmse:<10.4f}{score:<10.2f}{late:<10.1f}")
    print("="*80 + "\n")

# Analyze using standardized values (absolute metrics)
analyze_by_rul_ranges(test_labels_std, test_predictions_std, test_labels, test_predictions)
# Out:
# ================================================================================
# PERFORMANCE BY RUL RANGES (Using Standardized Metrics)
# ================================================================================
# Range          Count     MAE       RMSE      NASA      Late%
# --------------------------------------------------------------------------------
# Critical       51010     0.0579    0.0824    0.01      41.9
# High Risk      52773     0.1916    0.2791    0.02      60.5
# Medium         55507     0.2793    0.3559    0.03      53.2
# Low            20681     0.2944    0.3710    0.02      75.5
# ================================================================================

# %%
def create_summary_report():
    print("\n" + "="*80)
    print("FINAL SUMMARY REPORT - STANDARDIZED SCALE METRICS".center(80))
    print("="*80)
    
    print("\n📊 PRIMARY METRICS (Standardized Scale - Absolute)")
    print("-"*80)
    print("Validation Set:")
    for k,v in val_metrics_std.items(): print(f" {k:<15}: {v:.4f}")
    print("\nTest Set:")
    for k,v in test_metrics_std.items(): print(f" {k:<15}: {v:.4f}")

    test_errors_std = test_predictions_std.flatten() - test_labels_std.flatten()
    late = np.sum(test_errors_std < 0)
    early = np.sum(test_errors_std > 0)
    bias = np.mean(test_errors_std)

    print("\n⚠️ STANDARDIZED SCALE - RISK ANALYSIS")
    print("-"*80)
    print(f"Late Predictions (risky): {late} ({late/len(test_errors_std)*100:.1f}%)")
    print(f"Early Predictions (safe): {early} ({early/len(test_errors_std)*100:.1f}%)")
    print(f"Mean Bias (standardized): {bias:+.4f}")
    
    print("\n📈 REFERENCE METRICS (Original RUL Scale)")
    print("-"*80)
    print("Validation Set:")
    for k,v in val_metrics_orig.items(): print(f" {k:<15}: {v:.4f}")
    print("\nTest Set:")
    for k,v in test_metrics_orig.items(): print(f" {k:<15}: {v:.4f}")
    print("="*80 + "\n")

create_summary_report()
# Out:
# ================================================================================
#                FINAL SUMMARY REPORT - STANDARDIZED SCALE METRICS
# ================================================================================
#
# 📊 PRIMARY METRICS (Standardized Scale - Absolute)
# --------------------------------------------------------------------------------
# Validation Set:
#  mae            : 0.2166
#  mse            : 0.1033
#  rmse           : 0.3213
#  nasa_score     : 0.0189
#  mape           : 67.0870
#  r2             : 0.8967
#
# Test Set:
#  mae            : 0.1926
#  mse            : 0.0796
#  rmse           : 0.2822
#  nasa_score     : 0.0174
#  mape           : 82.4659
#  r2             : 0.9052
#
# ⚠️ STANDARDIZED SCALE - RISK ANALYSIS
# --------------------------------------------------------------------------------
# Late Predictions (risky): 98460 (54.7%)
# Early Predictions (safe): 81511 (45.3%)
# Mean Bias (standardized): +0.0007
#
# 📈 REFERENCE METRICS (Original RUL Scale)
# --------------------------------------------------------------------------------
# Validation Set:
#  mae            : 5.7062
#  mse            : 71.6681
#  rmse           : 8.4657
#  nasa_score     : 0.9596
#  mape           : 21.5847
#  r2             : 0.8967
#
# Test Set:
#  mae            : 5.0733
#  mse            : 55.2793
#  rmse           : 7.4350
#  nasa_score     : 0.8864
#  mape           : 13.2442
#  r2             : 0.9052
# ================================================================================

# %%
# ==========================================
# 📤 Export Predictions
# ==========================================
def export_predictions(y_true, y_pred, filename="predictions.csv"):
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    errors = y_pred - y_true
    df = pd.DataFrame({
        "True_RUL": y_true,
        "Predicted_RUL": y_pred,
        "Error": errors,
        "Abs_Error": np.abs(errors),
        "Prediction_Type": ["Late" if e < 0 else "Early" for e in errors]
    })
    return df

predictions_df = export_predictions(test_labels, test_predictions)
predictions_df.head(10)
# Out:
#    True_RUL  Predicted_RUL     Error  Abs_Error Prediction_Type
# 0      89.0      84.663605 -4.336395   4.336395            Late
# 1      89.0      84.573090 -4.426910   4.426910            Late
# 2      89.0      84.670807 -4.329193   4.329193            Late
# 3      89.0      84.594231 -4.405769   4.405769            Late
# 4      89.0      84.627487 -4.372513   4.372513            Late
# 5      89.0      85.021690 -3.978310   3.978310            Late
# 6      89.0      84.812653 -4.187347   4.187347            Late
# 7      89.0      84.606300 -4.393700   4.393700            Late
# 8      89.0      84.748444 -4.251556   4.251556            Late
# 9      89.0      84.527184 -4.472816   4.472816            Late
